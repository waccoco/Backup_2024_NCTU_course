# %% [markdown]
# ## This notebook is dedicated to linear regression analysis : Data generated by random seed

# %%
# from google.colab import drive
# drive.mount('/content/drive/')

# %%
import os
os.listdir()
# !ls
# Out:
# ['.ipynb_checkpoints',
#  '1_Data_import_visulization_LoadData.ipynb',
#  '1_Data_import_visulization_LoadData_1.ipynb',
#  '1_Data_import_visulization_RandomSeed.ipynb',
#  '2_Cost_function.ipynb',
#  '3_gradient_descent.ipynb',
#  '4_Dash_Board.ipynb']

# %%
# !pip install wget
# !pip install pandas
# !pip install matplotlib
# !pip install plotly
# !pip install ipywidgets

# %%
import numpy as np

# 設定 a 和 b 的值
a = 7  # 假設 a 為 2
b = 3  # 假設 b 為 1

# 決定 x 的範圍和數量
x = np.linspace(0, 12, 500)  # 從 -10 到 10 生成 100 個點

# 計算對應的 y 值，並加入一些隨機性來模擬真實世界數據的波動
y = a * x + b + np.random.normal(0, 5, x.shape)

# https://numpy.org/doc/stable/reference/random/generated/numpy.random.normal.html

# 顯示前幾個生成的點來確認
y[:10]
# Out:
# array([ 2.19274591,  8.12281941,  0.58540374,  0.36345368,  4.80782343,
#        12.88816939,  6.72357449, -4.77806677,  2.72490459, 20.65257125])

# %% [markdown]
# ### Exercise : Please try to download waccoco/../Dataset/ChineseFont.ttf from my github

# %%
import wget
url = "https://raw.githubusercontent.com/waccoco/2024_NYCU_MI_course/master/Dataset/ChineseFont.ttf"
output_path = './ChineseFont.ttf'
wget.download(url, out=output_path)
# Out:
# 100% [........................................................................] 20852224 / 20852224
# './ChineseFont (1).ttf'

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib.font_manager import fontManager

fontManager.addfont("ChineseFont.ttf")
mpl.rc('font', family="ChineseFont")

plt.scatter(x, y, marker="x", color="red")
plt.axis((0,12, 0,140))
plt.title("年資-薪水")
plt.xlabel("年資")
plt.ylabel("月薪(千)")
plt.show()

# %%
def plot_pred(w, b):
  y_pred = x*w + b
  plt.plot(x, y_pred, color="blue", label="預測線")
  plt.scatter(x, y, marker="x", color="red", label="真實數據")
  plt.title("年資-薪水")
  plt.xlabel("年資")
  plt.ylabel("月薪(千)")
  plt.xlim([0, 12])
  plt.ylim([-60, 140])
  plt.legend()
  plt.show()

plot_pred(9, 30)

# %%
from ipywidgets import interact

interact(plot_pred, w=(-100, 100, 1), b=(-100, 100, 1))
# Out:
# interactive(children=(IntSlider(value=0, description='w', min=-100), IntSlider(value=0, description='b', min=-…
# <function __main__.plot_pred(w, b)>

# %%
import plotly.express as px
fig = px.scatter(x, y)
fig.show()

# %% [markdown]
# ### Excercise :　Please try to download the dataset 'Salary_Data2.csv'
# #### github path = waccoco/2024_NYCU_MI_course/Dataset/Salary_Data2.csv

# %%
import pandas as pd
import wget

# download dataset
url = "https://raw.githubusercontent.com/waccoco/2024_NYCU_MI_course/master/Dataset/Salary_Data2.csv"   # from ref. 
output_path = './Salary_Data2.csv'
wget.download(url, out=output_path)

# load dataset
path = output_path
df = pd.read_csv(output_path)

display(df)
# Out:
# 100% [................................................................................] 1040 / 1040
#    YearsExperience EducationLevel City  Salary
# 0              3.0             大學  城市A    45.9
# 1              7.8           碩士以上  城市C    80.5
# 2              2.3           高中以下  城市A    25.2
# 3              5.1           高中以下  城市A    30.4
# 4             10.0           碩士以上  城市B    65.7

# %%
def download_and_load (url):
    import pandas as pd
    import wget
    
    # download dataset
    output_path = './Salary_Data2.csv'
    wget.download(url, out=output_path)
    
    # load dataset
    path = output_path
    df = pd.read_csv(output_path)
    
    return df

url = "https://raw.githubusercontent.com/waccoco/2024_NYCU_MI_course/master/Dataset/Salary_Data2.csv"   # from ref. 
df= download_and_load (url)
display(df.head(5))
# Out:
# 100% [................................................................................] 1040 / 1040
#    YearsExperience EducationLevel City  Salary
# 0              3.0             大學  城市A    45.9
# 1              7.8           碩士以上  城市C    80.5
# 2              2.3           高中以下  城市A    25.2
# 3              5.1           高中以下  城市A    30.4
# 4             10.0           碩士以上  城市B    65.7

# %% [markdown]
# ### Excercise :　Please try to visulize yea

# %%
## You can use the program shown above 
x2 = df ['Salary']
y2 = df ['YearsExperience']

def plot_scatter (x, y, title, x_label, y_label):
    plt.scatter(x2, y2, marker="x", color="red")
    # plt.axis((0,12, 0,140))
    plt.title(title)
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.show()

plot_scatter(x2, y2, "年資-薪水", "年資", "月薪(千)")
