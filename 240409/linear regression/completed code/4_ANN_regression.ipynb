# %% [markdown]
# ## Data Preparation

# %%
# install scikit-learn, tensorflow, pandas, matplotlib, numpy
# Out:
# 'conda' 不是內部或外部命令、可執行的程式或批次檔。

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# randomseed
np.random.seed(0)

# data : y = ax+b
a = 2
b = 1
noise_scale = 10

# data generation
x = np.linspace(0, 50, 100)
q = np.random.normal(0, noise_scale, x.shape)
y = a * x + b + q

# # data : y = a*exp(bx)
# a = 2
# b = 1
# c= 50
# noise_scale = 20

# # data generation
# x = np.linspace(0, 5, 100)
# y = a * np.exp(b * x) + q + c

# splitting dataset to training set and testing set 
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %% [markdown]
# ##  data visualization

# %%
plt.scatter(x_train, y_train, color='blue', label='Training data')
plt.scatter(x_test, y_test, color='red', label='Testing data')
plt.legend()
plt.show()

# %% [markdown]
# ## Build ANN model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam

model = Sequential([
    Dense(1, input_shape=(1,), activation='linear')
])

# model = Sequential([
#     Dense(5, input_shape=(1,), activation='relu'),
#     Dense(3, activation='relu'),
#     Dense(1, activation='linear')
# ])

# Sequential.help

model.compile(optimizer=Adam(learning_rate=0.01), loss='mse')

# %% [markdown]
# ## Training ANN model

# %%
from tensorflow.keras.callbacks import EarlyStopping

early_stop = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)
history = model.fit(x_train, y_train, validation_split=0.2, epochs=200, batch_size=2)
# Out:
# Epoch 1/200
# 32/32 [==============================] - 2s 19ms/step - loss: 5131.1479 - val_loss: 5178.4346
# Epoch 2/200
# 32/32 [==============================] - 0s 5ms/step - loss: 4095.3801 - val_loss: 4067.1377
# Epoch 3/200
# 32/32 [==============================] - 0s 6ms/step - loss: 3210.6306 - val_loss: 3160.6353
# Epoch 4/200
# 32/32 [==============================] - 0s 6ms/step - loss: 2471.4863 - val_loss: 2449.0049
# Epoch 5/200
# 32/32 [==============================] - 0s 5ms/step - loss: 1886.3384 - val_loss: 1876.0204
# Epoch 6/200
# 32/32 [==============================] - 0s 6ms/step - loss: 1428.6300 - val_loss: 1400.8708
# Epoch 7/200
# 32/32 [==============================] - 0s 6ms/step - loss: 1064.5537 - val_loss: 1040.7168
# Epoch 8/200
# 32/32 [==============================] - 0s 6ms/step - loss: 790.9788 - val_loss: 760.6199
# Epoch 9/200
# 32/32 [==============================] - 0s 6ms/step - loss: 586.7297 - val_loss: 554.8301
# Epoch 10/200
# 32/32 [==============================] - 0s 6ms/step - loss: 433.3200 - val_loss: 414.0068
# Epoch 11/200
# 32/32 [==============================] - 0s 4ms/step - loss: 325.9399 - val_loss: 314.5110
# Epoch 12/200
# 32/32 [==============================] - 0s 4ms/step - loss: 252.6713 - val_loss: 234.1535
# Epoch 13/200
# 32/32 [==============================] - 0s 4ms/step - loss: 198.6021 - val_loss: 185.6072
# Epoch 14/200
# 32/32 [==============================] - 0s 5ms/step - loss: 164.4179 - val_loss: 148.5005
# Epoch 15/200
# 32/32 [==============================] - 0s 4ms/step - loss: 141.6135 - val_loss: 124.0119
# Epoch 16/200
# 32/32 [==============================] - 0s 5ms/step - loss: 127.1841 - val_loss: 108.3740
# Epoch 17/200
# 32/32 [==============================] - 0s 6ms/step - loss: 117.9342 - val_loss: 99.6106
# Epoch 18/200
# 32/32 [==============================] - 0s 4ms/step - loss: 112.4687 - val_loss: 92.9261
# Epoch 19/200
# 32/32 [==============================] - 0s 5ms/step - loss: 109.4268 - val_loss: 88.8616
# Epoch 20/200
# 32/32 [==============================] - 0s 5ms/step - loss: 107.3204 - val_loss: 86.3259
# Epoch 21/200
# 32/32 [==============================] - 0s 6ms/step - loss: 106.2036 - val_loss: 84.8872
# Epoch 22/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.6965 - val_loss: 83.3285
# Epoch 23/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.1858 - val_loss: 82.7376
# Epoch 24/200
# 32/32 [==============================] - 0s 4ms/step - loss: 105.0085 - val_loss: 82.5505
# Epoch 25/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.0126 - val_loss: 81.7578
# Epoch 26/200
# 32/32 [==============================] - 0s 5ms/step - loss: 104.8882 - val_loss: 81.7666
# Epoch 27/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.4676 - val_loss: 81.2169
# Epoch 28/200
# 32/32 [==============================] - 0s 6ms/step - loss: 105.0573 - val_loss: 81.8840
# Epoch 29/200
# 32/32 [==============================] - 0s 5ms/step - loss: 104.9161 - val_loss: 81.4019
# Epoch 30/200
# 32/32 [==============================] - 0s 4ms/step - loss: 104.8939 - val_loss: 81.3486
# Epoch 31/200
# 32/32 [==============================] - 0s 6ms/step - loss: 104.8396 - val_loss: 81.6391
# Epoch 32/200
# 32/32 [==============================] - 0s 7ms/step - loss: 105.0035 - val_loss: 81.4576
# Epoch 33/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.3626 - val_loss: 81.0251
# Epoch 34/200
# 32/32 [==============================] - 0s 5ms/step - loss: 104.9020 - val_loss: 81.3574
# Epoch 35/200
# 32/32 [==============================] - 0s 6ms/step - loss: 105.1202 - val_loss: 81.2179
# Epoch 36/200
# 32/32 [==============================] - 0s 6ms/step - loss: 105.0225 - val_loss: 81.7272
# Epoch 37/200
# 32/32 [==============================] - 0s 6ms/step - loss: 105.1797 - val_loss: 81.5644
# Epoch 38/200
# 32/32 [==============================] - 0s 6ms/step - loss: 105.1914 - val_loss: 81.7839
# Epoch 39/200
# 32/32 [==============================] - 0s 5ms/step - loss: 104.8933 - val_loss: 81.1299
# Epoch 40/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.3400 - val_loss: 81.0325
# Epoch 41/200
# 32/32 [==============================] - 0s 4ms/step - loss: 104.9510 - val_loss: 81.4431
# Epoch 42/200
# 32/32 [==============================] - 0s 4ms/step - loss: 105.0226 - val_loss: 81.2648
# Epoch 43/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.1203 - val_loss: 81.7839
# Epoch 44/200
# 32/32 [==============================] - 0s 6ms/step - loss: 105.2071 - val_loss: 80.9963
# Epoch 45/200
# 32/32 [==============================] - 0s 6ms/step - loss: 105.2897 - val_loss: 81.8316
# Epoch 46/200
# 32/32 [==============================] - 0s 6ms/step - loss: 105.6582 - val_loss: 80.8893
# Epoch 47/200
# 32/32 [==============================] - 0s 6ms/step - loss: 105.4461 - val_loss: 81.7493
# Epoch 48/200
# 32/32 [==============================] - 0s 6ms/step - loss: 105.5759 - val_loss: 80.9436
# Epoch 49/200
# 32/32 [==============================] - 0s 6ms/step - loss: 105.4807 - val_loss: 81.5392
# Epoch 50/200
# 32/32 [==============================] - 0s 5ms/step - loss: 104.8362 - val_loss: 81.3340
# Epoch 51/200
# 32/32 [==============================] - 0s 6ms/step - loss: 105.1094 - val_loss: 81.2954
# Epoch 52/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.2197 - val_loss: 80.8523
# Epoch 53/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.1324 - val_loss: 81.4543
# Epoch 54/200
# 32/32 [==============================] - 0s 5ms/step - loss: 104.9289 - val_loss: 81.1359
# Epoch 55/200
# 32/32 [==============================] - 0s 6ms/step - loss: 106.4190 - val_loss: 80.4963
# Epoch 56/200
# 32/32 [==============================] - 0s 6ms/step - loss: 105.6935 - val_loss: 81.4320
# Epoch 57/200
# 32/32 [==============================] - 0s 5ms/step - loss: 104.9418 - val_loss: 80.8161
# Epoch 58/200
# 32/32 [==============================] - 0s 5ms/step - loss: 104.9380 - val_loss: 81.4011
# Epoch 59/200
# 32/32 [==============================] - 0s 6ms/step - loss: 105.2343 - val_loss: 81.0634
# Epoch 60/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.1818 - val_loss: 80.7557
# Epoch 61/200
# 32/32 [==============================] - 0s 4ms/step - loss: 105.0479 - val_loss: 80.9176
# Epoch 62/200
# 32/32 [==============================] - 0s 4ms/step - loss: 105.2934 - val_loss: 81.4409
# Epoch 63/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.2700 - val_loss: 81.6969
# Epoch 64/200
# 32/32 [==============================] - 0s 5ms/step - loss: 107.3047 - val_loss: 80.4376
# Epoch 65/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.2442 - val_loss: 80.9123
# Epoch 66/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.8922 - val_loss: 82.2177
# Epoch 67/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.1765 - val_loss: 81.3711
# Epoch 68/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.2450 - val_loss: 81.2666
# Epoch 69/200
# 32/32 [==============================] - 0s 6ms/step - loss: 105.2543 - val_loss: 80.6452
# Epoch 70/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.2142 - val_loss: 81.3077
# Epoch 71/200
# 32/32 [==============================] - 0s 6ms/step - loss: 105.3112 - val_loss: 80.5851
# Epoch 72/200
# 32/32 [==============================] - 0s 5ms/step - loss: 104.8580 - val_loss: 81.0586
# Epoch 73/200
# 32/32 [==============================] - 0s 6ms/step - loss: 105.7705 - val_loss: 81.6268
# Epoch 74/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.0076 - val_loss: 80.9992
# Epoch 75/200
# 32/32 [==============================] - 0s 6ms/step - loss: 105.7213 - val_loss: 80.3166
# Epoch 76/200
# 32/32 [==============================] - 0s 5ms/step - loss: 104.8265 - val_loss: 81.3673
# Epoch 77/200
# 32/32 [==============================] - 0s 6ms/step - loss: 104.8200 - val_loss: 81.0030
# Epoch 78/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.3613 - val_loss: 80.6812
# Epoch 79/200
# 32/32 [==============================] - 0s 4ms/step - loss: 105.4804 - val_loss: 80.6801
# Epoch 80/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.1366 - val_loss: 80.9798
# Epoch 81/200
# 32/32 [==============================] - 0s 5ms/step - loss: 104.9508 - val_loss: 81.4053
# Epoch 82/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.1355 - val_loss: 81.2019
# Epoch 83/200
# 32/32 [==============================] - 0s 5ms/step - loss: 104.9401 - val_loss: 80.9945
# Epoch 84/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.2983 - val_loss: 81.4503
# Epoch 85/200
# 32/32 [==============================] - 0s 3ms/step - loss: 105.2531 - val_loss: 81.6580
# Epoch 86/200
# 32/32 [==============================] - 0s 3ms/step - loss: 104.8040 - val_loss: 80.9374
# Epoch 87/200
# 32/32 [==============================] - 0s 4ms/step - loss: 105.8273 - val_loss: 80.3137
# Epoch 88/200
# 32/32 [==============================] - 0s 6ms/step - loss: 105.0078 - val_loss: 80.9079
# Epoch 89/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.4783 - val_loss: 80.8011
# Epoch 90/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.0740 - val_loss: 80.6691
# Epoch 91/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.1058 - val_loss: 80.8042
# Epoch 92/200
# 32/32 [==============================] - 0s 6ms/step - loss: 105.0352 - val_loss: 81.2012
# Epoch 93/200
# 32/32 [==============================] - 0s 6ms/step - loss: 105.8640 - val_loss: 81.1308
# Epoch 94/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.3677 - val_loss: 81.3056
# Epoch 95/200
# 32/32 [==============================] - 0s 5ms/step - loss: 106.1153 - val_loss: 80.2632
# Epoch 96/200
# 32/32 [==============================] - 0s 6ms/step - loss: 105.0624 - val_loss: 81.3165
# Epoch 97/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.0803 - val_loss: 81.0762
# Epoch 98/200
# 32/32 [==============================] - 0s 6ms/step - loss: 104.9653 - val_loss: 80.8677
# Epoch 99/200
# 32/32 [==============================] - 0s 5ms/step - loss: 106.1450 - val_loss: 80.4761
# Epoch 100/200
# 32/32 [==============================] - 0s 4ms/step - loss: 104.9914 - val_loss: 81.6859
# Epoch 101/200
# 32/32 [==============================] - 0s 6ms/step - loss: 105.1014 - val_loss: 80.8366
# Epoch 102/200
# 32/32 [==============================] - 0s 5ms/step - loss: 106.1900 - val_loss: 80.2950
# Epoch 103/200
# 32/32 [==============================] - 0s 5ms/step - loss: 106.0535 - val_loss: 80.8142
# Epoch 104/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.6563 - val_loss: 81.1126
# Epoch 105/200
# 32/32 [==============================] - 0s 6ms/step - loss: 105.4341 - val_loss: 80.5604
# Epoch 106/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.4739 - val_loss: 80.6930
# Epoch 107/200
# 32/32 [==============================] - 0s 6ms/step - loss: 104.9164 - val_loss: 80.8173
# Epoch 108/200
# 32/32 [==============================] - 0s 6ms/step - loss: 105.3667 - val_loss: 80.5799
# Epoch 109/200
# 32/32 [==============================] - 0s 4ms/step - loss: 105.0903 - val_loss: 80.6224
# Epoch 110/200
# 32/32 [==============================] - 0s 6ms/step - loss: 106.2795 - val_loss: 82.1113
# Epoch 111/200
# 32/32 [==============================] - 0s 5ms/step - loss: 106.5106 - val_loss: 80.1890
# Epoch 112/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.7011 - val_loss: 80.4968
# Epoch 113/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.7065 - val_loss: 80.9959
# Epoch 114/200
# 32/32 [==============================] - 0s 6ms/step - loss: 106.3247 - val_loss: 81.4268
# Epoch 115/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.0344 - val_loss: 80.1657
# Epoch 116/200
# 32/32 [==============================] - 0s 6ms/step - loss: 105.0839 - val_loss: 80.5136
# Epoch 117/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.5348 - val_loss: 80.3645
# Epoch 118/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.4465 - val_loss: 81.1093
# Epoch 119/200
# 32/32 [==============================] - 0s 4ms/step - loss: 105.6812 - val_loss: 80.4402
# Epoch 120/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.1429 - val_loss: 81.7024
# Epoch 121/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.0314 - val_loss: 80.8895
# Epoch 122/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.3476 - val_loss: 81.0427
# Epoch 123/200
# 32/32 [==============================] - 0s 6ms/step - loss: 106.2271 - val_loss: 80.2037
# Epoch 124/200
# 32/32 [==============================] - 0s 6ms/step - loss: 106.5106 - val_loss: 80.3792
# Epoch 125/200
# 32/32 [==============================] - 0s 6ms/step - loss: 105.4370 - val_loss: 81.8800
# Epoch 126/200
# 32/32 [==============================] - 0s 6ms/step - loss: 106.3503 - val_loss: 82.1017
# Epoch 127/200
# 32/32 [==============================] - 0s 6ms/step - loss: 105.9440 - val_loss: 79.9270
# Epoch 128/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.3361 - val_loss: 80.4127
# Epoch 129/200
# 32/32 [==============================] - 0s 6ms/step - loss: 105.7037 - val_loss: 81.2899
# Epoch 130/200
# 32/32 [==============================] - 0s 6ms/step - loss: 105.1341 - val_loss: 80.7653
# Epoch 131/200
# 32/32 [==============================] - 0s 5ms/step - loss: 106.1036 - val_loss: 80.1240
# Epoch 132/200
# 32/32 [==============================] - 0s 5ms/step - loss: 104.9225 - val_loss: 80.8341
# Epoch 133/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.9042 - val_loss: 81.2979
# Epoch 134/200
# 32/32 [==============================] - 0s 4ms/step - loss: 105.2983 - val_loss: 80.4429
# Epoch 135/200
# 32/32 [==============================] - 0s 6ms/step - loss: 105.7459 - val_loss: 79.7752
# Epoch 136/200
# 32/32 [==============================] - 0s 5ms/step - loss: 104.7770 - val_loss: 80.6322
# Epoch 137/200
# 32/32 [==============================] - 0s 6ms/step - loss: 105.5336 - val_loss: 81.7071
# Epoch 138/200
# 32/32 [==============================] - 0s 6ms/step - loss: 106.6851 - val_loss: 79.9557
# Epoch 139/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.6622 - val_loss: 82.3547
# Epoch 140/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.3526 - val_loss: 80.7936
# Epoch 141/200
# 32/32 [==============================] - 0s 6ms/step - loss: 105.2592 - val_loss: 79.7178
# Epoch 142/200
# 32/32 [==============================] - 0s 5ms/step - loss: 107.3737 - val_loss: 82.1722
# Epoch 143/200
# 32/32 [==============================] - 0s 6ms/step - loss: 104.5392 - val_loss: 79.7867
# Epoch 144/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.8636 - val_loss: 80.1610
# Epoch 145/200
# 32/32 [==============================] - 0s 5ms/step - loss: 106.0188 - val_loss: 80.5118
# Epoch 146/200
# 32/32 [==============================] - 0s 5ms/step - loss: 106.1963 - val_loss: 81.6964
# Epoch 147/200
# 32/32 [==============================] - 0s 5ms/step - loss: 106.3018 - val_loss: 79.8616
# Epoch 148/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.2032 - val_loss: 80.7128
# Epoch 149/200
# 32/32 [==============================] - 0s 5ms/step - loss: 106.2815 - val_loss: 80.6353
# Epoch 150/200
# 32/32 [==============================] - 0s 6ms/step - loss: 105.0054 - val_loss: 79.7899
# Epoch 151/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.2850 - val_loss: 80.3193
# Epoch 152/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.4014 - val_loss: 81.1238
# Epoch 153/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.7953 - val_loss: 80.2261
# Epoch 154/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.0374 - val_loss: 80.2332
# Epoch 155/200
# 32/32 [==============================] - 0s 6ms/step - loss: 105.2067 - val_loss: 80.6574
# Epoch 156/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.8243 - val_loss: 80.3411
# Epoch 157/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.6366 - val_loss: 80.4045
# Epoch 158/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.2187 - val_loss: 81.0926
# Epoch 159/200
# 32/32 [==============================] - 0s 6ms/step - loss: 105.9887 - val_loss: 80.0414
# Epoch 160/200
# 32/32 [==============================] - 0s 4ms/step - loss: 107.0394 - val_loss: 81.0111
# Epoch 161/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.6278 - val_loss: 80.0357
# Epoch 162/200
# 32/32 [==============================] - 0s 6ms/step - loss: 105.3902 - val_loss: 80.6980
# Epoch 163/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.6307 - val_loss: 80.3130
# Epoch 164/200
# 32/32 [==============================] - 0s 5ms/step - loss: 106.3332 - val_loss: 81.0710
# Epoch 165/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.3836 - val_loss: 79.8218
# Epoch 166/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.8428 - val_loss: 80.3358
# Epoch 167/200
# 32/32 [==============================] - 0s 5ms/step - loss: 104.8600 - val_loss: 80.8622
# Epoch 168/200
# 32/32 [==============================] - 0s 5ms/step - loss: 106.9057 - val_loss: 80.6340
# Epoch 169/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.4480 - val_loss: 80.3299
# Epoch 170/200
# 32/32 [==============================] - 0s 5ms/step - loss: 107.2919 - val_loss: 80.0704
# Epoch 171/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.2159 - val_loss: 79.4824
# Epoch 172/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.7980 - val_loss: 80.0452
# Epoch 173/200
# 32/32 [==============================] - 0s 5ms/step - loss: 104.9712 - val_loss: 80.4427
# Epoch 174/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.2471 - val_loss: 79.9262
# Epoch 175/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.0683 - val_loss: 81.6314
# Epoch 176/200
# 32/32 [==============================] - 0s 5ms/step - loss: 106.4657 - val_loss: 80.1316
# Epoch 177/200
# 32/32 [==============================] - 0s 6ms/step - loss: 108.4272 - val_loss: 81.3554
# Epoch 178/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.6111 - val_loss: 79.5567
# Epoch 179/200
# 32/32 [==============================] - 0s 5ms/step - loss: 104.9016 - val_loss: 80.4170
# Epoch 180/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.1522 - val_loss: 80.4377
# Epoch 181/200
# 32/32 [==============================] - 0s 5ms/step - loss: 106.0671 - val_loss: 80.8000
# Epoch 182/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.2565 - val_loss: 80.5718
# Epoch 183/200
# 32/32 [==============================] - 0s 6ms/step - loss: 105.7978 - val_loss: 80.5499
# Epoch 184/200
# 32/32 [==============================] - 0s 5ms/step - loss: 106.6254 - val_loss: 79.9798
# Epoch 185/200
# 32/32 [==============================] - 0s 6ms/step - loss: 104.8498 - val_loss: 80.5668
# Epoch 186/200
# 32/32 [==============================] - 0s 6ms/step - loss: 105.7082 - val_loss: 80.6320
# Epoch 187/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.4721 - val_loss: 80.1326
# Epoch 188/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.1993 - val_loss: 80.5004
# Epoch 189/200
# 32/32 [==============================] - 0s 6ms/step - loss: 105.3780 - val_loss: 80.1488
# Epoch 190/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.6649 - val_loss: 79.9338
# Epoch 191/200
# 32/32 [==============================] - 0s 6ms/step - loss: 105.6833 - val_loss: 81.3782
# Epoch 192/200
# 32/32 [==============================] - 0s 6ms/step - loss: 107.2239 - val_loss: 80.1105
# Epoch 193/200
# 32/32 [==============================] - 0s 5ms/step - loss: 106.4151 - val_loss: 81.5094
# Epoch 194/200
# 32/32 [==============================] - 0s 6ms/step - loss: 105.8115 - val_loss: 81.8943
# Epoch 195/200
# 32/32 [==============================] - 0s 5ms/step - loss: 107.3092 - val_loss: 80.7127
# Epoch 196/200
# 32/32 [==============================] - 0s 5ms/step - loss: 106.4334 - val_loss: 79.7661
# Epoch 197/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.4714 - val_loss: 81.0606
# Epoch 198/200
# 32/32 [==============================] - 0s 5ms/step - loss: 106.2363 - val_loss: 80.1263
# Epoch 199/200
# 32/32 [==============================] - 0s 5ms/step - loss: 106.6609 - val_loss: 80.6095
# Epoch 200/200
# 32/32 [==============================] - 0s 6ms/step - loss: 104.8661 - val_loss: 79.7171

# %% [markdown]
# ## Model evaluation

# %%
# model.evaluate(x_test, y_test)
loss = model.evaluate(x_test, y_test)

# 繪製訓練歷史
plt.plot(history.history['loss'], label='Training loss')
plt.plot(history.history['val_loss'], label='Validation loss')
plt.legend()
plt.show()
# Out:
# 1/1 [==============================] - 0s 71ms/step - loss: 114.1879

# %%
def plot_scatter (x, y, title, x_label, y_label,n):
    # plt.subplot(2, 2, n);
    plt.figure(figsize=(5, 5));
    plt.plot(x, x, color="blue", label="d")
    plt.scatter(x, y, marker="x", color="red")
    # plt.axis((0,210, 0,210))
    plt.title(title)
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.show()

y_pred = model.predict(x_test)
plot_scatter(y_test, y_pred, "Testing set", "True value", "Pred. value",1)

y_pred = model.predict(x_train)
plot_scatter(y_train, y_pred, "Training set", "True value", "Pred. value",2)
# Out:
# 1/1 [==============================] - 0s 236ms/step
# 3/3 [==============================] - 0s 5ms/step

# %%
y_pred = model.predict(x_train)
plt.scatter(x_train, y_train, color='red', label='Actual values')
plt.scatter(x_train, y_pred, color='blue', marker='x', label='Predicted values')
plt.title('training set')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()


# 使用模型进行预测
y_pred = model.predict(x_test)
# 可视化真实值与预测值
plt.scatter(x_test, y_test, color='red', label='Actual values')
plt.scatter(x_test, y_pred, color='blue', marker='x', label='Predicted values')
plt.title('testing set')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()
# Out:
# 3/3 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 54ms/step

# %% [markdown]
# ## Exercise : Please try to write R2 and Pearson correlation function for evaluating the training model

# %% [markdown]
# ### Coefficient of determination, denoted R2
# R2值衡量的是模型解釋的"變異"量相對於總變異量的比例。R2=1意味著模型完美地擬合了數據，能夠解釋所有的變異性；而R2=0代表著模型沒有解釋任何變異量，即它未能捕捉到y和y^之間的任何關係，意味著線性模型沒有提供超越基線模型（即常數模型，這個模型預測的 y 值對於所有觀察值都是 y 的平均值）的預測能力預測能力
#
# ![image.png](attachment:380e4a82-09f5-4844-8532-a86e33d816df.png)
#
# Reference :
#
# https://en.wikipedia.org/wiki/Coefficient_of_determination
#
# https://www.ncl.ac.uk/webtemplate/ask-assets/external/maths-resources/statistics/regression-and-correlation/coefficient-of-determination-r-squared.html

# %%
from sklearn.metrics import r2_score
y_pred = model.predict(x_test)
r2_test = r2_score(y_test, y_pred)

y_pred = model.predict(x_train)
r2_train = r2_score(y_train, y_pred)

print(r2_train, r2_test)
# Out:
# 1/1 [==============================] - 0s 71ms/step
# 3/3 [==============================] - 0s 5ms/step
# 0.8979495819449116 0.7847300380316833

# %% [markdown]
# ### Pearson correlation function
# Pearson相關係數衡量兩個變數之間線性"關係"的強度。它的值介於-1到1之間，其中-1表示完全負線性相關，0表示無相關，+1表示完全正線性相關。
#
# ![image.png](attachment:891bbceb-b815-4fd3-af18-067c0046a1a3.png)

# %% [markdown]
# 餘弦相似度的定義是兩個向量的點積除以這兩個向量模的乘積：
#
# ![image.png](attachment:533369cc-d3bb-4647-b383-0cd3fcd26886.png)
# ​

# %%
from sklearn.datasets import make_regression
from sklearn.feature_selection import r_regression
y_pred = model.predict(x_test)
psc_test = r_regression(y_test.reshape(-1, 1), y_pred.ravel())[0]

y_pred = model.predict(x_train)
psc_train = r_regression(y_train.reshape(-1, 1), y_pred.ravel())[0]
print(psc_test, psc_train)
# Out:
# 1/1 [==============================] - 0s 67ms/step
# 3/3 [==============================] - 0s 5ms/step
# 0.9453592343693343 0.9477322466261232

# %% [markdown]
# ### r_regression(X,y) 說明
# X : {array-like, sparse matrix} of shape (n_samples, n_features)
#
# y : array-like of shape (n_samples,)
#
# .ravel() : 將任何形狀的陣列轉換成一維陣列
#
# .reshape(-1, 1) : 將陣列轉換成二維陣列
