# %% [markdown]
# ## Data Preparation

# %%
# install scikit-learn, tensorflow, pandas, matplotlib, numpy
# Out:
# 'conda' 不是內部或外部命令、可執行的程式或批次檔。

# %%
import pandas as pd

output_path = './F_Energy.csv'
path = output_path
df = pd.read_csv(output_path)
display(df.head())
# Out:
#   Pretty Formula   Density      Energy  Energy_per_Atom      Volume  \
# 0          B13C2  2.438648 -106.358032        -7.090535  112.056191
# 1           SiB3  2.449974 -204.992906        -6.406028  328.145035
# 2           SnB6  4.110240  -42.852113        -6.121730   74.164800
# 3           B6Pb  6.003820  -42.968600        -6.138371   75.248129
# 4             BN  3.302143  -68.876677        -8.609585   49.920018
#
#    Formation_Energy_per_Atom  Band Gap
# 0                  -0.072416    0.0089
# 1                  -0.040804    1.4083
# 2                   0.175492    0.7527
# 3                   0.114862    0.9209
# 4                  -1.294085    4.7885

# %%
df.info()
df.describe(include='all').round(2)

#round 函数在 Python（包括 Pandas 库中）的功能是对浮点数进行四舍五入到给定的精度。
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 194 entries, 0 to 193
# Data columns (total 7 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Pretty Formula             194 non-null    object
#  1   Density                    194 non-null    float64
#  2   Energy                     194 non-null    float64
#  3   Energy_per_Atom            194 non-null    float64
#  4   Volume                     194 non-null    float64
#  5   Formation_Energy_per_Atom  194 non-null    float64
#  6   Band Gap                   194 non-null    float64
# dtypes: float64(6), object(1)
# memory usage: 10.7+ KB
#        Pretty Formula  Density  Energy  Energy_per_Atom   Volume  \
# count             194   194.00  194.00           194.00   194.00
# unique            194      NaN     NaN              NaN      NaN
# top             B13C2      NaN     NaN              NaN      NaN
# freq                1      NaN     NaN              NaN      NaN
# mean              NaN     4.01 -102.56            -4.38   617.60
# std               NaN     1.84  134.24             1.50   867.71
# min               NaN     0.14 -787.96            -8.61    27.98
# 25%               NaN     2.60 -117.10            -5.29   147.24
# 50%               NaN     3.85  -54.00            -4.17   334.98
# 75%               NaN     5.07  -24.22            -3.18   720.48
# max               NaN     9.90   -4.03            -1.34  5834.92
#
#         Formation_Energy_per_Atom  Band Gap
# count                      194.00    194.00
# unique                        NaN       NaN
# top                           NaN       NaN
# freq                          NaN       NaN
# mean                        -0.65      1.96
# std                          0.94      1.54
# min                         -3.89      0.00
# 25%                         -1.12      0.80
# 50%                         -0.44      1.74
# 75%                         -0.07      2.85
# max                          1.88      7.72

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

y= df['Formation_Energy_per_Atom']
x= df.drop(columns=['Energy','Formation_Energy_per_Atom','Volume','Pretty Formula'])
display(x.head(5))
# print(set(x), set(y))

# splitting dataset to training set and testing set 
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=200)
# Out:
#     Density  Energy_per_Atom  Band Gap
# 0  2.438648        -7.090535    0.0089
# 1  2.449974        -6.406028    1.4083
# 2  4.110240        -6.121730    0.7527
# 3  6.003820        -6.138371    0.9209
# 4  3.302143        -8.609585    4.7885

# %% [markdown]
# ##  data visualization

# %%
import matplotlib.pyplot as plt
plt.scatter(x_train['Density'], y_train, color='blue', label='Training data')
plt.scatter(x_test['Density'], y_test, color='red', label='Testing data')
plt.legend()
plt.show()

# %%
# Visualizing data before and after scaling with a pair plot
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(8, 8));
sns.pairplot(data=df)
plt.suptitle('Pair Plot of Diabetes Dataset Before and After Scaling', y=1.02, fontsize=18);
plt.show();
# Out:
# C:\Users\m9230\anaconda3\envs\NYCU_py39_2024_02\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\m9230\anaconda3\envs\NYCU_py39_2024_02\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\m9230\anaconda3\envs\NYCU_py39_2024_02\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\m9230\anaconda3\envs\NYCU_py39_2024_02\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\m9230\anaconda3\envs\NYCU_py39_2024_02\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\m9230\anaconda3\envs\NYCU_py39_2024_02\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ## ==================================================================================================================
# ##　Data scaling
# https://www.cupoy.com/collection/0000018008CD5D70000000046375706F795F72656C656173654355/00000181709BCC8F000000056375706F795F72656C656173654349
# https://medium.com/@hhuseyincosgun/which-data-scaling-technique-should-i-use-a1615292061e
#
# Normalization (MinMaxScaler) :
# <br>
# <img src="https://miro.medium.com/v2/resize:fit:996/format:webp/1*gxth9npBXCrHDYbw9XJGrQ.png" width="20%" height="auto">
# <br>
#
# Standardization (Z-Score Standardization) : uses mean and standard deviation
# <br>
# <img src="https://miro.medium.com/v2/resize:fit:1400/format:webp/1*mViMXFWPqg7Vg2WwjaoKVQ.png" width="300" height="auto">
# <br>
#
# RobustScaler : uses median and interquartile range (IQR) instead
# <br>
# <img src="https://miro.medium.com/v2/resize:fit:1348/format:webp/1*uoQxqnwptSNabGU_JL3oPA.png" width="30%" height="auto">
# <br>
#
#
# <img src="https://miro.medium.com/v2/resize:fit:1400/format:webp/1*y0esOCH8O2NV1c_8iY3ouA.png" width="1200" height="auto">
# <br>
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/1/1a/Boxplot_vs_PDF.svg/440px-Boxplot_vs_PDF.svg.png" width="600" height="auto">
# <br>
# InterQuartile Range (四分位距 = 第三四分位數 - 第一四分位數) :
#
# [link to wiki](https://zh.wikipedia.org/zh-tw/%E5%9B%9B%E5%88%86%E4%BD%8D%E6%95%B0)
# <br>
#
# ### 中位數的重要性和應用 :
# 中位數是描述數據集中趨勢的一個非常有用的統計量，特別是當數據集中包含異常值（極端值）時。與平均值相比，中位數不易受到極端值的影響，因此在有異常值的數據集中提供了更穩定的“中心”測量。例如，在房價分析、收入分析等領域，使用中位數可以提供比平均值更真實的市場情況反映，因為這些領域常常受到極高或極低數據點的影響。

# %%
import numpy as np
from sklearn.preprocessing import StandardScaler

scaler_x = StandardScaler()
x_scaled = scaler_x.fit_transform(x_train)

# 如果你也想標準化目標變量
# scaler_y = StandardScaler()
# Y_train_scaled = scaler_y.fit_transform(y_train.reshape(-1, 1))

# x_train, x_test, y_train, y_test = train_test_split(X_scaler, y, test_size=0.2, random_state=200)

# %% [markdown]
# ## Build ANN model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam

# model = Sequential([
    # Dense(1, input_shape=(1,), activation='linear')
#     Dense(5, input_shape=(x.shape[1],), activation='linear')
# ])

model = Sequential([
    Dense(5, input_shape=(x.shape[1],), activation='relu'),
    Dense(3, activation='relu'),
    Dense(1, activation='linear')
])

# Sequential.help

model.compile(optimizer=Adam(learning_rate=0.005), loss='mse')

# %% [markdown]
# ## Training ANN model

# %%
from tensorflow.keras.callbacks import EarlyStopping

# early_stop = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

# history = model.fit(x_train, y_train, validation_split=0.2, epochs=200, batch_size=2)
history = model.fit(x_scaled, y_train, validation_split=0.2, epochs=200, batch_size=2)
# Out:
# Epoch 1/200
# 62/62 [==============================] - 1s 7ms/step - loss: 1.1869 - val_loss: 0.7156
# Epoch 2/200
# 62/62 [==============================] - 0s 4ms/step - loss: 1.0475 - val_loss: 0.6681
# Epoch 3/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.9671 - val_loss: 0.6368
# Epoch 4/200
# 62/62 [==============================] - 0s 3ms/step - loss: 0.9265 - val_loss: 0.6229
# Epoch 5/200
# 62/62 [==============================] - 0s 3ms/step - loss: 0.8967 - val_loss: 0.6058
# Epoch 6/200
# 62/62 [==============================] - 0s 3ms/step - loss: 0.8624 - val_loss: 0.5734
# Epoch 7/200
# 62/62 [==============================] - 0s 3ms/step - loss: 0.8251 - val_loss: 0.5293
# Epoch 8/200
# 62/62 [==============================] - 0s 3ms/step - loss: 0.7690 - val_loss: 0.3825
# Epoch 9/200
# 62/62 [==============================] - 0s 3ms/step - loss: 0.5790 - val_loss: 0.2543
# Epoch 10/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.5002 - val_loss: 0.2619
# Epoch 11/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.4657 - val_loss: 0.2513
# Epoch 12/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.4566 - val_loss: 0.2460
# Epoch 13/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.4486 - val_loss: 0.2503
# Epoch 14/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.4393 - val_loss: 0.2499
# Epoch 15/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.4367 - val_loss: 0.2554
# Epoch 16/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.4310 - val_loss: 0.2495
# Epoch 17/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.4363 - val_loss: 0.2517
# Epoch 18/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.4307 - val_loss: 0.2445
# Epoch 19/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.4256 - val_loss: 0.2444
# Epoch 20/200
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4245 - val_loss: 0.2461
# Epoch 21/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.4338 - val_loss: 0.2392
# Epoch 22/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.4295 - val_loss: 0.2371
# Epoch 23/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.4239 - val_loss: 0.2409
# Epoch 24/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.4216 - val_loss: 0.2591
# Epoch 25/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.4148 - val_loss: 0.2491
# Epoch 26/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.4223 - val_loss: 0.2485
# Epoch 27/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.4120 - val_loss: 0.2439
# Epoch 28/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.4131 - val_loss: 0.2521
# Epoch 29/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.4219 - val_loss: 0.2478
# Epoch 30/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.4201 - val_loss: 0.2638
# Epoch 31/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.4203 - val_loss: 0.2633
# Epoch 32/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.4217 - val_loss: 0.2389
# Epoch 33/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.4122 - val_loss: 0.2515
# Epoch 34/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.4152 - val_loss: 0.2500
# Epoch 35/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.4108 - val_loss: 0.2657
# Epoch 36/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.4119 - val_loss: 0.2524
# Epoch 37/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.4127 - val_loss: 0.2424
# Epoch 38/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.4018 - val_loss: 0.2751
# Epoch 39/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.4078 - val_loss: 0.2613
# Epoch 40/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.4051 - val_loss: 0.2707
# Epoch 41/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.4005 - val_loss: 0.2508
# Epoch 42/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.4040 - val_loss: 0.2661
# Epoch 43/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3996 - val_loss: 0.2547
# Epoch 44/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.4006 - val_loss: 0.2808
# Epoch 45/200
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4049 - val_loss: 0.2747
# Epoch 46/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4080 - val_loss: 0.2653
# Epoch 47/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.4115 - val_loss: 0.2869
# Epoch 48/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.4031 - val_loss: 0.2623
# Epoch 49/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.4066 - val_loss: 0.2681
# Epoch 50/200
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3954 - val_loss: 0.2579
# Epoch 51/200
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3982 - val_loss: 0.2583
# Epoch 52/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3984 - val_loss: 0.2583
# Epoch 53/200
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4028 - val_loss: 0.2568
# Epoch 54/200
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3999 - val_loss: 0.2487
# Epoch 55/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3927 - val_loss: 0.2659
# Epoch 56/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3971 - val_loss: 0.2686
# Epoch 57/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.4049 - val_loss: 0.2442
# Epoch 58/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3998 - val_loss: 0.2459
# Epoch 59/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3900 - val_loss: 0.2482
# Epoch 60/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3904 - val_loss: 0.2544
# Epoch 61/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3898 - val_loss: 0.2744
# Epoch 62/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3968 - val_loss: 0.2660
# Epoch 63/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3930 - val_loss: 0.2612
# Epoch 64/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3803 - val_loss: 0.2573
# Epoch 65/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3909 - val_loss: 0.2695
# Epoch 66/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3890 - val_loss: 0.2649
# Epoch 67/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3853 - val_loss: 0.2697
# Epoch 68/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3856 - val_loss: 0.2679
# Epoch 69/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3853 - val_loss: 0.2602
# Epoch 70/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3910 - val_loss: 0.2594
# Epoch 71/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3813 - val_loss: 0.2610
# Epoch 72/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3905 - val_loss: 0.2497
# Epoch 73/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3843 - val_loss: 0.2620
# Epoch 74/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3967 - val_loss: 0.2614
# Epoch 75/200
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3855 - val_loss: 0.2885
# Epoch 76/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3850 - val_loss: 0.2732
# Epoch 77/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3904 - val_loss: 0.2638
# Epoch 78/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3874 - val_loss: 0.2719
# Epoch 79/200
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3854 - val_loss: 0.2642
# Epoch 80/200
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3863 - val_loss: 0.2507
# Epoch 81/200
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3896 - val_loss: 0.2534
# Epoch 82/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3796 - val_loss: 0.2556
# Epoch 83/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3874 - val_loss: 0.2490
# Epoch 84/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3803 - val_loss: 0.2673
# Epoch 85/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3803 - val_loss: 0.2668
# Epoch 86/200
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3878 - val_loss: 0.2475
# Epoch 87/200
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3780 - val_loss: 0.2607
# Epoch 88/200
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3973 - val_loss: 0.2609
# Epoch 89/200
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3973 - val_loss: 0.2570
# Epoch 90/200
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3783 - val_loss: 0.2939
# Epoch 91/200
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3900 - val_loss: 0.2638
# Epoch 92/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3878 - val_loss: 0.2530
# Epoch 93/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3825 - val_loss: 0.2858
# Epoch 94/200
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3855 - val_loss: 0.2592
# Epoch 95/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3851 - val_loss: 0.2727
# Epoch 96/200
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3837 - val_loss: 0.2630
# Epoch 97/200
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3763 - val_loss: 0.2610
# Epoch 98/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3854 - val_loss: 0.2800
# Epoch 99/200
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3800 - val_loss: 0.2724
# Epoch 100/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3847 - val_loss: 0.2700
# Epoch 101/200
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3867 - val_loss: 0.2579
# Epoch 102/200
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3763 - val_loss: 0.2785
# Epoch 103/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3794 - val_loss: 0.2792
# Epoch 104/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3830 - val_loss: 0.2710
# Epoch 105/200
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3772 - val_loss: 0.2772
# Epoch 106/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3871 - val_loss: 0.2643
# Epoch 107/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3791 - val_loss: 0.2739
# Epoch 108/200
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3732 - val_loss: 0.2610
# Epoch 109/200
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3790 - val_loss: 0.2794
# Epoch 110/200
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3781 - val_loss: 0.2935
# Epoch 111/200
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3742 - val_loss: 0.2937
# Epoch 112/200
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3837 - val_loss: 0.2672
# Epoch 113/200
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3855 - val_loss: 0.2819
# Epoch 114/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3733 - val_loss: 0.2943
# Epoch 115/200
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3779 - val_loss: 0.2790
# Epoch 116/200
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3751 - val_loss: 0.2948
# Epoch 117/200
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3874 - val_loss: 0.2680
# Epoch 118/200
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3844 - val_loss: 0.2682
# Epoch 119/200
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3793 - val_loss: 0.3037
# Epoch 120/200
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3834 - val_loss: 0.2575
# Epoch 121/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3844 - val_loss: 0.2797
# Epoch 122/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3861 - val_loss: 0.2606
# Epoch 123/200
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3775 - val_loss: 0.3138
# Epoch 124/200
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3952 - val_loss: 0.2821
# Epoch 125/200
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3814 - val_loss: 0.2671
# Epoch 126/200
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3850 - val_loss: 0.2701
# Epoch 127/200
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3881 - val_loss: 0.2662
# Epoch 128/200
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3751 - val_loss: 0.3039
# Epoch 129/200
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3825 - val_loss: 0.2863
# Epoch 130/200
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3847 - val_loss: 0.2855
# Epoch 131/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3794 - val_loss: 0.2862
# Epoch 132/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3757 - val_loss: 0.2785
# Epoch 133/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3751 - val_loss: 0.2889
# Epoch 134/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3767 - val_loss: 0.2768
# Epoch 135/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3820 - val_loss: 0.2693
# Epoch 136/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3831 - val_loss: 0.3140
# Epoch 137/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3982 - val_loss: 0.2885
# Epoch 138/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3818 - val_loss: 0.2842
# Epoch 139/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3786 - val_loss: 0.2743
# Epoch 140/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.3807 - val_loss: 0.2723
# Epoch 141/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3772 - val_loss: 0.3066
# Epoch 142/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3969 - val_loss: 0.3039
# Epoch 143/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3889 - val_loss: 0.2726
# Epoch 144/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3865 - val_loss: 0.2717
# Epoch 145/200
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3813 - val_loss: 0.2725
# Epoch 146/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3734 - val_loss: 0.2830
# Epoch 147/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3772 - val_loss: 0.2716
# Epoch 148/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3771 - val_loss: 0.2676
# Epoch 149/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3771 - val_loss: 0.2800
# Epoch 150/200
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3844 - val_loss: 0.2884
# Epoch 151/200
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3756 - val_loss: 0.2525
# Epoch 152/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3765 - val_loss: 0.2896
# Epoch 153/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3836 - val_loss: 0.2782
# Epoch 154/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3794 - val_loss: 0.2693
# Epoch 155/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3800 - val_loss: 0.2747
# Epoch 156/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3789 - val_loss: 0.2736
# Epoch 157/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3724 - val_loss: 0.3349
# Epoch 158/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3733 - val_loss: 0.3051
# Epoch 159/200
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3733 - val_loss: 0.2912
# Epoch 160/200
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3783 - val_loss: 0.2813
# Epoch 161/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3761 - val_loss: 0.2838
# Epoch 162/200
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3774 - val_loss: 0.2873
# Epoch 163/200
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3763 - val_loss: 0.2810
# Epoch 164/200
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3710 - val_loss: 0.3033
# Epoch 165/200
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3797 - val_loss: 0.3163
# Epoch 166/200
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3903 - val_loss: 0.3109
# Epoch 167/200
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3915 - val_loss: 0.2866
# Epoch 168/200
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3916 - val_loss: 0.2925
# Epoch 169/200
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3916 - val_loss: 0.2858
# Epoch 170/200
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3957 - val_loss: 0.2627
# Epoch 171/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.3941 - val_loss: 0.2782
# Epoch 172/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3965 - val_loss: 0.2720
# Epoch 173/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.4145 - val_loss: 0.2670
# Epoch 174/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3925 - val_loss: 0.2737
# Epoch 175/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3995 - val_loss: 0.2741
# Epoch 176/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3843 - val_loss: 0.2864
# Epoch 177/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3916 - val_loss: 0.3110
# Epoch 178/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3850 - val_loss: 0.2595
# Epoch 179/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3894 - val_loss: 0.2785
# Epoch 180/200
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3775 - val_loss: 0.2760
# Epoch 181/200
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3844 - val_loss: 0.2793
# Epoch 182/200
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3829 - val_loss: 0.3302
# Epoch 183/200
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3808 - val_loss: 0.2857
# Epoch 184/200
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3735 - val_loss: 0.2650
# Epoch 185/200
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3799 - val_loss: 0.2735
# Epoch 186/200
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3750 - val_loss: 0.2721
# Epoch 187/200
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3802 - val_loss: 0.2880
# Epoch 188/200
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3765 - val_loss: 0.2887
# Epoch 189/200
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3834 - val_loss: 0.2857
# Epoch 190/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3732 - val_loss: 0.3018
# Epoch 191/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3716 - val_loss: 0.3028
# Epoch 192/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3790 - val_loss: 0.2993
# Epoch 193/200
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3788 - val_loss: 0.3072
# Epoch 194/200
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3936 - val_loss: 0.2951
# Epoch 195/200
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3906 - val_loss: 0.2957
# Epoch 196/200
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3940 - val_loss: 0.2872
# Epoch 197/200
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4034 - val_loss: 0.2812
# Epoch 198/200
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3984 - val_loss: 0.2849
# Epoch 199/200
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3945 - val_loss: 0.2924
# Epoch 200/200
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3847 - val_loss: 0.2961

# %% [markdown]
# ## Model evaluation

# %%
history.history['loss'][:10]
# Out:
# [1.1868919134140015,
#  1.0475345849990845,
#  0.967083752155304,
#  0.9264824390411377,
#  0.896681010723114,
#  0.8623725175857544,
#  0.8251017332077026,
#  0.7689856886863708,
#  0.579047679901123,
#  0.5002263784408569]

# %%
# model.evaluate(x_test, y_test)
loss = model.evaluate(x_test, y_test)

# 绘制训练历史
plt.plot(history.history['loss'][10:], label='Training loss')
plt.plot(history.history['val_loss'][10:], label='Validation loss')
plt.legend()
plt.show()
# Out:
# 2/2 [==============================] - 0s 5ms/step - loss: 2.7120

# %%
def plot_scatter (x, y, title, x_label, y_label,n):
    # plt.subplot(2, 2, n);
    plt.figure(figsize=(5, 5));
    plt.plot(x, x, color="blue", label="d")
    plt.scatter(x, y, marker="x", color="red")
    # plt.axis((0,210, 0,210))
    plt.title(title)
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.show()
    

# y_pred = model.predict(x_test)
# plot_scatter(y_test, y_pred, "Testing set", "True value", "Pred. value",1)

# y_pred = model.predict(x_train)
# plot_scatter(y_train, y_pred, "Training set", "True value", "Pred. value",2)

def pred(scaler_x, x):
    x_scaled = scaler_x.fit_transform(x)
    return model.predict(x_scaled)
    
from sklearn.metrics import r2_score

# y_pred計算前，input需先sacling。
y_pred = pred(scaler_x, x_test)
plot_scatter(y_test, y_pred, "Testing set", "True value", "Pred. value",1)
r2_test = r2_score(y_test, y_pred)
psc_test = r_regression(y_test.to_numpy().reshape(-1, 1) , y_pred.ravel())[0]

y_pred = pred(scaler_x, x_train)
plot_scatter(y_train, y_pred, "Testing set", "True value", "Pred. value",1)
r2_train = r2_score(y_train, y_pred)
psc_train = r_regression(y_train.to_numpy().reshape(-1, 1), y_pred.ravel())[0]

## Pearson correlation function
from sklearn.datasets import make_regression
from sklearn.feature_selection import r_regression


## Coefficient of determination, denoted R2
print(f"R2={r2_train, r2_test}, Pearson={psc_train, psc_test} for training and testing sets")
# Out:
# 2/2 [==============================] - 0s 5ms/step
# 5/5 [==============================] - 0s 3ms/step
# R2=(0.5718347946062663, 0.5093789938113029), Pearson=(0.7572204993026319, 0.7440065757682582) for training and testing sets

# %%
# y_pred計算前，input需先sacling。
# y_pred = model.predict(x_train)
y_pred = pred(scaler_x, x_train)

plt.scatter(x_train['Density'], y_train, color='red', label='Actual values')
plt.scatter(x_train['Density'], y_pred, color='blue', marker='x', label='Predicted values')
plt.title('training set')
plt.legend()
plt.show()

# y_pred計算前，input需先sacling。
# y_pred = model.predict(x_test)
y_pred = pred(scaler_x, x_test)

plt.scatter(x_test['Density'], y_test, color='red', label='Actual values')
plt.scatter(x_test['Density'], y_pred, color='blue', marker='x', label='Predicted values')
plt.title('testing set')
plt.legend()
plt.show()
# Out:
# 5/5 [==============================] - 0s 3ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step

# %%
# ## Coefficient of determination, denoted R2
# from sklearn.metrics import r2_score
# y_pred = model.predict(x_test)
# r2_test = r2_score(y_test, y_pred)

# y_pred = model.predict(x_train)
# r2_train = r2_score(y_train, y_pred)

# print(r2_train, r2_test)
# Out:
# 2/2 [==============================] - 0s 4ms/step
# 5/5 [==============================] - 0s 2ms/step
# -0.2401081388470787 -0.26571370296064356

# %%
# ## Pearson correlation function
# from sklearn.datasets import make_regression
# from sklearn.feature_selection import r_regression

# y_pred = model.predict(x_test)
# psc_test = r_regression(y_test.to_numpy().reshape(-1, 1) , y_pred.ravel())[0]
# y_pred = model.predict(x_train)
# psc_train = r_regression(y_train.to_numpy().reshape(-1, 1), y_pred.ravel())[0]
# print(psc_test, psc_train)
# Out:
# 2/2 [==============================] - 0s 4ms/step
# 5/5 [==============================] - 0s 3ms/step
# 0.26317809109081114 0.4475416492147637
