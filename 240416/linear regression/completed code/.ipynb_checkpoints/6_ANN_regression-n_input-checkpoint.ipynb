# %% [markdown]
# ## Data Preparation

# %%
# install scikit-learn, tensorflow, pandas, matplotlib, numpy
# Out:
# 'conda' 不是內部或外部命令、可執行的程式或批次檔。

# %%
# # download the data
import wget
url = "https://raw.githubusercontent.com/waccoco/2024_NCTU_MI_course/master/Dataset/Salary_Data2.csv"
output_path = './Salary_Data2.csv'
wget.download(url, out=output_path)
# Out:
# 100% [................................................................................] 1040 / 1040
# './Salary_Data2 (1).csv'

# %%
import pandas as pd

output_path = './Salary_Data2.csv'
path = output_path
df = pd.read_csv(output_path)
display(df.head())
# Out:
#    YearsExperience EducationLevel City  Salary
# 0              3.0             大學  城市A    45.9
# 1              7.8           碩士以上  城市C    80.5
# 2              2.3           高中以下  城市A    25.2
# 3              5.1           高中以下  城市A    30.4
# 4             10.0           碩士以上  城市B    65.7

# %%
df.info()
df.describe(include='all').round(2)

#round 函数在 Python（包括 Pandas 库中）的功能是对浮点数进行四舍五入到给定的精度。
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  36 non-null     float64
#  1   EducationLevel   36 non-null     object
#  2   City             36 non-null     object
#  3   Salary           36 non-null     float64
# dtypes: float64(2), object(2)
# memory usage: 1.2+ KB
#         YearsExperience EducationLevel City  Salary
# count             36.00             36   36   36.00
# unique              NaN              3    3     NaN
# top                 NaN           碩士以上  城市A     NaN
# freq                NaN             16   20     NaN
# mean               5.47            NaN  NaN   51.70
# std                2.71            NaN  NaN   17.53
# min                1.20            NaN  NaN   24.90
# 25%                3.38            NaN  NaN   38.05
# 50%                5.15            NaN  NaN   49.20
# 75%                7.65            NaN  NaN   65.75
# max               10.00            NaN  NaN   84.20

# %% [markdown]
# ## Transform the Categorical data to numerical data
# ### @ LabelEncoder：把類別型資料轉換成0,1,2,…的數值標籤 (特徵之間有順序或大小分別)
#    ![image.png](attachment:c86e50e9-fb01-44f3-8d23-a9548281d397.png)
#
# ### @ OneHotEncoder：把類別型資料轉換成0與1的數值標籤 (特徵之間沒有順序或大小分別)
# ![image.png](attachment:f9460b51-747e-473b-9324-c386e4bf5edc.png)
#
# ### Exercise : Try to use the one-hot encoder to encode the Categorical data into numerical data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

########################################################
df_encoded = pd.get_dummies(df, columns=['EducationLevel', 'City'])
# 假設df是已經通過get_dummies轉換後的DataFrame，且包含布林值
# 轉換布林值為整數
df_encoded = df_encoded.astype(int)
########################################################

# 顯示轉換後的DataFrame
display(df_encoded.head(5))
# Out:
#    YearsExperience  Salary  EducationLevel_大學  EducationLevel_碩士以上  \
# 0                3      45                  1                    0
# 1                7      80                  0                    1
# 2                2      25                  0                    0
# 3                5      30                  0                    0
# 4               10      65                  0                    1
#
#    EducationLevel_高中以下  City_城市A  City_城市B  City_城市C
# 0                    0         1         0         0
# 1                    0         0         0         1
# 2                    1         1         0         0
# 3                    1         1         0         0
# 4                    0         0         1         0

# %%
# Delete redundant features
########################################################
df_encoded = df_encoded.drop(columns=['EducationLevel_高中以下', 'City_城市C'])
########################################################

df_encoded.to_csv('./encoded.csv')
y= df_encoded['Salary']
x= df_encoded.drop(columns=['Salary'])
display(x.head(5))
# print(set(x), set(y))
# Out:
#    YearsExperience  EducationLevel_大學  EducationLevel_碩士以上  City_城市A  City_城市B
# 0                3                  1                    0         1         0
# 1                7                  0                    1         0         0
# 2                2                  0                    0         1         0
# 3                5                  0                    0         1         0
# 4               10                  0                    1         0         1

# %%
# splitting dataset to training set and testing set 
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=200)

# %% [markdown]
# ##  data visualization

# %%
plt.scatter(x_train['YearsExperience'], y_train, color='blue', label='Training data')
plt.scatter(x_test['YearsExperience'], y_test, color='red', label='Testing data')
plt.legend()
plt.show()

# %% [markdown]
# ## Build ANN model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam

# model = Sequential([
    # Dense(1, input_shape=(1,), activation='linear')
#     Dense(5, input_shape=(x.shape[1],), activation='linear')
# ])

model = Sequential([
    Dense(8, input_shape=(x.shape[1],), activation='relu'),
    Dense(4, activation='relu'),
    Dense(1, activation='linear')
])

# Sequential.help

model.compile(optimizer=Adam(learning_rate=0.005), loss='mse')

# %% [markdown]
# ## Training ANN model

# %%
from tensorflow.keras.callbacks import EarlyStopping

# early_stop = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)
history = model.fit(x_train, y_train, validation_split=0.2, epochs=200, batch_size=2)
# Out:
# Epoch 1/200
# 11/11 [==============================] - 2s 54ms/step - loss: 2581.7744 - val_loss: 4119.8579
# Epoch 2/200
# 11/11 [==============================] - 0s 11ms/step - loss: 2501.7197 - val_loss: 3995.9631
# Epoch 3/200
# 11/11 [==============================] - 0s 10ms/step - loss:
200
# 11/11 [==============================] - 0s 10ms/step - loss: 9.6695 - val_loss: 25.9670
# Epoch 196/200
# 11/11 [==============================] - 0s 10ms/step - loss: 10.2742 - val_loss: 24.3372
# Epoch 197/200
# 11/11 [==============================] - 0s 12ms/step - loss: 9.9146 - val_loss: 26.0235
# Epoch 198/200
# 11/11 [==============================] - 0s 10ms/step - loss: 9.8373 - val_loss: 24.8312
# Epoch 199/200
# 11/11 [==============================] - 0s 7ms/step - loss: 10.5218 - val_loss: 21.8603
# Epoch 200/200
# 11/11 [==============================] - 0s 9ms/step - loss: 10.2220 - val_loss: 26.7178

# %% [markdown]
# ## Model evaluation

# %%
history.history['loss'][:10]
# Out:
# [2581.7744140625,
#  2501.7197265625,
#  2423.726806640625,
#  2306.521484375,
#  2147.6142578125,
#  1941.4559326171875,
#  1677.4827880859375,
#  1389.937255859375,
#  1022.8167724609375,
#  700.7117919921875]

# %%
# model.evaluate(x_test, y_test)
loss = model.evaluate(x_test, y_test)

# 繪製訓練歷史
plt.plot(history.history['loss'][10:], label='Training loss')
plt.plot(history.history['val_loss'][10:], label='Validation loss')
plt.legend()
plt.show()
# Out:
# 1/1 [==============================] - 0s 340ms/step - loss: 32.1430

# %%
def plot_scatter (x, y, title, x_label, y_label,n):
    # plt.subplot(2, 2, n);
    plt.figure(figsize=(5, 5));
    plt.plot(x, x, color="blue", label="d")
    plt.scatter(x, y, marker="x", color="red")
    # plt.axis((0,210, 0,210))
    plt.title(title)
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.show()

y_pred = model.predict(x_test)
plot_scatter(y_test, y_pred, "Testing set", "True value", "Pred. value",1)

y_pred = model.predict(x_train)
plot_scatter(y_train, y_pred, "Training set", "True value", "Pred. value",2)
# Out:
# 1/1 [==============================] - 0s 175ms/step
# 1/1 [==============================] - 0s 67ms/step

# %%
print((y_train))
print(x_train,y_pred)
# Out:
# 3     30
# 0     45
# 35    36
# 24    48
# 18    26
# 8     40
# 5     60
# 21    78
# 29    41
# 22    63
# 31    60
# 9     28
# 19    31
# 7     70
# 1     80
# 10    32
# 6     50
# 11    48
# 28    29
# 30    76
# 27    24
# 14    62
# 25    68
# 15    55
# 12    84
# 4     65
# 16    72
# 26    38
# Name: Salary, dtype: int32
#     YearsExperience  EducationLevel_大學  EducationLevel_碩士以上  City_城市A  \
# 3                 5                  0                    0         1
# 0                 3                  1                    0         1
# 35                4                  1                    0         1
# 24                8                  1                    0         0
# 18                2                  0                    0         1
# 8                 4                  1                    0         1
# 5                 1                  0                    1         0
# 21                7                  0                    1         0
# 29                3                  1                    0         1
# 22               10                  0                    1         0
# 31               10                  0                    1         0
# 9                 2                  0                    0         1
# 19                5                  0                    0         1
# 7                 6                  0                    1         1
# 1                 7                  0                    1         0
# 10                5                  0                    0         1
# 6                 8                  1                    0         0
# 11                3                  1                    0         1
# 28                5                  0                    0         1
# 30                7                  0                    1         0
# 27                2                  0                    0         1
# 14                1                  0                    1         0
# 25                6                  0                    1         1
# 15                8                  1                    0         0
# 12                7                  0                    1         0
# 4                10                  0                    1         0
# 16                6                  0                    1         1
# 26                4                  1                    0         1
#
#     City_城市B
# 3          0
# 0          0
# 35         0
# 24         0
# 18         0
# 8          0
# 5          0
# 21         0
# 29         0
# 22         1
# 31         1
# 9          0
# 19         0
# 7          0
# 1          0
# 10         0
# 6          0
# 11         0
# 28         0
# 30         0
# 27         0
# 14         0
# 25         0
# 15         0
# 12         0
# 4          1
# 16         0
# 26         0   [[30.80136 ]
#  [40.18251 ]
#  [42.021656]
#  [50.285774]
#  [25.272951]
#  [42.021656]
#  [63.55155 ]
#  [74.58642 ]
#  [40.18251 ]
#  [60.69604 ]
#  [60.69604 ]
#  [25.272951]
#  [30.80136 ]
#  [71.83974 ]
#  [74.58642 ]
#  [30.80136 ]
#  [50.285774]
#  [40.18251 ]
#  [30.80136 ]
#  [74.58642 ]
#  [25.272951]
#  [63.55155 ]
#  [71.83974 ]
#  [50.285774]
#  [74.58642 ]
#  [60.69604 ]
#  [71.83974 ]
#  [42.021656]]

# %%
y_pred = model.predict(x_train)
plt.scatter(x_train['YearsExperience'], y_train, color='red', label='Actual values')
plt.scatter(x_train['YearsExperience'], y_pred, color='blue', marker='x', label='Predicted values')
plt.title('training set')
plt.legend()
plt.show()

y_pred = model.predict(x_test)
plt.scatter(x_test['YearsExperience'], y_test, color='red', label='Actual values')
plt.scatter(x_test['YearsExperience'], y_pred, color='blue', marker='x', label='Predicted values')
plt.title('testing set')
plt.legend()
plt.show()
# Out:
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 61ms/step

# %%
## coefficient of determination, denoted R2
from sklearn.metrics import r2_score
y_pred = model.predict(x_test)
r2_test = r2_score(y_test, y_pred)

y_pred = model.predict(x_train)
r2_train = r2_score(y_train, y_pred)

print(r2_train, r2_test)
# Out:
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 64ms/step
# 0.959663983224341 0.826955595157973

# %%
## Pearson correlation function
from sklearn.datasets import make_regression
from sklearn.feature_selection import r_regression

y_pred = model.predict(x_test)
psc_test = r_regression(y_test.to_numpy().reshape(-1, 1) , y_pred.ravel())[0]
y_pred = model.predict(x_train)
psc_train = r_regression(y_train.to_numpy().reshape(-1, 1), y_pred.ravel())[0]
print(psc_test, psc_train)
# Out:
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 56ms/step
# 0.9281169184929442 0.9808791382490734
