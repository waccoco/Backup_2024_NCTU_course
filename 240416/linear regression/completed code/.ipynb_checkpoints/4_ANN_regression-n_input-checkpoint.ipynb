# %% [markdown]
# ## Data Preparation

# %%
# install scikit-learn, tensorflow, pandas, matplotlib, numpy
# Out:
# 'conda' 不是內部或外部命令、可執行的程式或批次檔。

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# randomseed
np.random.seed(0)

# data : y = ax+b
a = 2
b = 1
noise_scale = 10

# data generation
x = np.linspace(0, 50, 100)
q = np.random.normal(0, noise_scale, x.shape)
y = a * x + b + q

# # data : y = a*exp(bx)
# a = 2
# b = 1
# c= 50
# noise_scale = 20

# # data generation
# x = np.linspace(0, 5, 100)
# y = a * np.exp(b * x) + q + c

# splitting dataset to training set and testing set 
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %% [markdown]
# ##  data visualization

# %%
plt.scatter(x_train, y_train, color='blue', label='Training data')
plt.scatter(x_test, y_test, color='red', label='Testing data')
plt.legend()
plt.show()

# %% [markdown]
# ## Build ANN model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam

model = Sequential([
    Dense(1, input_shape=(1,), activation='linear')
])

# model = Sequential([
#     Dense(5, input_shape=(1,), activation='relu'),
#     Dense(3, activation='relu'),
#     Dense(1, activation='linear')
# ])

# Sequential.help

model.compile(optimizer=Adam(learning_rate=0.01), loss='mse')

# %% [markdown]
# ## Training ANN model

# %%
from tensorflow.keras.callbacks import EarlyStopping

early_stop = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)
history = model.fit(x_train, y_train, validation_split=0.2, epochs=200, batch_size=2)
# Out:
# Epoch 1/200
# 32/32 [==============================] - 1s 15ms/step - loss: 9286.0664 - val_loss: 9541.1816
# Epoch 2/200
# 32/32 [==============================] - 0s 6ms/step - loss: 7794.0415 - val_loss: 8016.3184
# Epoch 3/200
# 32/32 [==============================] - 0s 5ms/step - loss: 6485.0776 - val_loss: 6689.1743
# Epoch 4/200
# 32/32 [==============================] - 0s 5ms/step - loss: 5386.8804 - val_loss: 5468.7217
# Epoch 5/200
# 32/32 [==============================] - 0s 6ms/step - loss: 4393.4360 - val_loss: 4519.5200
# Epoch 6/200
# 32/32 [==============================] - 0s 6ms/step - loss: 3589.2598 - val_loss: 3671.8843
# Epoch 7/200
# 32/32 [==============================] - 0s 6ms/step - loss: 2910.3352 - val_loss: 2934.8752
# Epoch 8/200
# 32/32 [==============================] - 0s 5ms/step - loss: 2316.6987 - val_loss: 2381.5322
# Epoch 9/200
# 32/32 [==============================] - 0s 4ms/step - loss: 1856.0089 - val_loss: 1871.0497
# Epoch 10/200
# 32/32 [==============================] - 0s 5ms/step - loss: 1460.1553 - val_loss: 1477.5615
# Epoch 11/200
# 32/32 [==============================] - 0s 5ms/step - loss: 1150.3008 - val_loss: 1151.3879
# Epoch 12/200
# 32/32 [==============================] - 0s 5ms/step - loss: 900.1979 - val_loss: 894.1742
# Epoch 13/200
# 32/32 [==============================] - 0s 5ms/step - loss: 697.5814 - val_loss: 714.1140
# Epoch 14/200
# 32/32 [==============================] - 0s 5ms/step - loss: 552.1674 - val_loss: 542.3806
# Epoch 15/200
# 32/32 [==============================] - 0s 4ms/step - loss: 429.1578 - val_loss: 426.7658
# Epoch 16/200
# 32/32 [==============================] - 0s 5ms/step - loss: 340.0522 - val_loss: 337.9002
# Epoch 17/200
# 32/32 [==============================] - 0s 5ms/step - loss: 272.1302 - val_loss: 272.0250
# Epoch 18/200
# 32/32 [==============================] - 0s 5ms/step - loss: 226.5187 - val_loss: 212.5000
# Epoch 19/200
# 32/32 [==============================] - 0s 6ms/step - loss: 186.7636 - val_loss: 178.9944
# Epoch 20/200
# 32/32 [==============================] - 0s 6ms/step - loss: 162.5068 - val_loss: 150.7501
# Epoch 21/200
# 32/32 [==============================] - 0s 4ms/step - loss: 143.4929 - val_loss: 132.1123
# Epoch 22/200
# 32/32 [==============================] - 0s 4ms/step - loss: 131.0379 - val_loss: 118.1594
# Epoch 23/200
# 32/32 [==============================] - 0s 6ms/step - loss: 122.0094 - val_loss: 108.2518
# Epoch 24/200
# 32/32 [==============================] - 0s 6ms/step - loss: 116.2206 - val_loss: 100.5851
# Epoch 25/200
# 32/32 [==============================] - 0s 6ms/step - loss: 112.2054 - val_loss: 95.3156
# Epoch 26/200
# 32/32 [==============================] - 0s 5ms/step - loss: 109.6593 - val_loss: 92.1316
# Epoch 27/200
# 32/32 [==============================] - 0s 5ms/step - loss: 108.2757 - val_loss: 89.4207
# Epoch 28/200
# 32/32 [==============================] - 0s 6ms/step - loss: 107.1392 - val_loss: 87.5446
# Epoch 29/200
# 32/32 [==============================] - 0s 6ms/step - loss: 106.3927 - val_loss: 86.3734
# Epoch 30/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.8936 - val_loss: 85.5897
# Epoch 31/200
# 32/32 [==============================] - 0s 6ms/step - loss: 105.7188 - val_loss: 85.5815
# Epoch 32/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.5321 - val_loss: 84.6636
# Epoch 33/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.3656 - val_loss: 84.4872
# Epoch 34/200
# 32/32 [==============================] - 0s 6ms/step - loss: 105.4486 - val_loss: 84.5456
# Epoch 35/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.5662 - val_loss: 83.7264
# Epoch 36/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.2677 - val_loss: 83.8571
# Epoch 37/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.2334 - val_loss: 83.7655
# Epoch 38/200
# 32/32 [==============================] - 0s 4ms/step - loss: 105.4936 - val_loss: 83.7613
# Epoch 39/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.3013 - val_loss: 83.9504
# Epoch 40/200
# 32/32 [==============================] - 0s 6ms/step - loss: 105.6190 - val_loss: 83.9543
# Epoch 41/200
# 32/32 [==============================] - 0s 6ms/step - loss: 105.8432 - val_loss: 83.0647
# Epoch 42/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.1638 - val_loss: 83.5047
# Epoch 43/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.3694 - val_loss: 83.3308
# Epoch 44/200
# 32/32 [==============================] - 0s 4ms/step - loss: 105.1754 - val_loss: 83.6785
# Epoch 45/200
# 32/32 [==============================] - 0s 6ms/step - loss: 105.2789 - val_loss: 83.6746
# Epoch 46/200
# 32/32 [==============================] - 0s 6ms/step - loss: 105.2237 - val_loss: 83.2642
# Epoch 47/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.1882 - val_loss: 83.3626
# Epoch 48/200
# 32/32 [==============================] - 0s 6ms/step - loss: 105.2569 - val_loss: 83.4487
# Epoch 49/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.1668 - val_loss: 83.2296
# Epoch 50/200
# 32/32 [==============================] - 0s 6ms/step - loss: 105.4642 - val_loss: 83.0783
# Epoch 51/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.6583 - val_loss: 83.5229
# Epoch 52/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.2845 - val_loss: 83.5486
# Epoch 53/200
# 32/32 [==============================] - 0s 6ms/step - loss: 105.3202 - val_loss: 83.1577
# Epoch 54/200
# 32/32 [==============================] - 0s 6ms/step - loss: 105.2998 - val_loss: 83.4596
# Epoch 55/200
# 32/32 [==============================] - 0s 4ms/step - loss: 105.2141 - val_loss: 83.1385
# Epoch 56/200
# 32/32 [==============================] - 0s 6ms/step - loss: 105.6752 - val_loss: 83.1727
# Epoch 57/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.3245 - val_loss: 83.4008
# Epoch 58/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.4246 - val_loss: 83.5762
# Epoch 59/200
# 32/32 [==============================] - 0s 6ms/step - loss: 105.2078 - val_loss: 83.4063
# Epoch 60/200
# 32/32 [==============================] - 0s 6ms/step - loss: 105.2859 - val_loss: 83.1605
# Epoch 61/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.1762 - val_loss: 83.0793
# Epoch 62/200
# 32/32 [==============================] - 0s 6ms/step - loss: 105.8329 - val_loss: 82.8634
# Epoch 63/200
# 32/32 [==============================] - 0s 6ms/step - loss: 105.2676 - val_loss: 83.5642
# Epoch 64/200
# 32/32 [==============================] - 0s 6ms/step - loss: 105.2303 - val_loss: 83.1811
# Epoch 65/200
# 32/32 [==============================] - 0s 6ms/step - loss: 105.4579 - val_loss: 83.2878
# Epoch 66/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.7891 - val_loss: 83.5283
# Epoch 67/200
# 32/32 [==============================] - 0s 6ms/step - loss: 105.8361 - val_loss: 82.5035
# Epoch 68/200
# 32/32 [==============================] - 0s 6ms/step - loss: 107.1840 - val_loss: 83.2782
# Epoch 69/200
# 32/32 [==============================] - 0s 6ms/step - loss: 105.2970 - val_loss: 83.2448
# Epoch 70/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.1927 - val_loss: 82.7092
# Epoch 71/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.2918 - val_loss: 83.2984
# Epoch 72/200
# 32/32 [==============================] - 0s 6ms/step - loss: 105.9505 - val_loss: 82.4712
# Epoch 73/200
# 32/32 [==============================] - 0s 6ms/step - loss: 105.2785 - val_loss: 83.2327
# Epoch 74/200
# 32/32 [==============================] - 0s 6ms/step - loss: 105.6803 - val_loss: 82.7447
# Epoch 75/200
# 32/32 [==============================] - 0s 6ms/step - loss: 105.1615 - val_loss: 83.0401
# Epoch 76/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.9768 - val_loss: 84.1941
# Epoch 77/200
# 32/32 [==============================] - 0s 4ms/step - loss: 105.1059 - val_loss: 83.0157
# Epoch 78/200
# 32/32 [==============================] - 0s 6ms/step - loss: 105.4501 - val_loss: 83.2522
# Epoch 79/200
# 32/32 [==============================] - 0s 6ms/step - loss: 105.3616 - val_loss: 82.5802
# Epoch 80/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.3760 - val_loss: 83.0255
# Epoch 81/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.7552 - val_loss: 83.5655
# Epoch 82/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.5841 - val_loss: 82.5752
# Epoch 83/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.3285 - val_loss: 83.0363
# Epoch 84/200
# 32/32 [==============================] - 0s 6ms/step - loss: 105.3005 - val_loss: 82.4057
# Epoch 85/200
# 32/32 [==============================] - 0s 6ms/step - loss: 105.3853 - val_loss: 82.9159
# Epoch 86/200
# 32/32 [==============================] - 0s 6ms/step - loss: 105.3154 - val_loss: 82.5063
# Epoch 87/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.5570 - val_loss: 83.3582
# Epoch 88/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.7686 - val_loss: 82.3371
# Epoch 89/200
# 32/32 [==============================] - 0s 6ms/step - loss: 105.2694 - val_loss: 82.8006
# Epoch 90/200
# 32/32 [==============================] - 0s 6ms/step - loss: 105.7647 - val_loss: 82.9212
# Epoch 91/200
# 32/32 [==============================] - 0s 6ms/step - loss: 105.4839 - val_loss: 82.9234
# Epoch 92/200
# 32/32 [==============================] - 0s 6ms/step - loss: 105.9188 - val_loss: 82.0002
# Epoch 93/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.7116 - val_loss: 83.5841
# Epoch 94/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.1484 - val_loss: 82.5626
# Epoch 95/200
# 32/32 [==============================] - 0s 5ms/step - loss: 106.2739 - val_loss: 83.8106
# Epoch 96/200
# 32/32 [==============================] - 0s 5ms/step - loss: 104.8993 - val_loss: 82.6444
# Epoch 97/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.5175 - val_loss: 82.5556
# Epoch 98/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.0856 - val_loss: 82.2466
# Epoch 99/200
# 32/32 [==============================] - 0s 5ms/step - loss: 106.1851 - val_loss: 83.1377
# Epoch 100/200
# 32/32 [==============================] - 0s 4ms/step - loss: 105.4806 - val_loss: 81.9537
# Epoch 101/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.4063 - val_loss: 82.6350
# Epoch 102/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.2696 - val_loss: 82.0205
# Epoch 103/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.4196 - val_loss: 82.2316
# Epoch 104/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.2435 - val_loss: 82.9981
# Epoch 105/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.3274 - val_loss: 82.4449
# Epoch 106/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.3892 - val_loss: 83.2309
# Epoch 107/200
# 32/32 [==============================] - 0s 6ms/step - loss: 105.3788 - val_loss: 82.4987
# Epoch 108/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.1557 - val_loss: 82.4971
# Epoch 109/200
# 32/32 [==============================] - 0s 6ms/step - loss: 105.9443 - val_loss: 81.6651
# Epoch 110/200
# 32/32 [==============================] - 0s 6ms/step - loss: 105.4451 - val_loss: 82.7340
# Epoch 111/200
# 32/32 [==============================] - 0s 4ms/step - loss: 105.6188 - val_loss: 82.2999
# Epoch 112/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.1681 - val_loss: 82.3819
# Epoch 113/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.2051 - val_loss: 82.6859
# Epoch 114/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.1430 - val_loss: 81.9995
# Epoch 115/200
# 32/32 [==============================] - 0s 5ms/step - loss: 106.3679 - val_loss: 81.8691
# Epoch 116/200
# 32/32 [==============================] - 0s 6ms/step - loss: 105.9069 - val_loss: 83.6569
# Epoch 117/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.5829 - val_loss: 82.0194
# Epoch 118/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.3910 - val_loss: 82.5289
# Epoch 119/200
# 32/32 [==============================] - 0s 6ms/step - loss: 105.2957 - val_loss: 83.0854
# Epoch 120/200
# 32/32 [==============================] - 0s 6ms/step - loss: 106.4149 - val_loss: 81.0845
# Epoch 121/200
# 32/32 [==============================] - 0s 6ms/step - loss: 105.9322 - val_loss: 83.1372
# Epoch 122/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.0565 - val_loss: 82.1270
# Epoch 123/200
# 32/32 [==============================] - 0s 4ms/step - loss: 105.2253 - val_loss: 81.7449
# Epoch 124/200
# 32/32 [==============================] - 0s 6ms/step - loss: 105.9002 - val_loss: 82.6565
# Epoch 125/200
# 32/32 [==============================] - 0s 5ms/step - loss: 106.3076 - val_loss: 82.5229
# Epoch 126/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.4335 - val_loss: 80.9384
# Epoch 127/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.5872 - val_loss: 81.9608
# Epoch 128/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.5216 - val_loss: 82.3898
# Epoch 129/200
# 32/32 [==============================] - 0s 4ms/step - loss: 104.9922 - val_loss: 81.8729
# Epoch 130/200
# 32/32 [==============================] - 0s 6ms/step - loss: 105.0797 - val_loss: 82.0617
# Epoch 131/200
# 32/32 [==============================] - 0s 6ms/step - loss: 105.2433 - val_loss: 81.9474
# Epoch 132/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.1441 - val_loss: 81.9067
# Epoch 133/200
# 32/32 [==============================] - 0s 6ms/step - loss: 105.5206 - val_loss: 81.7714
# Epoch 134/200
# 32/32 [==============================] - 0s 5ms/step - loss: 107.1279 - val_loss: 81.6937
# Epoch 135/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.5263 - val_loss: 82.0952
# Epoch 136/200
# 32/32 [==============================] - 0s 6ms/step - loss: 106.0090 - val_loss: 82.0513
# Epoch 137/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.3523 - val_loss: 81.9827
# Epoch 138/200
# 32/32 [==============================] - 0s 6ms/step - loss: 106.0192 - val_loss: 81.8541
# Epoch 139/200
# 32/32 [==============================] - 0s 6ms/step - loss: 105.2866 - val_loss: 81.8129
# Epoch 140/200
# 32/32 [==============================] - 0s 4ms/step - loss: 105.7700 - val_loss: 81.5071
# Epoch 141/200
# 32/32 [==============================] - 0s 6ms/step - loss: 107.0528 - val_loss: 82.1857
# Epoch 142/200
# 32/32 [==============================] - 0s 6ms/step - loss: 105.5079 - val_loss: 81.5870
# Epoch 143/200
# 32/32 [==============================] - 0s 5ms/step - loss: 106.2280 - val_loss: 81.3246
# Epoch 144/200
# 32/32 [==============================] - 0s 6ms/step - loss: 105.3356 - val_loss: 82.2912
# Epoch 145/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.2873 - val_loss: 81.9417
# Epoch 146/200
# 32/32 [==============================] - 0s 6ms/step - loss: 105.6181 - val_loss: 81.3436
# Epoch 147/200
# 32/32 [==============================] - 0s 5ms/step - loss: 106.3365 - val_loss: 80.8939
# Epoch 148/200
# 32/32 [==============================] - 0s 6ms/step - loss: 105.9007 - val_loss: 83.0304
# Epoch 149/200
# 32/32 [==============================] - 0s 6ms/step - loss: 104.9770 - val_loss: 82.0038
# Epoch 150/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.0541 - val_loss: 81.3414
# Epoch 151/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.3395 - val_loss: 81.3280
# Epoch 152/200
# 32/32 [==============================] - 0s 6ms/step - loss: 105.3723 - val_loss: 81.1486
# Epoch 153/200
# 32/32 [==============================] - 0s 6ms/step - loss: 105.2087 - val_loss: 81.2967
# Epoch 154/200
# 32/32 [==============================] - 0s 6ms/step - loss: 105.2723 - val_loss: 82.2610
# Epoch 155/200
# 32/32 [==============================] - 0s 6ms/step - loss: 105.4366 - val_loss: 81.8049
# Epoch 156/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.8701 - val_loss: 81.9147
# Epoch 157/200
# 32/32 [==============================] - 0s 5ms/step - loss: 106.1256 - val_loss: 80.6251
# Epoch 158/200
# 32/32 [==============================] - 0s 6ms/step - loss: 107.0454 - val_loss: 82.3562
# Epoch 159/200
# 32/32 [==============================] - 0s 6ms/step - loss: 105.3838 - val_loss: 80.7515
# Epoch 160/200
# 32/32 [==============================] - 0s 6ms/step - loss: 105.8453 - val_loss: 81.5942
# Epoch 161/200
# 32/32 [==============================] - 0s 6ms/step - loss: 105.3545 - val_loss: 81.3220
# Epoch 162/200
# 32/32 [==============================] - 0s 4ms/step - loss: 105.1082 - val_loss: 81.0836
# Epoch 163/200
# 32/32 [==============================] - 0s 6ms/step - loss: 105.6104 - val_loss: 80.9028
# Epoch 164/200
# 32/32 [==============================] - 0s 6ms/step - loss: 105.5482 - val_loss: 82.2043
# Epoch 165/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.5322 - val_loss: 81.0409
# Epoch 166/200
# 32/32 [==============================] - 0s 6ms/step - loss: 106.2825 - val_loss: 82.0594
# Epoch 167/200
# 32/32 [==============================] - 0s 6ms/step - loss: 105.1216 - val_loss: 80.7582
# Epoch 168/200
# 32/32 [==============================] - 0s 6ms/step - loss: 105.3856 - val_loss: 81.1301
# Epoch 169/200
# 32/32 [==============================] - 0s 6ms/step - loss: 105.5184 - val_loss: 80.7214
# Epoch 170/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.0431 - val_loss: 81.3903
# Epoch 171/200
# 32/32 [==============================] - 0s 5ms/step - loss: 107.0994 - val_loss: 81.1486
# Epoch 172/200
# 32/32 [==============================] - 0s 6ms/step - loss: 105.1298 - val_loss: 80.7791
# Epoch 173/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.7867 - val_loss: 80.8283
# Epoch 174/200
# 32/32 [==============================] - 0s 6ms/step - loss: 105.3356 - val_loss: 81.4232
# Epoch 175/200
# 32/32 [==============================] - 0s 6ms/step - loss: 107.8353 - val_loss: 81.9469
# Epoch 176/200
# 32/32 [==============================] - 0s 6ms/step - loss: 105.1916 - val_loss: 80.9234
# Epoch 177/200
# 32/32 [==============================] - 0s 6ms/step - loss: 105.4033 - val_loss: 80.6637
# Epoch 178/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.6924 - val_loss: 82.5197
# Epoch 179/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.7109 - val_loss: 80.9477
# Epoch 180/200
# 32/32 [==============================] - 0s 6ms/step - loss: 106.1006 - val_loss: 82.6808
# Epoch 181/200
# 32/32 [==============================] - 0s 6ms/step - loss: 106.8409 - val_loss: 81.1808
# Epoch 182/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.7120 - val_loss: 81.8161
# Epoch 183/200
# 32/32 [==============================] - 0s 7ms/step - loss: 105.6700 - val_loss: 82.0300
# Epoch 184/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.2456 - val_loss: 81.3683
# Epoch 185/200
# 32/32 [==============================] - 0s 6ms/step - loss: 105.9220 - val_loss: 81.6855
# Epoch 186/200
# 32/32 [==============================] - 0s 6ms/step - loss: 106.6670 - val_loss: 81.7697
# Epoch 187/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.2253 - val_loss: 80.2720
# Epoch 188/200
# 32/32 [==============================] - 0s 6ms/step - loss: 105.8522 - val_loss: 80.7778
# Epoch 189/200
# 32/32 [==============================] - 0s 6ms/step - loss: 105.5478 - val_loss: 80.7468
# Epoch 190/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.4160 - val_loss: 80.9175
# Epoch 191/200
# 32/32 [==============================] - 0s 6ms/step - loss: 105.8043 - val_loss: 81.0940
# Epoch 192/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.1857 - val_loss: 80.4579
# Epoch 193/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.8169 - val_loss: 80.7578
# Epoch 194/200
# 32/32 [==============================] - 0s 6ms/step - loss: 105.8147 - val_loss: 81.2514
# Epoch 195/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.7750 - val_loss: 80.7532
# Epoch 196/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.5427 - val_loss: 82.0613
# Epoch 197/200
# 32/32 [==============================] - 0s 5ms/step - loss: 106.0641 - val_loss: 80.5009
# Epoch 198/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.1318 - val_loss: 80.9598
# Epoch 199/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.3179 - val_loss: 81.9277
# Epoch 200/200
# 32/32 [==============================] - 0s 5ms/step - loss: 105.7000 - val_loss: 81.3421

# %% [markdown]
# ## Model evaluation

# %%
# model.evaluate(x_test, y_test)
loss, accuracy = model.evaluate(x_test, y_test)

# 绘制训练历史
plt.plot(history.history['loss'], label='Training loss')
plt.plot(history.history['val_loss'], label='Validation loss')
plt.legend()
plt.show()
# Out:
# 1/1 [==============================] - 0s 313ms/step - loss: 107.5541
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[50], line 3
#       1 # 评估模型
#       2 # model.evaluate(x_test, y_test)
# ----> 3 loss, accuracy = model.evaluate(x_test, y_test)
#       5 # 打印损失值和准确率
#       6 print(f'Loss: {loss}')
#
# TypeError: cannot unpack non-iterable float object

# %%
def plot_scatter (x, y, title, x_label, y_label,n):
    # plt.subplot(2, 2, n);
    plt.figure(figsize=(5, 5));
    plt.plot(x, x, color="blue", label="d")
    plt.scatter(x, y, marker="x", color="red")
    # plt.axis((0,210, 0,210))
    plt.title(title)
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.show()

y_pred = model.predict(x_test)
plot_scatter(y_test, y_pred, "Testing set", "True value", "Pred. value",1)

y_pred = model.predict(x_train)
plot_scatter(y_train, y_pred, "Training set", "True value", "Pred. value",2)

# %%
y_pred = model.predict(x_train)
plt.scatter(x_train, y_train, color='red', label='Actual values')
plt.scatter(x_train, y_pred, color='blue', marker='x', label='Predicted values')
plt.title('training set')
plt.legend()
plt.show()


# 使用模型进行预测
y_pred = model.predict(x_test)
# 可视化真实值与预测值
plt.scatter(x_test, y_test, color='red', label='Actual values')
plt.scatter(x_test, y_pred, color='blue', marker='x', label='Predicted values')
plt.title('testing set')
plt.legend()
plt.show()

# %% [markdown]
# ### Exercise : Please try to write R2 and Pearson correlation function for evaluating the training model

# %% [markdown]
# ## coefficient of determination, denoted R2
# https://en.wikipedia.org/wiki/Coefficient_of_determination
#
# ![image.png](attachment:eb0ce0c8-3109-4ef9-ac63-948d4a1a7148.png)

# %% [markdown]
# ## Pearson correlation function
# #### The Pearson correlation measures the strength of the linear relationship between two variables. It has a value between -1 to 1, with a value of -1 meaning a total negative linear correlation, 0 being no correlation, and + 1 meaning a total positive correlation.
#
# ![image.png](attachment:891bbceb-b815-4fd3-af18-067c0046a1a3.png)

# %% [markdown]
# 餘弦相似度的定義是兩個向量的點積除以這兩個向量模的乘積：
#
# ![image.png](attachment:533369cc-d3bb-4647-b383-0cd3fcd26886.png)
# ​
