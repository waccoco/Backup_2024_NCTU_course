# %% [markdown]
# ## Data Preparation

# %%
# install scikit-learn, tensorflow, pandas, matplotlib, numpy
# Out:
# 'conda' 不是內部或外部命令、可執行的程式或批次檔。

# %%
import pandas as pd

output_path = './F_Energy.csv'
path = output_path
df = pd.read_csv(output_path)
display(df.head())
# Out:
#   Pretty Formula   Density      Energy  Energy_per_Atom      Volume  \
# 0          B13C2  2.438648 -106.358032        -7.090535  112.056191
# 1           SiB3  2.449974 -204.992906        -6.406028  328.145035
# 2           SnB6  4.110240  -42.852113        -6.121730   74.164800
# 3           B6Pb  6.003820  -42.968600        -6.138371   75.248129
# 4             BN  3.302143  -68.876677        -8.609585   49.920018
#
#    Formation_Energy_per_Atom  Band Gap
# 0                  -0.072416    0.0089
# 1                  -0.040804    1.4083
# 2                   0.175492    0.7527
# 3                   0.114862    0.9209
# 4                  -1.294085    4.7885

# %%
df.info()
df.describe(include='all').round(2)

#round 函数在 Python（包括 Pandas 库中）的功能是对浮点数进行四舍五入到给定的精度。
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 194 entries, 0 to 193
# Data columns (total 7 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Pretty Formula             194 non-null    object
#  1   Density                    194 non-null    float64
#  2   Energy                     194 non-null    float64
#  3   Energy_per_Atom            194 non-null    float64
#  4   Volume                     194 non-null    float64
#  5   Formation_Energy_per_Atom  194 non-null    float64
#  6   Band Gap                   194 non-null    float64
# dtypes: float64(6), object(1)
# memory usage: 10.7+ KB
#        Pretty Formula  Density  Energy  Energy_per_Atom   Volume  \
# count             194   194.00  194.00           194.00   194.00
# unique            194      NaN     NaN              NaN      NaN
# top             B13C2      NaN     NaN              NaN      NaN
# freq                1      NaN     NaN              NaN      NaN
# mean              NaN     4.01 -102.56            -4.38   617.60
# std               NaN     1.84  134.24             1.50   867.71
# min               NaN     0.14 -787.96            -8.61    27.98
# 25%               NaN     2.60 -117.10            -5.29   147.24
# 50%               NaN     3.85  -54.00            -4.17   334.98
# 75%               NaN     5.07  -24.22            -3.18   720.48
# max               NaN     9.90   -4.03            -1.34  5834.92
#
#         Formation_Energy_per_Atom  Band Gap
# count                      194.00    194.00
# unique                        NaN       NaN
# top                           NaN       NaN
# freq                          NaN       NaN
# mean                        -0.65      1.96
# std                          0.94      1.54
# min                         -3.89      0.00
# 25%                         -1.12      0.80
# 50%                         -0.44      1.74
# 75%                         -0.07      2.85
# max                          1.88      7.72

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

y= df['Formation_Energy_per_Atom']
x= df.drop(columns=['Energy','Formation_Energy_per_Atom','Volume','Pretty Formula'])
display(x.head(5))
# print(set(x), set(y))

# splitting dataset to training set and testing set 
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=20)
# Out:
#     Density      Energy  Energy_per_Atom      Volume  Band Gap
# 0  2.438648 -106.358032        -7.090535  112.056191    0.0089
# 1  2.449974 -204.992906        -6.406028  328.145035    1.4083
# 2  4.110240  -42.852113        -6.121730   74.164800    0.7527
# 3  6.003820  -42.968600        -6.138371   75.248129    0.9209
# 4  3.302143  -68.876677        -8.609585   49.920018    4.7885

# %% [markdown]
# ##  data visualization

# %%
import matplotlib.pyplot as plt
plt.scatter(x_train['Density'], y_train, color='blue', label='Training data')
plt.scatter(x_test['Density'], y_test, color='red', label='Testing data')
plt.legend()
plt.show()

# %%
# Visualizing data before and after scaling with a pair plot
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(8, 8));
sns.pairplot(data=df)
plt.suptitle('Pair Plot of Diabetes Dataset Before and After Scaling', y=1.02, fontsize=18);
plt.show();
# Out:
# C:\Users\m9230\anaconda3\envs\NYCU_py39_2024\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\m9230\anaconda3\envs\NYCU_py39_2024\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\m9230\anaconda3\envs\NYCU_py39_2024\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\m9230\anaconda3\envs\NYCU_py39_2024\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\m9230\anaconda3\envs\NYCU_py39_2024\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\m9230\anaconda3\envs\NYCU_py39_2024\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ## ==================================================================================================================
# ##　Data scaling
# https://www.cupoy.com/collection/0000018008CD5D70000000046375706F795F72656C656173654355/00000181709BCC8F000000056375706F795F72656C656173654349
# https://medium.com/@hhuseyincosgun/which-data-scaling-technique-should-i-use-a1615292061e
#
# Normalization (MinMaxScaler) :
# <br>
# <img src="https://miro.medium.com/v2/resize:fit:996/format:webp/1*gxth9npBXCrHDYbw9XJGrQ.png" width="20%" height="auto">
# <br>
#
# Standardization (Z-Score Standardization) : uses mean and standard deviation
# <br>
# <img src="https://miro.medium.com/v2/resize:fit:1400/format:webp/1*mViMXFWPqg7Vg2WwjaoKVQ.png" width="300" height="auto">
# <br>
#
# RobustScaler : uses median and interquartile range (IQR) instead
# <br>
# <img src="https://miro.medium.com/v2/resize:fit:1348/format:webp/1*uoQxqnwptSNabGU_JL3oPA.png" width="30%" height="auto">
# <br>
#
#
# <img src="https://miro.medium.com/v2/resize:fit:1400/format:webp/1*y0esOCH8O2NV1c_8iY3ouA.png" width="1200" height="auto">
# <br>
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/1/1a/Boxplot_vs_PDF.svg/440px-Boxplot_vs_PDF.svg.png" width="600" height="auto">
# <br>
# InterQuartile Range (四分位距 = 第三四分位數 - 第一四分位數) :
#
# [link to wiki](https://zh.wikipedia.org/zh-tw/%E5%9B%9B%E5%88%86%E4%BD%8D%E6%95%B0)
# <br>
#
# ### 中位數的重要性和應用 :
# 中位數是描述數據集中趨勢的一個非常有用的統計量，特別是當數據集中包含異常值（極端值）時。與平均值相比，中位數不易受到極端值的影響，因此在有異常值的數據集中提供了更穩定的“中心”測量。例如，在房價分析、收入分析等領域，使用中位數可以提供比平均值更真實的市場情況反映，因為這些領域常常受到極高或極低數據點的影響。

# %% [markdown]
# ## Exercise : try to use Standardization and Normalization to scale the training data

# %% [markdown]
# ## Build ANN model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam

# model = Sequential([
    # Dense(1, input_shape=(1,), activation='linear')
#     Dense(5, input_shape=(x.shape[1],), activation='linear')
# ])

model = Sequential([
    Dense(5, input_shape=(x.shape[1],), activation='relu'),
    Dense(3, activation='relu'),
    Dense(1, activation='linear')
])

# Sequential.help

model.compile(optimizer=Adam(learning_rate=0.005), loss='mse')

# %% [markdown]
# ## Training ANN model

# %%
from tensorflow.keras.callbacks import EarlyStopping

# early_stop = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

# history = model.fit(x_train, y_train, validation_split=0.2, epochs=200, batch_size=2)
history = model.fit(x_scaled, y_train, validation_split=0.2, epochs=200, batch_size=5)
# Out:
# Epoch 1/200
# 25/25 [==============================] - 1s 8ms/step - loss: 1.2902 - val_loss: 1.2872
# Epoch 2/200
# 25/25 [==============================] - 0s 3ms/step - loss: 1.1491 - val_loss: 1.1931
# Epoch 3/200
# 25/25 [==============================] - 0s 4ms/step - loss: 1.0680 - val_loss: 1.1259
# Epoch 4/200
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0061 - val_loss: 1.0790
# Epoch 5/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.9521 - val_loss: 1.0310
# Epoch 6/200
# 25/25 [==============================] - 0s 5ms/step - loss: 0.9007 - val_loss: 0.9925
# Epoch 7/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.8563 - val_loss: 0.9617
# Epoch 8/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.8151 - val_loss: 0.9347
# Epoch 9/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.7776 - val_loss: 0.8869
# Epoch 10/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.7445 - val_loss: 0.8699
# Epoch 11/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.7185 - val_loss: 0.8225
# Epoch 12/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.6964 - val_loss: 0.7862
# Epoch 13/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.6772 - val_loss: 0.7621
# Epoch 14/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.6618 - val_loss: 0.7399
# Epoch 15/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6448 - val_loss: 0.7155
# Epoch 16/200
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6324 - val_loss: 0.6989
# Epoch 17/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6179 - val_loss: 0.6726
# Epoch 18/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6143 - val_loss: 0.7166
# Epoch 19/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.5974 - val_loss: 0.6512
# Epoch 20/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.5785 - val_loss: 0.6354
# Epoch 21/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.5723 - val_loss: 0.6239
# Epoch 22/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.5746 - val_loss: 0.6217
# Epoch 23/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.5606 - val_loss: 0.5896
# Epoch 24/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.5388 - val_loss: 0.5994
# Epoch 25/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.5333 - val_loss: 0.5710
# Epoch 26/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.5273 - val_loss: 0.5730
# Epoch 27/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.5278 - val_loss: 0.5579
# Epoch 28/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.5266 - val_loss: 0.5538
# Epoch 29/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.5127 - val_loss: 0.5619
# Epoch 30/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.5206 - val_loss: 0.5585
# Epoch 31/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.5028 - val_loss: 0.5452
# Epoch 32/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4959 - val_loss: 0.5343
# Epoch 33/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.4900 - val_loss: 0.5336
# Epoch 34/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4942 - val_loss: 0.5239
# Epoch 35/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4807 - val_loss: 0.5196
# Epoch 36/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4826 - val_loss: 0.5067
# Epoch 37/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4711 - val_loss: 0.4950
# Epoch 38/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4539 - val_loss: 0.4883
# Epoch 39/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4425 - val_loss: 0.4927
# Epoch 40/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.4236 - val_loss: 0.4752
# Epoch 41/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.4095 - val_loss: 0.4700
# Epoch 42/200
# 25/25 [==============================] - 0s 5ms/step - loss: 0.4144 - val_loss: 0.4621
# Epoch 43/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.3995 - val_loss: 0.4515
# Epoch 44/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.3792 - val_loss: 0.4587
# Epoch 45/200
# 25/25 [==============================] - 0s 11ms/step - loss: 0.3739 - val_loss: 0.4439
# Epoch 46/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.3649 - val_loss: 0.4287
# Epoch 47/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.3584 - val_loss: 0.4371
# Epoch 48/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.3474 - val_loss: 0.4132
# Epoch 49/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.3431 - val_loss: 0.4186
# Epoch 50/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.3505 - val_loss: 0.3960
# Epoch 51/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.3353 - val_loss: 0.3880
# Epoch 52/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.3268 - val_loss: 0.4198
# Epoch 53/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.3282 - val_loss: 0.3992
# Epoch 54/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.3189 - val_loss: 0.3995
# Epoch 55/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.3228 - val_loss: 0.4293
# Epoch 56/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.3272 - val_loss: 0.4036
# Epoch 57/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.3189 - val_loss: 0.4105
# Epoch 58/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.3224 - val_loss: 0.4092
# Epoch 59/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.3026 - val_loss: 0.3924
# Epoch 60/200
# 25/25 [==============================] - 0s 5ms/step - loss: 0.3019 - val_loss: 0.4186
# Epoch 61/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.3102 - val_loss: 0.4225
# Epoch 62/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.3011 - val_loss: 0.3929
# Epoch 63/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2986 - val_loss: 0.4410
# Epoch 64/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2967 - val_loss: 0.4078
# Epoch 65/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2955 - val_loss: 0.4012
# Epoch 66/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2833 - val_loss: 0.4108
# Epoch 67/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2914 - val_loss: 0.4184
# Epoch 68/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2860 - val_loss: 0.3990
# Epoch 69/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2863 - val_loss: 0.4140
# Epoch 70/200
# 25/25 [==============================] - 0s 5ms/step - loss: 0.2818 - val_loss: 0.3952
# Epoch 71/200
# 25/25 [==============================] - 0s 5ms/step - loss: 0.2845 - val_loss: 0.4165
# Epoch 72/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2822 - val_loss: 0.4080
# Epoch 73/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2735 - val_loss: 0.4143
# Epoch 74/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2829 - val_loss: 0.3909
# Epoch 75/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2703 - val_loss: 0.4301
# Epoch 76/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2684 - val_loss: 0.3943
# Epoch 77/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2745 - val_loss: 0.4306
# Epoch 78/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2684 - val_loss: 0.3906
# Epoch 79/200
# 25/25 [==============================] - 0s 5ms/step - loss: 0.2742 - val_loss: 0.4088
# Epoch 80/200
# 25/25 [==============================] - 0s 6ms/step - loss: 0.2670 - val_loss: 0.3996
# Epoch 81/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2623 - val_loss: 0.4337
# Epoch 82/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2695 - val_loss: 0.3991
# Epoch 83/200
# 25/25 [==============================] - 0s 5ms/step - loss: 0.2646 - val_loss: 0.4290
# Epoch 84/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2644 - val_loss: 0.4176
# Epoch 85/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2719 - val_loss: 0.4836
# Epoch 86/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2745 - val_loss: 0.4502
# Epoch 87/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2611 - val_loss: 0.4189
# Epoch 88/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2585 - val_loss: 0.4225
# Epoch 89/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2547 - val_loss: 0.4299
# Epoch 90/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2618 - val_loss: 0.4484
# Epoch 91/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2549 - val_loss: 0.4216
# Epoch 92/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2567 - val_loss: 0.4369
# Epoch 93/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2608 - val_loss: 0.4486
# Epoch 94/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2581 - val_loss: 0.4293
# Epoch 95/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2717 - val_loss: 0.4810
# Epoch 96/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2599 - val_loss: 0.4396
# Epoch 97/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2565 - val_loss: 0.4405
# Epoch 98/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2487 - val_loss: 0.4361
# Epoch 99/200
# 25/25 [==============================] - 0s 5ms/step - loss: 0.2566 - val_loss: 0.4535
# Epoch 100/200
# 25/25 [==============================] - 0s 5ms/step - loss: 0.2534 - val_loss: 0.4422
# Epoch 101/200
# 25/25 [==============================] - 0s 5ms/step - loss: 0.2606 - val_loss: 0.4346
# Epoch 102/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2723 - val_loss: 0.4371
# Epoch 103/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2668 - val_loss: 0.4131
# Epoch 104/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2589 - val_loss: 0.4506
# Epoch 105/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2662 - val_loss: 0.4840
# Epoch 106/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2597 - val_loss: 0.4540
# Epoch 107/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2508 - val_loss: 0.4415
# Epoch 108/200
# 25/25 [==============================] - 0s 5ms/step - loss: 0.2515 - val_loss: 0.4820
# Epoch 109/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2599 - val_loss: 0.4541
# Epoch 110/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2486 - val_loss: 0.4834
# Epoch 111/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2524 - val_loss: 0.4678
# Epoch 112/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2503 - val_loss: 0.4609
# Epoch 113/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2527 - val_loss: 0.4799
# Epoch 114/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2445 - val_loss: 0.4870
# Epoch 115/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2538 - val_loss: 0.4701
# Epoch 116/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2500 - val_loss: 0.4400
# Epoch 117/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2455 - val_loss: 0.4817
# Epoch 118/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2505 - val_loss: 0.4678
# Epoch 119/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2541 - val_loss: 0.4614
# Epoch 120/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2474 - val_loss: 0.4765
# Epoch 121/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2471 - val_loss: 0.4881
# Epoch 122/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2458 - val_loss: 0.4547
# Epoch 123/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2570 - val_loss: 0.4490
# Epoch 124/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2538 - val_loss: 0.4559
# Epoch 125/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2448 - val_loss: 0.4318
# Epoch 126/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2446 - val_loss: 0.4625
# Epoch 127/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2447 - val_loss: 0.4652
# Epoch 128/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2550 - val_loss: 0.4611
# Epoch 129/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2527 - val_loss: 0.4576
# Epoch 130/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2568 - val_loss: 0.4729
# Epoch 131/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2569 - val_loss: 0.4544
# Epoch 132/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2539 - val_loss: 0.4423
# Epoch 133/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2495 - val_loss: 0.4667
# Epoch 134/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2545 - val_loss: 0.4752
# Epoch 135/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2465 - val_loss: 0.4563
# Epoch 136/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2419 - val_loss: 0.4409
# Epoch 137/200
# 25/25 [==============================] - 0s 5ms/step - loss: 0.2457 - val_loss: 0.4762
# Epoch 138/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2444 - val_loss: 0.4694
# Epoch 139/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2491 - val_loss: 0.4656
# Epoch 140/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2444 - val_loss: 0.4522
# Epoch 141/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2461 - val_loss: 0.4695
# Epoch 142/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2501 - val_loss: 0.4424
# Epoch 143/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2406 - val_loss: 0.4662
# Epoch 144/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2432 - val_loss: 0.4460
# Epoch 145/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2444 - val_loss: 0.4712
# Epoch 146/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2457 - val_loss: 0.4567
# Epoch 147/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2524 - val_loss: 0.4705
# Epoch 148/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2569 - val_loss: 0.5302
# Epoch 149/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2524 - val_loss: 0.4382
# Epoch 150/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2523 - val_loss: 0.4710
# Epoch 151/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2491 - val_loss: 0.4335
# Epoch 152/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2456 - val_loss: 0.4751
# Epoch 153/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2422 - val_loss: 0.4491
# Epoch 154/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2487 - val_loss: 0.4359
# Epoch 155/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2509 - val_loss: 0.4565
# Epoch 156/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2455 - val_loss: 0.4895
# Epoch 157/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2435 - val_loss: 0.4851
# Epoch 158/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2433 - val_loss: 0.4404
# Epoch 159/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2428 - val_loss: 0.4505
# Epoch 160/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2452 - val_loss: 0.4197
# Epoch 161/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2456 - val_loss: 0.4482
# Epoch 162/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2481 - val_loss: 0.4189
# Epoch 163/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2474 - val_loss: 0.4454
# Epoch 164/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2452 - val_loss: 0.4591
# Epoch 165/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2516 - val_loss: 0.4905
# Epoch 166/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2438 - val_loss: 0.4616
# Epoch 167/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2403 - val_loss: 0.4377
# Epoch 168/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2418 - val_loss: 0.4484
# Epoch 169/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2382 - val_loss: 0.4105
# Epoch 170/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2450 - val_loss: 0.4418
# Epoch 171/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2423 - val_loss: 0.4523
# Epoch 172/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2362 - val_loss: 0.4460
# Epoch 173/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2442 - val_loss: 0.4156
# Epoch 174/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2471 - val_loss: 0.4361
# Epoch 175/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2454 - val_loss: 0.4272
# Epoch 176/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2494 - val_loss: 0.4303
# Epoch 177/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2434 - val_loss: 0.4252
# Epoch 178/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2460 - val_loss: 0.4305
# Epoch 179/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2379 - val_loss: 0.4388
# Epoch 180/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2439 - val_loss: 0.4049
# Epoch 181/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2357 - val_loss: 0.4070
# Epoch 182/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2387 - val_loss: 0.4048
# Epoch 183/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2400 - val_loss: 0.4291
# Epoch 184/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2418 - val_loss: 0.4200
# Epoch 185/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2412 - val_loss: 0.4027
# Epoch 186/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2434 - val_loss: 0.4334
# Epoch 187/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2366 - val_loss: 0.4153
# Epoch 188/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2384 - val_loss: 0.4067
# Epoch 189/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2345 - val_loss: 0.4188
# Epoch 190/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2430 - val_loss: 0.4104
# Epoch 191/200
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2321 - val_loss: 0.4261
# Epoch 192/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2350 - val_loss: 0.4090
# Epoch 193/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2349 - val_loss: 0.4338
# Epoch 194/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2383 - val_loss: 0.4306
# Epoch 195/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2375 - val_loss: 0.3843
# Epoch 196/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2377 - val_loss: 0.4439
# Epoch 197/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2416 - val_loss: 0.4147
# Epoch 198/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2516 - val_loss: 0.4168
# Epoch 199/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2476 - val_loss: 0.3753
# Epoch 200/200
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2460 - val_loss: 0.4128

# %% [markdown]
# ## Model evaluation

# %%
history.history['loss'][:10]
# Out:
# [1.9263197183609009,
#  1.2002594470977783,
#  1.0813995599746704,
#  1.023516058921814,
#  0.9795260429382324,
#  0.9502384066581726,
#  0.9288224577903748,
#  0.914122998714447,
#  0.9050933718681335,
#  0.9009512066841125]

# %%
# model.evaluate(x_test, y_test)
loss = model.evaluate(x_test, y_test)

# 绘制训练历史
plt.plot(history.history['loss'][10:], label='Training loss')
plt.plot(history.history['val_loss'][10:], label='Validation loss')
plt.legend()
plt.show()
# Out:
# 2/2 [==============================] - 0s 0s/step - loss: 99850.1328

# %% [markdown]
# ## Error inside
# ## Hint : scaling the data before prediction

# %%
def plot_scatter (x, y, title, x_label, y_label,n):
    # plt.subplot(2, 2, n);
    plt.figure(figsize=(5, 5));
    plt.plot(x, x, color="blue", label="d")
    plt.scatter(x, y, marker="x", color="red")
    # plt.axis((0,210, 0,210))
    plt.title(title)
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.show()
    

y_pred = model.predict(x_test)
plot_scatter(y_test, y_pred, "Testing set", "True value", "Pred. value",1)

y_pred = model.predict(x_train)
plot_scatter(y_train, y_pred, "Training set", "True value", "Pred. value",2)
# Out:
# 2/2 [==============================] - 0s 0s/step
# 5/5 [==============================] - 0s 6ms/step

# %% [markdown]
# ## Error inside
# ## Hint : scaling the data before prediction

# %%
y_pred = model.predict(x_train)
plt.scatter(x_train['Density'], y_train, color='red', label='Actual values')
plt.scatter(x_train['Density'], y_pred, color='blue', marker='x', label='Predicted values')
plt.title('training set')
plt.legend()
plt.show()


y_pred = model.predict(x_test)
plt.scatter(x_test['Density'], y_test, color='red', label='Actual values')
plt.scatter(x_test['Density'], y_pred, color='blue', marker='x', label='Predicted values')
plt.title('testing set')
plt.legend()
plt.show()
# Out:
# 5/5 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 4ms/step

# %% [markdown]
# ## Error inside
# ## Hint : scaling the data before prediction

# %%
## Coefficient of determination, denoted R2
from sklearn.metrics import r2_score
y_pred = model.predict(x_test)
r2_test = r2_score(y_test, y_pred)

y_pred = model.predict(x_train)
r2_train = r2_score(y_train, y_pred)

print(r2_train, r2_test)
# Out:
# 2/2 [==============================] - 0s 10ms/step
# 5/5 [==============================] - 0s 3ms/step
# 0.705367302876187 0.3035144456239177

# %%
## Pearson correlation function
from sklearn.datasets import make_regression
from sklearn.feature_selection import r_regression

y_pred = model.predict(x_test)
psc_test = r_regression(y_test.to_numpy().reshape(-1, 1) , y_pred.ravel())[0]
y_pred = model.predict(x_train)
psc_train = r_regression(y_train.to_numpy().reshape(-1, 1), y_pred.ravel())[0]
print(psc_train, psc_test)
# Out:
# 2/2 [==============================] - 0s 0s/step
# 5/5 [==============================] - 0s 0s/step
# 0.842745970872494 0.6068386803354457
