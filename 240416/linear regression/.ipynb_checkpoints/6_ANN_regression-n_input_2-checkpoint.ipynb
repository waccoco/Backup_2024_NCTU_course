# %% [markdown]
# ## Data Preparation

# %%
# install scikit-learn, tensorflow, pandas, matplotlib, numpy
# Out:
# 'conda' 不是內部或外部命令、可執行的程式或批次檔。

# %%
# # download the data
import wget
url = "https://raw.githubusercontent.com/waccoco/2024_NCTU_MI_course/master/Dataset/Salary_Data2.csv"
output_path = './Salary_Data2.csv'
wget.download(url, out=output_path)
# Out:
# 100% [................................................................................] 1040 / 1040
# './Salary_Data2 (1).csv'

# %%
import pandas as pd

output_path = './data.csv'
path = output_path
df = pd.read_csv(output_path)
display(df.head())
# Out:
#   Pretty Formula   Density      Energy  Energy_per_Atom      Volume  \
# 0          B13C2  2.438648 -106.358032        -7.090535  112.056191
# 1           SiB3  2.449974 -204.992906        -6.406028  328.145035
# 2           SnB6  4.110240  -42.852113        -6.121730   74.164800
# 3           B6Pb  6.003820  -42.968600        -6.138371   75.248129
# 4             BN  3.302143  -68.876677        -8.609585   49.920018
#
#    Formation_Energy_per_Atom  Band Gap
# 0                  -0.072416    0.0089
# 1                  -0.040804    1.4083
# 2                   0.175492    0.7527
# 3                   0.114862    0.9209
# 4                  -1.294085    4.7885

# %%
df.info()
df.describe(include='all').round(2)

#round 函数在 Python（包括 Pandas 库中）的功能是对浮点数进行四舍五入到给定的精度。
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 194 entries, 0 to 193
# Data columns (total 7 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Pretty Formula             194 non-null    object
#  1   Density                    194 non-null    float64
#  2   Energy                     194 non-null    float64
#  3   Energy_per_Atom            194 non-null    float64
#  4   Volume                     194 non-null    float64
#  5   Formation_Energy_per_Atom  194 non-null    float64
#  6   Band Gap                   194 non-null    float64
# dtypes: float64(6), object(1)
# memory usage: 10.7+ KB
#        Pretty Formula  Density  Energy  Energy_per_Atom   Volume  \
# count             194   194.00  194.00           194.00   194.00
# unique            194      NaN     NaN              NaN      NaN
# top             B13C2      NaN     NaN              NaN      NaN
# freq                1      NaN     NaN              NaN      NaN
# mean              NaN     4.01 -102.56            -4.38   617.60
# std               NaN     1.84  134.24             1.50   867.71
# min               NaN     0.14 -787.96            -8.61    27.98
# 25%               NaN     2.60 -117.10            -5.29   147.24
# 50%               NaN     3.85  -54.00            -4.17   334.98
# 75%               NaN     5.07  -24.22            -3.18   720.48
# max               NaN     9.90   -4.03            -1.34  5834.92
#
#         Formation_Energy_per_Atom  Band Gap
# count                      194.00    194.00
# unique                        NaN       NaN
# top                           NaN       NaN
# freq                          NaN       NaN
# mean                        -0.65      1.96
# std                          0.94      1.54
# min                         -3.89      0.00
# 25%                         -1.12      0.80
# 50%                         -0.44      1.74
# 75%                         -0.07      2.85
# max                          1.88      7.72

# %% [markdown]
# ## Transform the Categorical data to numerical data
# ### @ LabelEncoder：把類別型資料轉換成0,1,2,…的數值標籤 (特徵之間有順序或大小分別)
#    ![image.png](attachment:c86e50e9-fb01-44f3-8d23-a9548281d397.png)
#
# ### @ OneHotEncoder：把類別型資料轉換成0與1的數值標籤 (特徵之間沒有順序或大小分別)
# ![image.png](attachment:f9460b51-747e-473b-9324-c386e4bf5edc.png)
#
# ### Exercise : Try to use the one-hot encoder to encode the Categorical data into numerical data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# ########################################################
# df_encoded = pd.get_dummies(df, columns=['EducationLevel', 'City'])
# # 假設df是已經通過get_dummies轉換後的DataFrame，且包含布林值
# # 轉換布林值為整數
# df_encoded = df_encoded.astype(int)
# ########################################################

# # 顯示轉換後的DataFrame
# display(df_encoded.head(5))

# %%
# Delete redundant features
########################################################
# df_encoded = df_encoded.drop(columns=['EducationLevel_高中以下', 'City_城市C'])
########################################################

# df_encoded.to_csv('./encoded.csv')
y= df['Formation_Energy_per_Atom']
x= df.drop(columns=['Energy','Formation_Energy_per_Atom','Volume','Pretty Formula'])
display(x.head(5))
# print(set(x), set(y))
# Out:
#     Density  Energy_per_Atom  Band Gap
# 0  2.438648        -7.090535    0.0089
# 1  2.449974        -6.406028    1.4083
# 2  4.110240        -6.121730    0.7527
# 3  6.003820        -6.138371    0.9209
# 4  3.302143        -8.609585    4.7885

# %%
# splitting dataset to training set and testing set 
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=200)

# %%
print(x_test)
# Out:
#       Density  Energy_per_Atom  Band Gap
# 168  2.361598        -2.282951    0.7188
# 108  2.082977        -3.211538    3.5510
# 178  2.986298        -3.926115    4.1353
# 5    2.588885        -6.788335    2.5139
# 192  3.063119        -1.827899    1.4704
# 94   4.231468        -4.120423    1.5209
# 103  5.069638        -5.526139    0.4815
# 111  4.475043        -7.254285    2.2879
# 184  3.643513        -2.321755    2.5202
# 73   2.994789        -6.517565    1.2305
# 18   3.200890        -7.444919    4.0540
# 36   3.267386        -3.456478    0.6100
# 19   2.304784        -5.189210    1.6302
# 78   2.110662        -5.541621    1.4224
# 80   2.388957        -7.895982    5.5220
# 88   1.530940        -3.827010    0.2200
# 53   4.361795        -2.445547    1.7858
# 142  4.284021        -4.071579    1.4354
# 179  2.412448        -2.507735    2.8550
# 186  2.282502        -2.499673    2.4608
# 49   5.956751        -3.192181    0.1772
# 172  4.239816        -2.240701    2.1320
# 11   3.241430        -4.686806    1.7550
# 22   3.159566        -7.314467    3.2886
# 153  4.026649        -4.656103    3.5093
# 156  4.293228        -2.533615    2.1496
# 107  4.472517        -4.854774    3.1504
# 163  4.438966        -2.969292    2.8350
# 164  4.227851        -2.570462    2.7184
# 109  2.994720        -2.799388    2.7003
# 39   2.562369        -3.246064    4.1440
# 75   3.823847        -4.992760    0.6092
# 182  3.234783        -4.075357    4.4438
# 44   5.321023        -3.928446    0.3241
# 114  7.308181        -4.456735    0.5556
# 101  5.636037        -4.642855    0.0315
# 69   0.475249        -4.249129    0.5393
# 58   7.720003        -3.203765    0.2497
# 176  2.434063        -2.924557    2.2298

# %% [markdown]
# ##  data visualization

# %%
plt.scatter(x_train['Density'], y_train, color='blue', label='Training data')
plt.scatter(x_test['Density'], y_test, color='red', label='Testing data')
plt.legend()
plt.show()

# %% [markdown]
# ## Build ANN model

# %%
print(x.shape[1],)
# Out:
# 3

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam

# model = Sequential([
    # Dense(1, input_shape=(1,), activation='linear')
#     Dense(5, input_shape=(x.shape[1],), activation='linear')
# ])

model = Sequential([
    Dense(5, input_shape=(x.shape[1],), activation='relu'),
    Dense(3, activation='relu'),
    Dense(1, activation='linear')
])

# Sequential.help

model.compile(optimizer=Adam(learning_rate=0.005), loss='mse')

# %% [markdown]
# ## Training ANN model

# %%
from tensorflow.keras.callbacks import EarlyStopping

# early_stop = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)
history = model.fit(x_train, y_train, validation_split=0.2, epochs=200, batch_size=2)
# Out:
# Epoch 1/200
# 62/62 [==============================] - 2s 11ms/step - loss: 1.0530 - val_loss: 0.5318
# Epoch 2/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.8065 - val_loss: 0.4256
# Epoch 3/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.6796 - val_loss: 0.4205
# Epoch 4/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.6191 - val_loss: 0.3166
# Epoch 5/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.5709 - val_loss: 0.4030
# Epoch 6/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.5595 - val_loss: 0.2804
# Epoch 7/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.5754 - val_loss: 0.2747
# Epoch 8/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.5738 - val_loss: 0.2673
# Epoch 9/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.5308 - val_loss: 0.3020
# Epoch 10/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.5687 - val_loss: 0.3474
# Epoch 11/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.5153 - val_loss: 0.2558
# Epoch 12/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.5164 - val_loss: 0.2688
# Epoch 13/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.5049 - val_loss: 0.2622
# Epoch 14/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.5021 - val_loss: 0.2639
# Epoch 15/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.5578 - val_loss: 0.3140
# Epoch 16/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.5142 - val_loss: 0.2638
# Epoch 17/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.5230 - val_loss: 0.3425
# Epoch 18/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4973 - val_loss: 0.3528
# Epoch 19/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.5190 - val_loss: 0.2663
# Epoch 20/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.5276 - val_loss: 0.3078
# Epoch 21/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.5062 - val_loss: 0.2661
# Epoch 22/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.5041 - val_loss: 0.2662
# Epoch 23/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.5047 - val_loss: 0.3244
# Epoch 24/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4854 - val_loss: 0.2707
# Epoch 25/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4817 - val_loss: 0.2855
# Epoch 26/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4796 - val_loss: 0.2590
# Epoch 27/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4839 - val_loss: 0.2617
# Epoch 28/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4864 - val_loss: 0.2690
# Epoch 29/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4904 - val_loss: 0.3219
# Epoch 30/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4941 - val_loss: 0.3375
# Epoch 31/200
# 62/62 [==============================] - 0s 6ms/step - loss: 0.4884 - val_loss: 0.2643
# Epoch 32/200
# 62/62 [==============================] - 0s 6ms/step - loss: 0.4982 - val_loss: 0.2644
# Epoch 33/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4989 - val_loss: 0.3193
# Epoch 34/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4845 - val_loss: 0.2862
# Epoch 35/200
# 62/62 [==============================] - 0s 6ms/step - loss: 0.5165 - val_loss: 0.3050
# Epoch 36/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.5022 - val_loss: 0.3209
# Epoch 37/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4753 - val_loss: 0.2656
# Epoch 38/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4684 - val_loss: 0.2627
# Epoch 39/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4790 - val_loss: 0.2686
# Epoch 40/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4952 - val_loss: 0.2650
# Epoch 41/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4708 - val_loss: 0.2620
# Epoch 42/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4756 - val_loss: 0.2709
# Epoch 43/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4688 - val_loss: 0.2662
# Epoch 44/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4641 - val_loss: 0.2653
# Epoch 45/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4902 - val_loss: 0.2973
# Epoch 46/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.5191 - val_loss: 0.2729
# Epoch 47/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4658 - val_loss: 0.2829
# Epoch 48/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4685 - val_loss: 0.2831
# Epoch 49/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4705 - val_loss: 0.2905
# Epoch 50/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4830 - val_loss: 0.2574
# Epoch 51/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.5146 - val_loss: 0.2631
# Epoch 52/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4744 - val_loss: 0.3049
# Epoch 53/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4721 - val_loss: 0.2806
# Epoch 54/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4708 - val_loss: 0.2794
# Epoch 55/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.4690 - val_loss: 0.2878
# Epoch 56/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4785 - val_loss: 0.2748
# Epoch 57/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4634 - val_loss: 0.2717
# Epoch 58/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4686 - val_loss: 0.2667
# Epoch 59/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4521 - val_loss: 0.3910
# Epoch 60/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4853 - val_loss: 0.2621
# Epoch 61/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4733 - val_loss: 0.2614
# Epoch 62/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4748 - val_loss: 0.2934
# Epoch 63/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4622 - val_loss: 0.2645
# Epoch 64/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4582 - val_loss: 0.2637
# Epoch 65/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4528 - val_loss: 0.2700
# Epoch 66/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4784 - val_loss: 0.2624
# Epoch 67/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4590 - val_loss: 0.2964
# Epoch 68/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4636 - val_loss: 0.3074
# Epoch 69/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4525 - val_loss: 0.2666
# Epoch 70/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4613 - val_loss: 0.3409
# Epoch 71/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4615 - val_loss: 0.2671
# Epoch 72/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4552 - val_loss: 0.2658
# Epoch 73/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4858 - val_loss: 0.2707
# Epoch 74/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4412 - val_loss: 0.3844
# Epoch 75/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4884 - val_loss: 0.2999
# Epoch 76/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4470 - val_loss: 0.2557
# Epoch 77/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4749 - val_loss: 0.2906
# Epoch 78/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4560 - val_loss: 0.3929
# Epoch 79/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4596 - val_loss: 0.2692
# Epoch 80/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4469 - val_loss: 0.3207
# Epoch 81/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4589 - val_loss: 0.2664
# Epoch 82/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4712 - val_loss: 0.2801
# Epoch 83/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4624 - val_loss: 0.2717
# Epoch 84/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4692 - val_loss: 0.3008
# Epoch 85/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4525 - val_loss: 0.2614
# Epoch 86/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4705 - val_loss: 0.2635
# Epoch 87/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4591 - val_loss: 0.3316
# Epoch 88/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4605 - val_loss: 0.2793
# Epoch 89/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4517 - val_loss: 0.2962
# Epoch 90/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4569 - val_loss: 0.2759
# Epoch 91/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4466 - val_loss: 0.2725
# Epoch 92/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4403 - val_loss: 0.3696
# Epoch 93/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4713 - val_loss: 0.3257
# Epoch 94/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4595 - val_loss: 0.3134
# Epoch 95/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4556 - val_loss: 0.2611
# Epoch 96/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4578 - val_loss: 0.2952
# Epoch 97/200
# 62/62 [==============================] - 0s 6ms/step - loss: 0.4588 - val_loss: 0.3420
# Epoch 98/200
# 62/62 [==============================] - 0s 6ms/step - loss: 0.4534 - val_loss: 0.2677
# Epoch 99/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4570 - val_loss: 0.2857
# Epoch 100/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4623 - val_loss: 0.2768
# Epoch 101/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4566 - val_loss: 0.2665
# Epoch 102/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4439 - val_loss: 0.2838
# Epoch 103/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4770 - val_loss: 0.2715
# Epoch 104/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4621 - val_loss: 0.2735
# Epoch 105/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4652 - val_loss: 0.2573
# Epoch 106/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4625 - val_loss: 0.2742
# Epoch 107/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4548 - val_loss: 0.2599
# Epoch 108/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4831 - val_loss: 0.2868
# Epoch 109/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4689 - val_loss: 0.2962
# Epoch 110/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4495 - val_loss: 0.3304
# Epoch 111/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4592 - val_loss: 0.3169
# Epoch 112/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4448 - val_loss: 0.2697
# Epoch 113/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4732 - val_loss: 0.2993
# Epoch 114/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4399 - val_loss: 0.2681
# Epoch 115/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4720 - val_loss: 0.2664
# Epoch 116/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4637 - val_loss: 0.2699
# Epoch 117/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4551 - val_loss: 0.2960
# Epoch 118/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4458 - val_loss: 0.2724
# Epoch 119/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4522 - val_loss: 0.2637
# Epoch 120/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4446 - val_loss: 0.3421
# Epoch 121/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4524 - val_loss: 0.3652
# Epoch 122/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4570 - val_loss: 0.2906
# Epoch 123/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4466 - val_loss: 0.3165
# Epoch 124/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4592 - val_loss: 0.2734
# Epoch 125/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4748 - val_loss: 0.3116
# Epoch 126/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4754 - val_loss: 0.3022
# Epoch 127/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4638 - val_loss: 0.3427
# Epoch 128/200
# 62/62 [==============================] - 0s 6ms/step - loss: 0.4658 - val_loss: 0.2682
# Epoch 129/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4544 - val_loss: 0.2688
# Epoch 130/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4444 - val_loss: 0.2906
# Epoch 131/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4566 - val_loss: 0.3009
# Epoch 132/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4576 - val_loss: 0.2910
# Epoch 133/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4442 - val_loss: 0.3775
# Epoch 134/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4557 - val_loss: 0.3027
# Epoch 135/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4616 - val_loss: 0.2641
# Epoch 136/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4716 - val_loss: 0.2788
# Epoch 137/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4381 - val_loss: 0.3632
# Epoch 138/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4458 - val_loss: 0.2805
# Epoch 139/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4403 - val_loss: 0.2565
# Epoch 140/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4602 - val_loss: 0.2632
# Epoch 141/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4336 - val_loss: 0.2852
# Epoch 142/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4474 - val_loss: 0.2949
# Epoch 143/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4439 - val_loss: 0.2834
# Epoch 144/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4435 - val_loss: 0.2645
# Epoch 145/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4434 - val_loss: 0.2693
# Epoch 146/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4469 - val_loss: 0.2881
# Epoch 147/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4430 - val_loss: 0.2817
# Epoch 148/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4406 - val_loss: 0.3689
# Epoch 149/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4525 - val_loss: 0.2900
# Epoch 150/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4375 - val_loss: 0.2778
# Epoch 151/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4341 - val_loss: 0.3955
# Epoch 152/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4274 - val_loss: 0.3538
# Epoch 153/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4518 - val_loss: 0.2737
# Epoch 154/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4441 - val_loss: 0.2834
# Epoch 155/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4370 - val_loss: 0.2916
# Epoch 156/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4283 - val_loss: 0.3751
# Epoch 157/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4288 - val_loss: 0.2501
# Epoch 158/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4739 - val_loss: 0.2644
# Epoch 159/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4373 - val_loss: 0.3033
# Epoch 160/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4319 - val_loss: 0.2886
# Epoch 161/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4310 - val_loss: 0.3148
# Epoch 162/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4711 - val_loss: 0.4573
# Epoch 163/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.5189 - val_loss: 0.2842
# Epoch 164/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4653 - val_loss: 0.2852
# Epoch 165/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4624 - val_loss: 0.3515
# Epoch 166/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4753 - val_loss: 0.2685
# Epoch 167/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4664 - val_loss: 0.2955
# Epoch 168/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4632 - val_loss: 0.3370
# Epoch 169/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4719 - val_loss: 0.2915
# Epoch 170/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4581 - val_loss: 0.3112
# Epoch 171/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4679 - val_loss: 0.2772
# Epoch 172/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4348 - val_loss: 0.3122
# Epoch 173/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4561 - val_loss: 0.3681
# Epoch 174/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4502 - val_loss: 0.3146
# Epoch 175/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4419 - val_loss: 0.3144
# Epoch 176/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4439 - val_loss: 0.2668
# Epoch 177/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4343 - val_loss: 0.2703
# Epoch 178/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4588 - val_loss: 0.3066
# Epoch 179/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4419 - val_loss: 0.2991
# Epoch 180/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4453 - val_loss: 0.2774
# Epoch 181/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4323 - val_loss: 0.3156
# Epoch 182/200
# 62/62 [==============================] - 0s 6ms/step - loss: 0.4474 - val_loss: 0.2698
# Epoch 183/200
# 62/62 [==============================] - 0s 6ms/step - loss: 0.4537 - val_loss: 0.2790
# Epoch 184/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4551 - val_loss: 0.2928
# Epoch 185/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4386 - val_loss: 0.2800
# Epoch 186/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4443 - val_loss: 0.2748
# Epoch 187/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4357 - val_loss: 0.3278
# Epoch 188/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4657 - val_loss: 0.2554
# Epoch 189/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4524 - val_loss: 0.2648
# Epoch 190/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4374 - val_loss: 0.3006
# Epoch 191/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4537 - val_loss: 0.5111
# Epoch 192/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4711 - val_loss: 0.4033
# Epoch 193/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4502 - val_loss: 0.3552
# Epoch 194/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4513 - val_loss: 0.3829
# Epoch 195/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4478 - val_loss: 0.3259
# Epoch 196/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4232 - val_loss: 0.4092
# Epoch 197/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4219 - val_loss: 0.2864
# Epoch 198/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4435 - val_loss: 0.3077
# Epoch 199/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4327 - val_loss: 0.3028
# Epoch 200/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4318 - val_loss: 0.2971

# %% [markdown]
# ## Model evaluation

# %%
history.history['loss'][:10]
# Out:
# [1.0529992580413818,
#  0.806546151638031,
#  0.6795642971992493,
#  0.6191343665122986,
#  0.5708767175674438,
#  0.5595381855964661,
#  0.5754373073577881,
#  0.5737779140472412,
#  0.5308009386062622,
#  0.5687131285667419]

# %%
# model.evaluate(x_test, y_test)
loss = model.evaluate(x_test, y_test)

# 绘制训练历史
plt.plot(history.history['loss'][10:], label='Training loss')
plt.plot(history.history['val_loss'][10:], label='Validation loss')
plt.legend()
plt.show()
# Out:
# 2/2 [==============================] - 0s 7ms/step - loss: 0.5435

# %%
def plot_scatter (x, y, title, x_label, y_label,n):
    # plt.subplot(2, 2, n);
    plt.figure(figsize=(5, 5));
    plt.plot(x, x, color="blue", label="d")
    plt.scatter(x, y, marker="x", color="red")
    # plt.axis((0,210, 0,210))
    plt.title(title)
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.show()

y_pred = model.predict(x_test)
plot_scatter(y_test, y_pred, "Testing set", "True value", "Pred. value",1)

y_pred = model.predict(x_train)
plot_scatter(y_train, y_pred, "Training set", "True value", "Pred. value",2)
# Out:
# 2/2 [==============================] - 0s 7ms/step
# 5/5 [==============================] - 0s 4ms/step

# %%
print((y_train))
print(x_train,y_pred)
# Out:
# 3     30
# 0     45
# 35    36
# 24    48
# 18    26
# 8     40
# 5     60
# 21    78
# 29    41
# 22    63
# 31    60
# 9     28
# 19    31
# 7     70
# 1     80
# 10    32
# 6     50
# 11    48
# 28    29
# 30    76
# 27    24
# 14    62
# 25    68
# 15    55
# 12    84
# 4     65
# 16    72
# 26    38
# Name: Salary, dtype: int32
#     YearsExperience  EducationLevel_大學  EducationLevel_碩士以上  City_城市A  \
# 3                 5                  0                    0         1
# 0                 3                  1                    0         1
# 35                4                  1                    0         1
# 24                8                  1                    0         0
# 18                2                  0                    0         1
# 8                 4                  1                    0         1
# 5                 1                  0                    1         0
# 21                7                  0                    1         0
# 29                3                  1                    0         1
# 22               10                  0                    1         0
# 31               10                  0                    1         0
# 9                 2                  0                    0         1
# 19                5                  0                    0         1
# 7                 6                  0                    1         1
# 1                 7                  0                    1         0
# 10                5                  0                    0         1
# 6                 8                  1                    0         0
# 11                3                  1                    0         1
# 28                5                  0                    0         1
# 30                7                  0                    1         0
# 27                2                  0                    0         1
# 14                1                  0                    1         0
# 25                6                  0                    1         1
# 15                8                  1                    0         0
# 12                7                  0                    1         0
# 4                10                  0                    1         0
# 16                6                  0                    1         1
# 26                4                  1                    0         1
#
#     City_城市B
# 3          0
# 0          0
# 35         0
# 24         0
# 18         0
# 8          0
# 5          0
# 21         0
# 29         0
# 22         1
# 31         1
# 9          0
# 19         0
# 7          0
# 1          0
# 10         0
# 6          0
# 11         0
# 28         0
# 30         0
# 27         0
# 14         0
# 25         0
# 15         0
# 12         0
# 4          1
# 16         0
# 26         0   [[31.025942]
#  [40.24463 ]
#  [42.08697 ]
#  [50.795795]
#  [25.498907]
#  [42.08697 ]
#  [63.891804]
#  [74.94588 ]
#  [40.24463 ]
#  [61.1484  ]
#  [61.1484  ]
#  [25.498907]
#  [31.025942]
#  [71.76408 ]
#  [74.94588 ]
#  [31.025942]
#  [50.795795]
#  [40.24463 ]
#  [31.025942]
#  [74.94588 ]
#  [25.498907]
#  [63.891804]
#  [71.76408 ]
#  [50.795795]
#  [74.94588 ]
#  [61.1484  ]
#  [71.76408 ]
#  [42.08697 ]]

# %%
y_pred = model.predict(x_train)
plt.scatter(x_train['YearsExperience'], y_train, color='red', label='Actual values')
plt.scatter(x_train['YearsExperience'], y_pred, color='blue', marker='x', label='Predicted values')
plt.title('training set')
plt.legend()
plt.show()


# 使用模型进行预测
# y_pred = model.predict(x_test)
# # 可视化真实值与预测值
# plt.scatter(x_test, y_test, color='red', label='Actual values')
# plt.scatter(x_test, y_pred, color='blue', marker='x', label='Predicted values')
# plt.title('testing set')
# plt.legend()
# plt.show()
# Out:
# 1/1 [==============================] - 0s 55ms/step

# %% [markdown]
# ### Exercise : Please try to write R2 and Pearson correlation function for evaluating the training model

# %% [markdown]
# ## Coefficient of determination, denoted R2
# R2值衡量的是模型解釋的"變異"量相對於總變異量的比例。R2=1意味著模型完美地擬合了數據，能夠解釋所有的變異性；而R2=0代表著模型沒有解釋任何變異量，即它未能捕捉到y和y^之間的任何關係，意味著線性模型沒有提供超越基線模型（即常數模型，這個模型預測的 y 值對於所有觀察值都是 y 的平均值）的預測能力
#
# ![image.png](attachment:00a7e8b4-11f6-4d8c-8d02-eee9ae546c1a.png)
#
# https://en.wikipedia.org/wiki/Coefficient_of_determination
#
# https://www.ncl.ac.uk/webtemplate/ask-assets/external/maths-resources/statistics/regression-and-correlation/coefficient-of-determination-r-squared.html

# %%
from sklearn.metrics import r2_score
y_pred = model.predict(x_test)
r2_test = r2_score(y_test, y_pred)

y_pred = model.predict(x_train)
r2_train = r2_score(y_train, y_pred)

print(r2_train, r2_test)
# Out:
# 2/2 [==============================] - 0s 10ms/step
# 5/5 [==============================] - 0s 7ms/step
# 0.5436651064817377 0.45754326678033475

# %% [markdown]
# ## Pearson correlation function
# #### The Pearson correlation measures the strength of the linear relationship between two variables. It has a value between -1 to 1, with a value of -1 meaning a total negative linear correlation, 0 being no correlation, and + 1 meaning a total positive correlation.
#
# ![image.png](attachment:891bbceb-b815-4fd3-af18-067c0046a1a3.png)

# %% [markdown]
# 餘弦相似度的定義是兩個向量的點積除以這兩個向量模的乘積：
#
# ![image.png](attachment:533369cc-d3bb-4647-b383-0cd3fcd26886.png)
# ​

# %%
from sklearn.datasets import make_regression
from sklearn.feature_selection import r_regression

y_pred = model.predict(x_test)
psc_test = r_regression(y_test.to_numpy().reshape(-1, 1) , y_pred.ravel())[0]
y_pred = model.predict(x_train)
psc_train = r_regression(y_train.to_numpy().reshape(-1, 1), y_pred.ravel())[0]
print(psc_test, psc_train)
# Out:
# 2/2 [==============================] - 0s 7ms/step
# 0.7428825043827453
# 5/5 [==============================] - 0s 3ms/step
# 0.7428825043827453 0.7383426008418558
