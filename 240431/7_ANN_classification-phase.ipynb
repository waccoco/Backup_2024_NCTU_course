# %% [markdown]
# ## Data Preparation

# %%
import pandas as pd

output_path = './2018_HEAphase_dataset.csv'
path = output_path
df = pd.read_csv(output_path)
display(df.head())
# Out:
#       Alloy  No Component Fraction       a   delta           Tm    D_Tm  \
# 0     AlB12   2      Al B     1 12  0.8671  0.1881  2239.190000  376.93
# 1      B4Co   2     B Co       4 1  0.9062  0.1902  2232.000000  232.00
# 2      AlB2   2      Al B      1 2  1.0240  0.2817  1876.490000  666.82
# 3  B6Co2Nb2   3   B Co Nb    6 2 2  1.0280  0.2538  2312.400000  313.58
# 4      HfB2   2      Hf B      1 2  1.0727  0.3331  2400.666667   74.48
#
#       Hmix   σHmix  ...  Phase  Phase_inshort  AM？  IM?  SS? Phase_3  Ref  \
# 0   0.0000  0.0000  ...     IM             IM    0    1    0     2.0  NaN
# 1 -15.3600  3.4560  ...     IM             IM    0    1    0     2.0  NaN
# 2   0.0000  0.0000  ...     IM             IM    0    1    0     2.0  NaN
# 3 -41.4400  8.1388  ...     IM             IM    0    1    0     2.0  NaN
# 4 -58.6667  3.4570  ...     IM             IM    0    1    0     2.0  NaN
#
#    From Size  Method
# 0  三元相图  123     NaN
# 1  三元相图  NaN     NaN
# 2  三元相图  NaN     NaN
# 3  三元相图  123     NaN
# 4  三元相图  NaN     NaN
#
# [5 rows x 27 columns]

# %%
df.info()
df.describe(include='all').round(2)

#round 函数在 Python（包括 Pandas 库中）的功能是对浮点数进行四舍五入到给定的精度。
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 601 entries, 0 to 600
# Data columns (total 27 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Alloy          601 non-null    object
#  1   No             601 non-null    int64
#  2   Component      601 non-null    object
#  3   Fraction       601 non-null    object
#  4   a              601 non-null    float64
#  5   delta          601 non-null    float64
#  6   Tm             601 non-null    float64
#  7   D_Tm           601 non-null    float64
#  8   Hmix           601 non-null    float64
#  9   σHmix          601 non-null    float64
#  10  Sid            601 non-null    float64
#  11  Elec_nega      601 non-null    float64
#  12  D_elec_nega    601 non-null    float64
#  13  VEC            601 non-null    float64
#  14  d_VEC          601 non-null    float64
#  15  BulkModulus    601 non-null    object
#  16  D_Bulk         601 non-null    float64
#  17  Phase          601 non-null    object
#  18  Phase_inshort  601 non-null    object
#  19  AM？            601 non-null    int64
#  20  IM?            601 non-null    int64
#  21  SS?            601 non-null    int64
#  22  Phase_3        537 non-null    float64
#  23  Ref            333 non-null    object
#  24  From           601 non-null    object
#  25  Size           4 non-null      object
#  26  Method         2 non-null      object
# dtypes: float64(13), int64(4), object(10)
# memory usage: 126.9+ KB
#                 Alloy      No          Component   Fraction       a   delta  \
# count             601  601.00                601        601  601.00  601.00
# unique            599     NaN                362        357     NaN     NaN
# top     Ti2CrCuFeCoNi     NaN  Al Co Cr Cu Fe Ni  1 1 1 1 1     NaN     NaN
# freq                2     NaN                 15         44     NaN     NaN
# mean              NaN    3.88                NaN        NaN    1.38    0.08
# std               NaN    1.60                NaN        NaN    0.14    0.05
# min               NaN    2.00                NaN        NaN    0.87    0.00
# 25%               NaN    2.00                NaN        NaN    1.29    0.05
# 50%               NaN    4.00                NaN        NaN    1.37    0.07
# 75%               NaN    5.00                NaN        NaN    1.45    0.11
# max               NaN    9.00                NaN        NaN    1.83    0.33
#
#              Tm     D_Tm    Hmix   σHmix  ...  Phase  Phase_inshort     AM？  \
# count    601.00   601.00  601.00  601.00  ...    601            601  601.00
# unique      NaN      NaN     NaN     NaN  ...     32              5     NaN
# top         NaN      NaN     NaN     NaN  ...     IM             IM     NaN
# freq        NaN      NaN     NaN     NaN  ...    243            248     NaN
# mean    1599.59   336.41  -16.11    5.27  ...    NaN            NaN    0.28
# std      436.22   155.00   14.24    4.02  ...    NaN            NaN    0.45
# min      437.54     5.13  -76.44    0.00  ...    NaN            NaN    0.00
# 25%     1254.10   234.54  -25.59    1.84  ...    NaN            NaN    0.00
# 50%     1675.59   334.60  -12.99    5.24  ...    NaN            NaN    0.00
# 75%     1851.34   412.42   -4.80    7.77  ...    NaN            NaN    1.00
# max     3298.67  1190.55    9.90   33.99  ...    NaN            NaN    1.00
#
#            IM?     SS? Phase_3  Ref  From Size               Method
# count   601.00  601.00  537.00  333   601    4                    2
# unique     NaN     NaN     NaN   96    15    3                    1
# top        NaN     NaN     NaN    9  三元相图  123  Copper mold casting
# freq       NaN     NaN     NaN   29   213    2                    2
# mean      0.51    0.30    1.93  NaN   NaN  NaN                  NaN
# std       0.50    0.46    0.74  NaN   NaN  NaN                  NaN
# min       0.00    0.00    1.00  NaN   NaN  NaN                  NaN
# 25%       0.00    0.00    1.00  NaN   NaN  NaN                  NaN
# 50%       1.00    0.00    2.00  NaN   NaN  NaN                  NaN
# 75%       1.00    1.00    2.00  NaN   NaN  NaN                  NaN
# max       1.00    1.00    3.00  NaN   NaN  NaN                  NaN
#
# [11 rows x 27 columns]

# %%
set(df)
# Out:
# {'AM？',
#  'Alloy',
#  'BulkModulus',
#  'Component',
#  'D_Bulk',
#  'D_Tm',
#  'D_elec_nega',
#  'Elec_nega',
#  'Fraction',
#  'From',
#  'Hmix',
#  'IM?',
#  'Method',
#  'No',
#  'Phase',
#  'Phase_3',
#  'Phase_inshort',
#  'Ref',
#  'SS?',
#  'Sid',
#  'Size',
#  'Tm',
#  'VEC',
#  'a',
#  'd_VEC',
#  'delta',
#  'σHmix'}

# %%
# import numpy as np
# import pandas as pd
# import matplotlib.pyplot as plt
# from sklearn.model_selection import train_test_split

df_y= df['Phase_inshort']
df_x= df.drop(columns=['Fraction','No','AM？',
 'Alloy',
 'BulkModulus',
 'Component','From','Phase_inshort','Phase',
 'Ref',
 'SS?','Size', 'Method','Phase_3', 'IM?'])
display(df_x.head(5))
# print(set(x), set(y))
# Out:
#         a   delta           Tm    D_Tm     Hmix   σHmix     Sid  Elec_nega  \
# 0  0.8671  0.1881  2239.190000  376.93   0.0000  0.0000  0.2712     2.0069
# 1  0.9062  0.1902  2232.000000  232.00 -15.3600  3.4560  0.5004     2.0080
# 2  1.0240  0.2817  1876.490000  666.82   0.0000  0.0000  0.6365     1.8967
# 3  1.0280  0.2538  2312.400000  313.58 -41.4400  8.1388  0.9503     1.9200
# 4  1.0727  0.3331  2400.666667   74.48 -58.6667  3.4570  0.6365     1.7933
#
#    D_elec_nega     VEC   d_VEC    D_Bulk
# 0       0.1146  3.0000  0.0000   65.0185
# 1       0.0640  4.2000  2.4000   56.0000
# 2       0.2027  3.0000  0.0000  115.0227
# 3       0.1716  4.6000  2.3324   71.1056
# 4       0.3488  3.3333  0.4714   98.9949

# %%
display()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, StandardScaler, LabelEncoder

# encoder = OneHotEncoder()
# phase_encoded = encoder.fit_transform(df[['Phase']]).toarray()

scaler = StandardScaler()
# scaled_features = scaler.fit_transform(x[['YearsExperience', 'Salary']])
scaled_features = scaler.fit_transform(df_x)

label_encoder = LabelEncoder()
labels = label_encoder.fit_transform(df['Phase_inshort'])

x = scaled_features
y = labels
# display(x.head(5))

# %%
set(df['Phase_inshort'])
# Out:
# {'AM', 'AM+IM', 'IM', 'IM+SS', 'SS'}

# %%
# splitting dataset to training set and testing set 
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=200)

# %% [markdown]
# ##  data visualization

# %% [markdown]
# ## Build ANN model

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam

# model = Sequential([
    # Dense(1, input_shape=(1,), activation='linear')
#     Dense(5, input_shape=(x.shape[1],), activation='linear')
# ])

model = Sequential([
    Dense(8, input_shape=(x.shape[1],), activation='relu'),
    Dense(6, activation='relu'),
    Dense(5, activation='softmax')
])

# Sequential.help

model.compile(optimizer=Adam(learning_rate=0.005), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ## Training ANN model

# %%
from tensorflow.keras.callbacks import EarlyStopping

# early_stop = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)
history = model.fit(x_train, y_train, validation_split=0.2, epochs=20, batch_size=2)
# Out:
# Epoch 1/20
# 192/192 [==============================] - 3s 6ms/step - loss: 1.1201 - accuracy: 0.5000 - val_loss: 0.8773 - val_accuracy: 0.6562
# Epoch 2/20
# 192/192 [==============================] - 1s 4ms/step - loss: 0.7178 - accuracy: 0.7604 - val_loss: 0.6379 - val_accuracy: 0.7917
# Epoch 3/20
# 192/192 [==============================] - 1s 4ms/step - loss: 0.5975 - accuracy: 0.7865 - val_loss: 0.6117 - val_accuracy: 0.7500
# Epoch 4/20
# 192/192 [==============================] - 1s 5ms/step - loss: 0.5453 - accuracy: 0.8073 - val_loss: 0.5743 - val_accuracy: 0.7708
# Epoch 5/20
# 192/192 [==============================] - 1s 5ms/step - loss: 0.5067 - accuracy: 0.8177 - val_loss: 0.5349 - val_accuracy: 0.8229
# Epoch 6/20
# 192/192 [==============================] - 1s 5ms/step - loss: 0.4765 - accuracy: 0.8203 - val_loss: 0.5305 - val_accuracy: 0.7708
# Epoch 7/20
# 192/192 [==============================] - 1s 5ms/step - loss: 0.4676 - accuracy: 0.8099 - val_loss: 0.5617 - val_accuracy: 0.8125
# Epoch 8/20
# 192/192 [==============================] - 1s 4ms/step - loss: 0.4306 - accuracy: 0.8255 - val_loss: 0.5369 - val_accuracy: 0.8229
# Epoch 9/20
# 192/192 [==============================] - 1s 4ms/step - loss: 0.4190 - accuracy: 0.8385 - val_loss: 0.5789 - val_accuracy: 0.8021
# Epoch 10/20
# 192/192 [==============================] - 1s 4ms/step - loss: 0.4104 - accuracy: 0.8438 - val_loss: 0.5547 - val_accuracy: 0.8333
# Epoch 11/20
# 192/192 [==============================] - 1s 4ms/step - loss: 0.3961 - accuracy: 0.8490 - val_loss: 0.5637 - val_accuracy: 0.8333
# Epoch 12/20
# 192/192 [==============================] - 1s 4ms/step - loss: 0.3953 - accuracy: 0.8411 - val_loss: 0.5575 - val_accuracy: 0.8542
# Epoch 13/20
# 192/192 [==============================] - 1s 4ms/step - loss: 0.3767 - accuracy: 0.8464 - val_loss: 0.5551 - val_accuracy: 0.8333
# Epoch 14/20
# 192/192 [==============================] - 1s 4ms/step - loss: 0.3652 - accuracy: 0.8594 - val_loss: 0.5417 - val_accuracy: 0.8333
# Epoch 15/20
# 192/192 [==============================] - 1s 4ms/step - loss: 0.3507 - accuracy: 0.8620 - val_loss: 0.5634 - val_accuracy: 0.8333
# Epoch 16/20
# 192/192 [==============================] - 1s 4ms/step - loss: 0.3443 - accuracy: 0.8672 - val_loss: 0.5584 - val_accuracy: 0.8229
# Epoch 17/20
# 192/192 [==============================] - 1s 5ms/step - loss: 0.3335 - accuracy: 0.8672 - val_loss: 0.5665 - val_accuracy: 0.8646
# Epoch 18/20
# 192/192 [==============================] - 1s 4ms/step - loss: 0.3433 - accuracy: 0.8724 - val_loss: 0.6271 - val_accuracy: 0.8333
# Epoch 19/20
# 192/192 [==============================] - 1s 4ms/step - loss: 0.3388 - accuracy: 0.8620 - val_loss: 0.5844 - val_accuracy: 0.8646
# Epoch 20/20
# 192/192 [==============================] - 1s 4ms/step - loss: 0.3116 - accuracy: 0.8854 - val_loss: 0.5799 - val_accuracy: 0.8438

# %% [markdown]
# ## Model evaluation

# %%
history.history['loss'][:10]
# Out:
# [1.2885864973068237,
#  0.789177656173706,
#  0.6506104469299316,
#  0.5748196244239807,
#  0.5282263159751892,
#  0.4947853088378906,
#  0.4732189476490021,
#  0.4557848870754242,
#  0.43759575486183167,
#  0.42233631014823914]

# %%
# model.evaluate(x_test, y_test)
loss = model.evaluate(x_test, y_test)

# 繪製訓練歷史
plt.plot(history.history['loss'][10:], label='Training loss')
plt.plot(history.history['val_loss'][10:], label='Validation loss')
plt.legend()
plt.show()
# Out:
# 4/4 [==============================] - 0s 6ms/step - loss: 0.4467 - accuracy: 0.8099

# %%
loss, accuracy = model.evaluate(x_test, y_test)
print(f'Accuracy: {accuracy*100}%')
# Out:
# 4/4 [==============================] - 0s 5ms/step - loss: 0.4467 - accuracy: 0.8099
# Accuracy: 80.99173307418823%

# %%
y_pred = model.predict(x_test)
print((y_pred),(y_test))
# Out:
# 4/4 [==============================] - 0s 3ms/step
#   8.49705929e-15]
#  [1.56250760e-01 1.54934764e-01 1.60842523e-01 3.18657905e-01
#   2.09314048e-01]
#  [2.08284985e-02 5.83621487e-03 1.28319981e-02 1.88141078e-01
#   7.72362232e-01]
#  [9.55233403e-09 6.84220822e-12 9.99999940e-01 1.59163860e-14
#   4.24229743e-14]
#  [8.27546325e-03 1.90495498e-07 9.91681874e-01 4.20185279e-05
#   3.28928962e-07]
#  [6.85162306e-01 3.45165790e-05 3.14797193e-01 5.88703551e-06
#   9.94916562e-12]
#  [9.93677974e-01 7.57714675e-04 5.52670937e-03 3.75485870e-05
#   1.01224096e-08]
#  [1.79183587e-01 2.10849702e-01 3.10005695e-01 2.11657733e-01
#   8.83033872e-02]
#  [6.09803736e-01 2.41204805e-04 3.89952272e-01 2.84648399e-06
#   7.30562486e-12]
#  [5.31724701e-03 9.46748884e-08 9.94675696e-01 6.89781564e-06
#   1.16671028e-08]
#  [3.72453220e-02 1.44246658e-02 2.78353989e-02 2.50685453e-01
#   6.69809163e-01]
#  [1.12679263e-03 6.95565250e-05 3.11879376e-06 1.44893631e-01
#   8.53906870e-01]
#  [3.43835354e-01 1.39405325e-01 5.02383649e-01 1.39173064e-02
#   4.58310358e-04]
#  [1.15142539e-01 9.19392258e-02 7.71709159e-02 3.93232167e-01
#   3.22515100e-01]
#  [9.99263048e-01 1.44367106e-04 5.75477781e-04 1.71070988e-05
#   5.15517717e-09]
#  [1.32677844e-04 3.12090544e-12 9.99867439e-01 7.35054195e-09
#   5.84210906e-15]
#  [7.98590064e-01 3.86691427e-05 1.94272056e-01 7.09827663e-03
#   9.14743907e-07]
#  [1.03885094e-02 1.40198870e-04 1.00617704e-04 1.18779659e-01
#   8.70591044e-01]
#  [6.09625578e-02 3.29872929e-02 2.53475942e-02 3.82643044e-01
#   4.98059452e-01]
#  [1.29492357e-01 1.05045497e-01 1.15505174e-01 3.48779291e-01
#   3.01177651e-01]
#  [3.34861837e-02 2.20298723e-04 9.61922109e-01 3.77483829e-03
#   5.96470374e-04]
#  [4.36480609e-11 2.83453596e-14 9.99999940e-01 1.09379403e-16
#   6.26008678e-15]
#  [2.45021170e-07 3.74504472e-09 9.99999762e-01 4.75553347e-11
#   5.72846492e-10]] [0 2 2 2 2 2 2 2 0 4 0 0 3 0 0 4 0 2 0 0 4 2 2 0 2 0 4 2 0 0 2 2 2 0 2 2 4
#  2 4 4 2 4 2 0 3 0 2 4 4 2 0 4 2 2 3 2 2 4 2 2 2 2 2 4 2 0 0 3 0 4 3 0 2 2
#  4 2 4 0 4 0 2 0 2 2 2 2 0 4 4 3 2 2 3 2 4 2 2 0 0 3 4 2 2 0 0 3 2 2 4 4 2
#  3 0 2 2 4 4 3 2 2 2]

# %%
def plot_scatter (x, y, title, x_label, y_label,n):
    # plt.subplot(2, 2, n);
    plt.figure(figsize=(5, 5));
    plt.scatter(x, y, marker="x", color="red")
    # plt.axis((0,210, 0,210))
    plt.title(title)
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.show()

y_pred = model.predict(x_test)
y_pred = np.argmax(y_pred, axis=1)


plot_scatter(y_test, y_pred, "Testing set", "True value", "Pred. value",1)

y_pred = model.predict(x_train)
y_pred = np.argmax(y_pred, axis=1)

plot_scatter(y_train, y_pred, "Training set", "True value", "Pred. value",2)
# Out:
# 4/4 [==============================] - 0s 6ms/step
# 15/15 [==============================] - 0s 3ms/step

# %%
from sklearn.metrics import confusion_matrix

y_pred = model.predict(x_train)
y_pred = np.argmax(y_pred, axis=1)
cm = confusion_matrix(y_train, y_pred)

# 打印混淆矩陣
print("Confusion Matrix:")
print(cm)
# Out:
# 15/15 [==============================] - 0s 3ms/step
# Confusion Matrix:
# [[127   0   4   2   2]
#  [  3   2   1   0   0]
#  [ 19   1 168   0   5]
#  [  1   3   0  19  17]
#  [  2   0   0   3 101]]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# 繪製混淆矩陣的熱圖
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()
