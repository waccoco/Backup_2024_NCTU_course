# %%
https://ithelp.ithome.com.tw/articles/10228941
https://medium.com/nlp-tsupei/precision-recall-f1-score%E7%B0%A1%E5%96%AE%E4%BB%8B%E7%B4%B9-f87baa82a47
https://medium.com/ai%E5%8F%8D%E6%96%97%E5%9F%8E/learning-model-%E4%BB%80%E9%BA%BC%E6%98%AFroc%E5%92%8Cauc-%E8%BD%89%E9%8C%84-33aafe644cf

# %% [markdown]
# ## Data Preparation

# %%
# install scikit-learn, tensorflow, pandas, matplotlib, numpy
# Out:
# 'conda' 不是內部或外部命令、可執行的程式或批次檔。

# %%
import pandas as pd

output_path = './Salary_Data2.csv'
path = output_path
df = pd.read_csv(output_path)
display(df.head())
# Out:
#    YearsExperience EducationLevel City  Salary
# 0              3.0             大學  城市A    45.9
# 1              7.8           碩士以上  城市C    80.5
# 2              2.3           高中以下  城市A    25.2
# 3              5.1           高中以下  城市A    30.4
# 4             10.0           碩士以上  城市B    65.7

# %%
df.info()
df.describe(include='all').round(2)

#round 函数在 Python（包括 Pandas 库中）的功能是对浮点数进行四舍五入到给定的精度。
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  36 non-null     float64
#  1   EducationLevel   36 non-null     object
#  2   City             36 non-null     object
#  3   Salary           36 non-null     float64
# dtypes: float64(2), object(2)
# memory usage: 1.2+ KB
#         YearsExperience EducationLevel City  Salary
# count             36.00             36   36   36.00
# unique              NaN              3    3     NaN
# top                 NaN           碩士以上  城市A     NaN
# freq                NaN             16   20     NaN
# mean               5.47            NaN  NaN   51.70
# std                2.71            NaN  NaN   17.53
# min                1.20            NaN  NaN   24.90
# 25%                3.38            NaN  NaN   38.05
# 50%                5.15            NaN  NaN   49.20
# 75%                7.65            NaN  NaN   65.75
# max               10.00            NaN  NaN   84.20

# %% [markdown]
# ## Transform the Categorical data to numerical data
# ### @ LabelEncoder：把類別型資料轉換成0,1,2,…的數值標籤 (特徵之間有順序或大小分別)
#    ![image.png](attachment:c86e50e9-fb01-44f3-8d23-a9548281d397.png)
#
# ### @ OneHotEncoder：把類別型資料轉換成0與1的數值標籤 (特徵之間沒有順序或大小分別)
# ![image.png](attachment:f9460b51-747e-473b-9324-c386e4bf5edc.png)
#
# ### Exercise : Try to use the one-hot encoder to encode the Categorical data into numerical data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

########################################################
df_encoded = pd.get_dummies(df, columns=['EducationLevel', 'City'])
# 假設df是已經通過get_dummies轉換後的DataFrame，且包含布林值
# 轉換布林值為整數
df_encoded = df_encoded.astype(int)
########################################################

# 顯示轉換後的DataFrame
display(df_encoded.head(5))
# Out:
#    YearsExperience  Salary  EducationLevel_大學  EducationLevel_碩士以上  \
# 0                3      45                  1                    0
# 1                7      80                  0                    1
# 2                2      25                  0                    0
# 3                5      30                  0                    0
# 4               10      65                  0                    1
#
#    EducationLevel_高中以下  City_城市A  City_城市B  City_城市C
# 0                    0         1         0         0
# 1                    0         0         0         1
# 2                    1         1         0         0
# 3                    1         1         0         0
# 4                    0         0         1         0

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, StandardScaler, LabelEncoder

encoder = OneHotEncoder()
city_encoded = encoder.fit_transform(df[['City']]).toarray()

scaler = StandardScaler()
scaled_features = scaler.fit_transform(df[['YearsExperience', 'Salary']])

label_encoder = LabelEncoder()
labels = label_encoder.fit_transform(df['EducationLevel'])
# labels = encoder.fit_transform(df[['EducationLevel']]).toarray()

x = np.hstack([scaled_features, city_encoded])
y = labels
# display(x.head(5))

# %%
display(y)
# Out:
# array([0, 1, 2, 2, 1, 1, 0, 1, 0, 2, 2, 0, 1, 1, 1, 0, 1, 0, 2, 2, 0, 1,
#        1, 1, 0, 1, 0, 2, 2, 0, 1, 1, 1, 0, 1, 0])

# %%
# splitting dataset to training set and testing set 
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=200)

# %% [markdown]
# ##  data visualization

# %% [markdown]
# ## Build ANN model

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam

# model = Sequential([
    # Dense(1, input_shape=(1,), activation='linear')
#     Dense(5, input_shape=(x.shape[1],), activation='linear')
# ])

model = Sequential([
    Dense(8, input_shape=(x.shape[1],), activation='relu'),
    Dense(6, activation='relu'),
    Dense(3, activation='softmax')
])

# Sequential.help

model.compile(optimizer=Adam(learning_rate=0.005), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ## Training ANN model

# %%
from tensorflow.keras.callbacks import EarlyStopping

# early_stop = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)
history = model.fit(x_train, y_train, validation_split=0.2, epochs=200, batch_size=2)
# Out:
# Epoch 1/200
# 11/11 [==============================] - 2s 71ms/step - loss: 1.1456 - accuracy: 0.2727 - val_loss: 1.1101 - val_accuracy: 0.1667
# Epoch 2/200
# 11/11 [==============================] - 0s 7ms/step - loss: 1.0531 - accuracy: 0.6364 - val_loss: 1.0470 - val_accuracy: 0.3333
# Epoch 3/200
# 11/11 [==============================] - 0s 10ms/step - loss: 0.9836 - accuracy: 0.6364 - val_loss: 0.9897 - val_accuracy: 0.6667
# Epoch 4/200
# 11/11 [==============================] - 0s 11ms/step - loss: 0.9031 - accuracy: 0.5909 - val_loss: 0.9297 - val_accuracy: 0.6667
# Epoch 5/200
# 11/11 [==============================] - 0s 10ms/step - loss: 0.8353 - accuracy: 0.5909 - val_loss: 0.8695 - val_accuracy: 0.6667
# Epoch 6/200
# 11/11 [==============================] - 0s 9ms/step - loss: 0.7572 - accuracy: 0.6364 - val_loss: 0.7866 - val_accuracy: 0.6667
# Epoch 7/200
# 11/11 [==============================] - 0s 10ms/step - loss: 0.6894 - accuracy: 0.6364 - val_loss: 0.7187 - val_accuracy: 0.6667
# Epoch 8/200
# 11/11 [==============================] - 0s 10ms/step - loss: 0.6219 - accuracy: 0.7273 - val_loss: 0.6570 - val_accuracy: 0.6667
# Epoch 9/200
# 11/11 [==============================] - 0s 14ms/step - loss: 0.5642 - accuracy: 0.7273 - val_loss: 0.5988 - val_accuracy: 0.6667
# Epoch 10/200
# 11/11 [==============================] - 0s 10ms/step - loss: 0.5195 - accuracy: 0.7727 - val_loss: 0.5607 - val_accuracy: 0.6667
# Epoch 11/200
# 11/11 [==============================] - 0s 9ms/step - loss: 0.4676 - accuracy: 0.8636 - val_loss: 0.5194 - val_accuracy: 0.6667
# Epoch 12/200
# 11/11 [==============================] - 0s 10ms/step - loss: 0.4249 - accuracy: 0.8636 - val_loss: 0.4668 - val_accuracy: 0.6667
# Epoch 13/200
# 11/11 [==============================] - 0s 10ms/step - loss: 0.3837 - accuracy: 0.8636 - val_loss: 0.4345 - val_accuracy: 0.6667
# Epoch 14/200
# 11/11 [==============================] - 0s 11ms/step - loss: 0.3534 - accuracy: 0.9091 - val_loss: 0.3841 - val_accuracy: 0.6667
# Epoch 15/200
# 11/11 [==============================] - 0s 10ms/step - loss: 0.3223 - accuracy: 0.8636 - val_loss: 0.3865 - val_accuracy: 0.6667
# Epoch 16/200
# 11/11 [==============================] - 0s 9ms/step - loss: 0.2869 - accuracy: 0.9091 - val_loss: 0.3501 - val_accuracy: 0.6667
# Epoch 17/200
# 11/11 [==============================] - 0s 9ms/step - loss: 0.2656 - accuracy: 0.9545 - val_loss: 0.3063 - val_accuracy: 0.6667
# Epoch 18/200
# 11/11 [==============================] - 0s 11ms/step - loss: 0.2344 - accuracy: 0.9545 - val_loss: 0.2894 - val_accuracy: 0.6667
# Epoch 19/200
# 11/11 [==============================] - 0s 10ms/step - loss: 0.2189 - accuracy: 0.9545 - val_loss: 0.2838 - val_accuracy: 0.8333
# Epoch 20/200
# 11/11 [==============================] - 0s 10ms/step - loss: 0.2005 - accuracy: 0.9545 - val_loss: 0.2505 - val_accuracy: 1.0000
# Epoch 21/200
# 11/11 [==============================] - 0s 9ms/step - loss: 0.1987 - accuracy: 0.9545 - val_loss: 0.2522 - val_accuracy: 0.8333
# Epoch 22/200
# 11/11 [==============================] - 0s 9ms/step - loss: 0.1663 - accuracy: 0.9545 - val_loss: 0.2044 - val_accuracy: 1.0000
# Epoch 23/200
# 11/11 [==============================] - 0s 10ms/step - loss: 0.1543 - accuracy: 0.9545 - val_loss: 0.1980 - val_accuracy: 1.0000
# Epoch 24/200
# 11/11 [==============================] - 0s 9ms/step - loss: 0.1373 - accuracy: 0.9545 - val_loss: 0.1999 - val_accuracy: 1.0000
# Epoch 25/200
# 11/11 [==============================] - 0s 10ms/step - loss: 0.1313 - accuracy: 0.9545 - val_loss: 0.1952 - val_accuracy: 1.0000
# Epoch 26/200
# 11/11 [==============================] - 0s 10ms/step - loss: 0.1192 - accuracy: 0.9545 - val_loss: 0.1724 - val_accuracy: 1.0000
# Epoch 27/200
# 11/11 [==============================] - 0s 9ms/step - loss: 0.1126 - accuracy: 0.9545 - val_loss: 0.1550 - val_accuracy: 1.0000
# Epoch 28/200
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0992 - accuracy: 1.0000 - val_loss: 0.1694 - val_accuracy: 1.0000
# Epoch 29/200
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0963 - accuracy: 0.9545 - val_loss: 0.1491 - val_accuracy: 1.0000
# Epoch 30/200
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0920 - accuracy: 1.0000 - val_loss: 0.1347 - val_accuracy: 1.0000
# Epoch 31/200
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0875 - accuracy: 0.9545 - val_loss: 0.1542 - val_accuracy: 1.0000
# Epoch 32/200
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0735 - accuracy: 1.0000 - val_loss: 0.1252 - val_accuracy: 1.0000
# Epoch 33/200
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0786 - accuracy: 1.0000 - val_loss: 0.1207 - val_accuracy: 1.0000
# Epoch 34/200
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0659 - accuracy: 1.0000 - val_loss: 0.1227 - val_accuracy: 1.0000
# Epoch 35/200
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0676 - accuracy: 1.0000 - val_loss: 0.1130 - val_accuracy: 1.0000
# Epoch 36/200
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0664 - accuracy: 0.9545 - val_loss: 0.1341 - val_accuracy: 1.0000
# Epoch 37/200
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0639 - accuracy: 0.9545 - val_loss: 0.0981 - val_accuracy: 1.0000
# Epoch 38/200
# 11/11 [==============================] - 0s 11ms/step - loss: 0.0576 - accuracy: 1.0000 - val_loss: 0.1123 - val_accuracy: 1.0000
# Epoch 39/200
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0543 - accuracy: 1.0000 - val_loss: 0.0880 - val_accuracy: 1.0000
# Epoch 40/200
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0474 - accuracy: 1.0000 - val_loss: 0.0983 - val_accuracy: 1.0000
# Epoch 41/200
# 11/11 [==============================] - 0s 12ms/step - loss: 0.0470 - accuracy: 1.0000 - val_loss: 0.0960 - val_accuracy: 1.0000
# Epoch 42/200
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0432 - accuracy: 1.0000 - val_loss: 0.0853 - val_accuracy: 1.0000
# Epoch 43/200
# 11/11 [==============================] - 0s 12ms/step - loss: 0.0396 - accuracy: 1.0000 - val_loss: 0.0857 - val_accuracy: 1.0000
# Epoch 44/200
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0386 - accuracy: 1.0000 - val_loss: 0.0845 - val_accuracy: 1.0000
# Epoch 45/200
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0397 - accuracy: 1.0000 - val_loss: 0.0972 - val_accuracy: 1.0000
# Epoch 46/200
# 11/11 [==============================] - 0s 14ms/step - loss: 0.0327 - accuracy: 1.0000 - val_loss: 0.1214 - val_accuracy: 1.0000
# Epoch 47/200
# 11/11 [==============================] - 0s 11ms/step - loss: 0.0336 - accuracy: 1.0000 - val_loss: 0.1332 - val_accuracy: 1.0000
# Epoch 48/200
# 11/11 [==============================] - 0s 12ms/step - loss: 0.0305 - accuracy: 1.0000 - val_loss: 0.1352 - val_accuracy: 1.0000
# Epoch 49/200
# 11/11 [==============================] - 0s 17ms/step - loss: 0.0323 - accuracy: 1.0000 - val_loss: 0.1257 - val_accuracy: 1.0000
# Epoch 50/200
# 11/11 [==============================] - 0s 14ms/step - loss: 0.0341 - accuracy: 1.0000 - val_loss: 0.1093 - val_accuracy: 1.0000
# Epoch 51/200
# 11/11 [==============================] - 0s 12ms/step - loss: 0.0270 - accuracy: 1.0000 - val_loss: 0.1185 - val_accuracy: 1.0000
# Epoch 52/200
# 11/11 [==============================] - 0s 14ms/step - loss: 0.0270 - accuracy: 1.0000 - val_loss: 0.1069 - val_accuracy: 1.0000
# Epoch 53/200
# 11/11 [==============================] - 0s 15ms/step - loss: 0.0243 - accuracy: 1.0000 - val_loss: 0.1072 - val_accuracy: 1.0000
# Epoch 54/200
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0242 - accuracy: 1.0000 - val_loss: 0.0974 - val_accuracy: 1.0000
# Epoch 55/200
# 11/11 [==============================] - 0s 11ms/step - loss: 0.0235 - accuracy: 1.0000 - val_loss: 0.0997 - val_accuracy: 1.0000
# Epoch 56/200
# 11/11 [==============================] - 0s 12ms/step - loss: 0.0225 - accuracy: 1.0000 - val_loss: 0.1031 - val_accuracy: 1.0000
# Epoch 57/200
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0203 - accuracy: 1.0000 - val_loss: 0.0992 - val_accuracy: 1.0000
# Epoch 58/200
# 11/11 [==============================] - 0s 14ms/step - loss: 0.0197 - accuracy: 1.0000 - val_loss: 0.0988 - val_accuracy: 1.0000
# Epoch 59/200
# 11/11 [==============================] - 0s 14ms/step - loss: 0.0195 - accuracy: 1.0000 - val_loss: 0.0918 - val_accuracy: 1.0000
# Epoch 60/200
# 11/11 [==============================] - 0s 13ms/step - loss: 0.0195 - accuracy: 1.0000 - val_loss: 0.0935 - val_accuracy: 1.0000
# Epoch 61/200
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0173 - accuracy: 1.0000 - val_loss: 0.0874 - val_accuracy: 1.0000
# Epoch 62/200
# 11/11 [==============================] - 0s 12ms/step - loss: 0.0200 - accuracy: 1.0000 - val_loss: 0.0904 - val_accuracy: 1.0000
# Epoch 63/200
# 11/11 [==============================] - 0s 11ms/step - loss: 0.0160 - accuracy: 1.0000 - val_loss: 0.0870 - val_accuracy: 1.0000
# Epoch 64/200
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0161 - accuracy: 1.0000 - val_loss: 0.0853 - val_accuracy: 1.0000
# Epoch 65/200
# 11/11 [==============================] - 0s 13ms/step - loss: 0.0153 - accuracy: 1.0000 - val_loss: 0.0800 - val_accuracy: 1.0000
# Epoch 66/200
# 11/11 [==============================] - 0s 14ms/step - loss: 0.0146 - accuracy: 1.0000 - val_loss: 0.0858 - val_accuracy: 1.0000
# Epoch 67/200
# 11/11 [==============================] - 0s 12ms/step - loss: 0.0148 - accuracy: 1.0000 - val_loss: 0.0914 - val_accuracy: 1.0000
# Epoch 68/200
# 11/11 [==============================] - 0s 14ms/step - loss: 0.0146 - accuracy: 1.0000 - val_loss: 0.0880 - val_accuracy: 1.0000
# Epoch 69/200
# 11/11 [==============================] - 0s 13ms/step - loss: 0.0137 - accuracy: 1.0000 - val_loss: 0.0779 - val_accuracy: 1.0000
# Epoch 70/200
# 11/11 [==============================] - 0s 11ms/step - loss: 0.0142 - accuracy: 1.0000 - val_loss: 0.0806 - val_accuracy: 1.0000
# Epoch 71/200
# 11/11 [==============================] - 0s 17ms/step - loss: 0.0124 - accuracy: 1.0000 - val_loss: 0.0842 - val_accuracy: 1.0000
# Epoch 72/200
# 11/11 [==============================] - 0s 14ms/step - loss: 0.0125 - accuracy: 1.0000 - val_loss: 0.0783 - val_accuracy: 1.0000
# Epoch 73/200
# 11/11 [==============================] - 0s 11ms/step - loss: 0.0122 - accuracy: 1.0000 - val_loss: 0.0775 - val_accuracy: 1.0000
# Epoch 74/200
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0120 - accuracy: 1.0000 - val_loss: 0.0747 - val_accuracy: 1.0000
# Epoch 75/200
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0111 - accuracy: 1.0000 - val_loss: 0.0792 - val_accuracy: 1.0000
# Epoch 76/200
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0103 - accuracy: 1.0000 - val_loss: 0.0809 - val_accuracy: 1.0000
# Epoch 77/200
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0104 - accuracy: 1.0000 - val_loss: 0.0750 - val_accuracy: 1.0000
# Epoch 78/200
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0100 - accuracy: 1.0000 - val_loss: 0.0787 - val_accuracy: 1.0000
# Epoch 79/200
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0101 - accuracy: 1.0000 - val_loss: 0.0759 - val_accuracy: 1.0000
# Epoch 80/200
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0100 - accuracy: 1.0000 - val_loss: 0.0795 - val_accuracy: 1.0000
# Epoch 81/200
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0097 - accuracy: 1.0000 - val_loss: 0.0760 - val_accuracy: 1.0000
# Epoch 82/200
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0085 - accuracy: 1.0000 - val_loss: 0.0739 - val_accuracy: 1.0000
# Epoch 83/200
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0087 - accuracy: 1.0000 - val_loss: 0.0756 - val_accuracy: 1.0000
# Epoch 84/200
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0080 - accuracy: 1.0000 - val_loss: 0.0778 - val_accuracy: 1.0000
# Epoch 85/200
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0098 - accuracy: 1.0000 - val_loss: 0.0719 - val_accuracy: 1.0000
# Epoch 86/200
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0077 - accuracy: 1.0000 - val_loss: 0.0729 - val_accuracy: 1.0000
# Epoch 87/200
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0077 - accuracy: 1.0000 - val_loss: 0.0732 - val_accuracy: 1.0000
# Epoch 88/200
# 11/11 [==============================] - 0s 12ms/step - loss: 0.0074 - accuracy: 1.0000 - val_loss: 0.0728 - val_accuracy: 1.0000
# Epoch 89/200
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0071 - accuracy: 1.0000 - val_loss: 0.0713 - val_accuracy: 1.0000
# Epoch 90/200
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 0.0740 - val_accuracy: 1.0000
# Epoch 91/200
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0068 - accuracy: 1.0000 - val_loss: 0.0743 - val_accuracy: 1.0000
# Epoch 92/200
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0065 - accuracy: 1.0000 - val_loss: 0.0766 - val_accuracy: 1.0000
# Epoch 93/200
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0063 - accuracy: 1.0000 - val_loss: 0.0765 - val_accuracy: 1.0000
# Epoch 94/200
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0063 - accuracy: 1.0000 - val_loss: 0.0707 - val_accuracy: 1.0000
# Epoch 95/200
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.0735 - val_accuracy: 1.0000
# Epoch 96/200
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0061 - accuracy: 1.0000 - val_loss: 0.0757 - val_accuracy: 1.0000
# Epoch 97/200
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0065 - accuracy: 1.0000 - val_loss: 0.0749 - val_accuracy: 1.0000
# Epoch 98/200
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0058 - accuracy: 1.0000 - val_loss: 0.0756 - val_accuracy: 1.0000
# Epoch 99/200
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.0751 - val_accuracy: 1.0000
# Epoch 100/200
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0050 - accuracy: 1.0000 - val_loss: 0.0731 - val_accuracy: 1.0000
# Epoch 101/200
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.0728 - val_accuracy: 1.0000
# Epoch 102/200
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.0733 - val_accuracy: 1.0000
# Epoch 103/200
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 0.0742 - val_accuracy: 1.0000
# Epoch 104/200
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.0743 - val_accuracy: 1.0000
# Epoch 105/200
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.0707 - val_accuracy: 1.0000
# Epoch 106/200
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.0702 - val_accuracy: 1.0000
# Epoch 107/200
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 0.0705 - val_accuracy: 1.0000
# Epoch 108/200
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 0.0726 - val_accuracy: 1.0000
# Epoch 109/200
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.0722 - val_accuracy: 1.0000
# Epoch 110/200
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.0728 - val_accuracy: 1.0000
# Epoch 111/200
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.0729 - val_accuracy: 1.0000
# Epoch 112/200
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.0717 - val_accuracy: 1.0000
# Epoch 113/200
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.0703 - val_accuracy: 1.0000
# Epoch 114/200
# 11/11 [==============================] - 0s 11ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.0718 - val_accuracy: 1.0000
# Epoch 115/200
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.0751 - val_accuracy: 1.0000
# Epoch 116/200
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.0723 - val_accuracy: 1.0000
# Epoch 117/200
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.0737 - val_accuracy: 1.0000
# Epoch 118/200
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.0723 - val_accuracy: 1.0000
# Epoch 119/200
# 11/11 [==============================] - 0s 12ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.0706 - val_accuracy: 1.0000
# Epoch 120/200
# 11/11 [==============================] - 0s 12ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.0731 - val_accuracy: 1.0000
# Epoch 121/200
# 11/11 [==============================] - 0s 11ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.0726 - val_accuracy: 1.0000
# Epoch 122/200
# 11/11 [==============================] - 0s 11ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.0730 - val_accuracy: 1.0000
# Epoch 123/200
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.0732 - val_accuracy: 1.0000
# Epoch 124/200
# 11/11 [==============================] - 0s 13ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.0729 - val_accuracy: 1.0000
# Epoch 125/200
# 11/11 [==============================] - 0s 12ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.0725 - val_accuracy: 1.0000
# Epoch 126/200
# 11/11 [==============================] - 0s 11ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.0747 - val_accuracy: 1.0000
# Epoch 127/200
# 11/11 [==============================] - 0s 11ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.0725 - val_accuracy: 1.0000
# Epoch 128/200
# 11/11 [==============================] - 0s 13ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.0726 - val_accuracy: 1.0000
# Epoch 129/200
# 11/11 [==============================] - 0s 11ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.0733 - val_accuracy: 1.0000
# Epoch 130/200
# 11/11 [==============================] - 0s 11ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.0737 - val_accuracy: 1.0000
# Epoch 131/200
# 11/11 [==============================] - 0s 11ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.0748 - val_accuracy: 1.0000
# Epoch 132/200
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.0739 - val_accuracy: 1.0000
# Epoch 133/200
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.0719 - val_accuracy: 1.0000
# Epoch 134/200
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.0717 - val_accuracy: 1.0000
# Epoch 135/200
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.0726 - val_accuracy: 1.0000
# Epoch 136/200
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.0724 - val_accuracy: 1.0000
# Epoch 137/200
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.0720 - val_accuracy: 1.0000
# Epoch 138/200
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.0740 - val_accuracy: 1.0000
# Epoch 139/200
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.0755 - val_accuracy: 1.0000
# Epoch 140/200
# 11/11 [==============================] - 0s 13ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.0748 - val_accuracy: 1.0000
# Epoch 141/200
# 11/11 [==============================] - 0s 12ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.0737 - val_accuracy: 1.0000
# Epoch 142/200
# 11/11 [==============================] - 0s 12ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.0747 - val_accuracy: 1.0000
# Epoch 143/200
# 11/11 [==============================] - 0s 11ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.0738 - val_accuracy: 1.0000
# Epoch 144/200
# 11/11 [==============================] - 0s 19ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.0730 - val_accuracy: 1.0000
# Epoch 145/200
# 11/11 [==============================] - 0s 14ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0733 - val_accuracy: 1.0000
# Epoch 146/200
# 11/11 [==============================] - 0s 15ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0742 - val_accuracy: 1.0000
# Epoch 147/200
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0735 - val_accuracy: 1.0000
# Epoch 148/200
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0735 - val_accuracy: 1.0000
# Epoch 149/200
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0738 - val_accuracy: 1.0000
# Epoch 150/200
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0728 - val_accuracy: 1.0000
# Epoch 151/200
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0733 - val_accuracy: 1.0000
# Epoch 152/200
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0737 - val_accuracy: 1.0000
# Epoch 153/200
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0739 - val_accuracy: 1.0000
# Epoch 154/200
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0738 - val_accuracy: 1.0000
# Epoch 155/200
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0740 - val_accuracy: 1.0000
# Epoch 156/200
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0757 - val_accuracy: 1.0000
# Epoch 157/200
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0759 - val_accuracy: 1.0000
# Epoch 158/200
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0750 - val_accuracy: 1.0000
# Epoch 159/200
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0744 - val_accuracy: 1.0000
# Epoch 160/200
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0756 - val_accuracy: 1.0000
# Epoch 161/200
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0754 - val_accuracy: 1.0000
# Epoch 162/200
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0741 - val_accuracy: 1.0000
# Epoch 163/200
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0753 - val_accuracy: 1.0000
# Epoch 164/200
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0746 - val_accuracy: 1.0000
# Epoch 165/200
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0766 - val_accuracy: 1.0000
# Epoch 166/200
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0767 - val_accuracy: 1.0000
# Epoch 167/200
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0785 - val_accuracy: 1.0000
# Epoch 168/200
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0773 - val_accuracy: 1.0000
# Epoch 169/200
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0780 - val_accuracy: 1.0000
# Epoch 170/200
# 11/11 [==============================] - 0s 11ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0789 - val_accuracy: 1.0000
# Epoch 171/200
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0763 - val_accuracy: 1.0000
# Epoch 172/200
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0757 - val_accuracy: 1.0000
# Epoch 173/200
# 11/11 [==============================] - 0s 11ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0769 - val_accuracy: 1.0000
# Epoch 174/200
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0790 - val_accuracy: 1.0000
# Epoch 175/200
# 11/11 [==============================] - 0s 11ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0775 - val_accuracy: 1.0000
# Epoch 176/200
# 11/11 [==============================] - 0s 11ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0764 - val_accuracy: 1.0000
# Epoch 177/200
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0763 - val_accuracy: 1.0000
# Epoch 178/200
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0764 - val_accuracy: 1.0000
# Epoch 179/200
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0773 - val_accuracy: 1.0000
# Epoch 180/200
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0766 - val_accuracy: 1.0000
# Epoch 181/200
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0775 - val_accuracy: 1.0000
# Epoch 182/200
# 11/11 [==============================] - 0s 12ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0787 - val_accuracy: 1.0000
# Epoch 183/200
# 11/11 [==============================] - 0s 11ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0778 - val_accuracy: 1.0000
# Epoch 184/200
# 11/11 [==============================] - 0s 13ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0782 - val_accuracy: 1.0000
# Epoch 185/200
# 11/11 [==============================] - 0s 14ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0796 - val_accuracy: 1.0000
# Epoch 186/200
# 11/11 [==============================] - 0s 13ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0772 - val_accuracy: 1.0000
# Epoch 187/200
# 11/11 [==============================] - 0s 13ms/step - loss: 9.7279e-04 - accuracy: 1.0000 - val_loss: 0.0766 - val_accuracy: 1.0000
# Epoch 188/200
# 11/11 [==============================] - 0s 14ms/step - loss: 9.6117e-04 - accuracy: 1.0000 - val_loss: 0.0775 - val_accuracy: 1.0000
# Epoch 189/200
# 11/11 [==============================] - 0s 12ms/step - loss: 9.9803e-04 - accuracy: 1.0000 - val_loss: 0.0788 - val_accuracy: 1.0000
# Epoch 190/200
# 11/11 [==============================] - 0s 11ms/step - loss: 9.8704e-04 - accuracy: 1.0000 - val_loss: 0.0803 - val_accuracy: 1.0000
# Epoch 191/200
# 11/11 [==============================] - 0s 11ms/step - loss: 9.2180e-04 - accuracy: 1.0000 - val_loss: 0.0816 - val_accuracy: 1.0000
# Epoch 192/200
# 11/11 [==============================] - 0s 12ms/step - loss: 9.3508e-04 - accuracy: 1.0000 - val_loss: 0.0813 - val_accuracy: 1.0000
# Epoch 193/200
# 11/11 [==============================] - 0s 33ms/step - loss: 8.8923e-04 - accuracy: 1.0000 - val_loss: 0.0802 - val_accuracy: 1.0000
# Epoch 194/200
# 11/11 [==============================] - 0s 14ms/step - loss: 8.8963e-04 - accuracy: 1.0000 - val_loss: 0.0809 - val_accuracy: 1.0000
# Epoch 195/200
# 11/11 [==============================] - 0s 16ms/step - loss: 8.7235e-04 - accuracy: 1.0000 - val_loss: 0.0790 - val_accuracy: 1.0000
# Epoch 196/200
# 11/11 [==============================] - 0s 13ms/step - loss: 8.5618e-04 - accuracy: 1.0000 - val_loss: 0.0794 - val_accuracy: 1.0000
# Epoch 197/200
# 11/11 [==============================] - 0s 12ms/step - loss: 8.5447e-04 - accuracy: 1.0000 - val_loss: 0.0799 - val_accuracy: 1.0000
# Epoch 198/200
# 11/11 [==============================] - 0s 13ms/step - loss: 8.7353e-04 - accuracy: 1.0000 - val_loss: 0.0792 - val_accuracy: 1.0000
# Epoch 199/200
# 11/11 [==============================] - 0s 12ms/step - loss: 8.3640e-04 - accuracy: 1.0000 - val_loss: 0.0798 - val_accuracy: 1.0000
# Epoch 200/200
# 11/11 [==============================] - 0s 10ms/step - loss: 8.5624e-04 - accuracy: 1.0000 - val_loss: 0.0789 - val_accuracy: 1.0000

# %% [markdown]
# ## Model evaluation

# %%
history.history['loss'][:10]
# Out:
# [1.1456376314163208,
#  1.053115725517273,
#  0.9835941791534424,
#  0.9030812978744507,
#  0.8352982997894287,
#  0.7572495937347412,
#  0.689449667930603,
#  0.6218733787536621,
#  0.564205527305603,
#  0.5194980502128601]

# %%
# model.evaluate(x_test, y_test)
loss = model.evaluate(x_test, y_test)

# 繪製訓練歷史
plt.plot(history.history['loss'][10:], label='Training loss')
plt.plot(history.history['val_loss'][10:], label='Validation loss')
plt.legend()
plt.show()
# Out:
# 1/1 [==============================] - 1s 926ms/step - loss: 0.0021 - accuracy: 1.0000

# %%
loss, accuracy = model.evaluate(x_test, y_test)
print(f'Accuracy: {accuracy*100}%')
# Out:
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0021 - accuracy: 1.0000
# Accuracy: 100.0%

# %%
y_pred = model.predict(x_test)
print((y_pred),(y_test))
# Out:
# 1/1 [==============================] - 0s 159ms/step
# [[4.9698744e-03 9.9503005e-01 5.2203872e-09]
#  [9.9990743e-01 3.0398904e-05 6.2052153e-05]
#  [2.6320270e-04 9.9973691e-01 2.4361367e-11]
#  [9.9040288e-01 7.0385727e-06 9.5899254e-03]
#  [9.9991602e-01 6.3560765e-05 2.0425214e-05]
#  [3.6753941e-06 9.9999624e-01 3.3295304e-15]
#  [1.3589852e-03 9.9864095e-01 1.5284535e-09]
#  [5.1229792e-05 5.7060709e-13 9.9994868e-01]] [1 0 1 0 0 1 1 2]

# %%
def plot_scatter (x, y, title, x_label, y_label,n):
    # plt.subplot(2, 2, n);
    plt.figure(figsize=(5, 5));
    plt.scatter(x, y, marker="x", color="red")
    # plt.axis((0,210, 0,210))
    plt.title(title)
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.show()

y_pred = model.predict(x_test)
y_pred = np.argmax(y_pred, axis=1)


plot_scatter(y_test, y_pred, "Testing set", "True value", "Pred. value",1)

y_pred = model.predict(x_train)
y_pred = np.argmax(y_pred, axis=1)

plot_scatter(y_train, y_pred, "Training set", "True value", "Pred. value",2)
# Out:
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 95ms/step

# %%
from sklearn.metrics import confusion_matrix

y_pred = model.predict(x_train)
y_pred = np.argmax(y_pred, axis=1)
cm = confusion_matrix(y_train, y_pred)

# 打印混淆矩陣
print("Confusion Matrix:")
print(cm)
# Out:
# 1/1 [==============================] - 0s 47ms/step
# Confusion Matrix:
# [[ 9  0  0]
#  [ 0 12  0]
#  [ 0  0  7]]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# 繪製混淆矩陣的熱圖
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()
