# %%
https://medium.com/ai%E5%8F%8D%E6%96%97%E5%9F%8E/learning-model-%E4%BB%80%E9%BA%BC%E6%98%AFroc%E5%92%8Cauc-%E8%BD%89%E9%8C%84-33aafe644cf

# %% [markdown]
# ## Data Preparation

# %%
import pandas as pd

output_path = './Salary_Data2.csv'
path = output_path
df = pd.read_csv(output_path)
display(df.head())
# Out:
#    YearsExperience EducationLevel City  Salary
# 0              3.0             大學  城市A    45.9
# 1              7.8           碩士以上  城市C    80.5
# 2              2.3           高中以下  城市A    25.2
# 3              5.1           高中以下  城市A    30.4
# 4             10.0           碩士以上  城市B    65.7

# %%
df.info()
df.describe(include='all').round(2)

#round 函数在 Python（包括 Pandas 库中）的功能是对浮点数进行四舍五入到给定的精度。
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  36 non-null     float64
#  1   EducationLevel   36 non-null     object
#  2   City             36 non-null     object
#  3   Salary           36 non-null     float64
# dtypes: float64(2), object(2)
# memory usage: 1.2+ KB
#         YearsExperience EducationLevel City  Salary
# count             36.00             36   36   36.00
# unique              NaN              3    3     NaN
# top                 NaN           碩士以上  城市A     NaN
# freq                NaN             16   20     NaN
# mean               5.47            NaN  NaN   51.70
# std                2.71            NaN  NaN   17.53
# min                1.20            NaN  NaN   24.90
# 25%                3.38            NaN  NaN   38.05
# 50%                5.15            NaN  NaN   49.20
# 75%                7.65            NaN  NaN   65.75
# max               10.00            NaN  NaN   84.20

# %% [markdown]
# ## Transform the Categorical data to numerical data
# ### @ LabelEncoder：把類別型資料轉換成0,1,2,…的數值標籤 (特徵之間有順序或大小分別)
#    ![image.png](attachment:c86e50e9-fb01-44f3-8d23-a9548281d397.png)
#
# ### @ OneHotEncoder：把類別型資料轉換成0與1的數值標籤 (特徵之間沒有順序或大小分別)
# ![image.png](attachment:f9460b51-747e-473b-9324-c386e4bf5edc.png)
#
# ### Exercise : Try to use the one-hot encoder to encode the Categorical data into numerical data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, StandardScaler, LabelEncoder

encoder = OneHotEncoder()
city_encoded = encoder.fit_transform(df[['City']]).toarray()

scaler = StandardScaler()
scaled_features = scaler.fit_transform(df[['YearsExperience', 'Salary']])

label_encoder = LabelEncoder()
labels = label_encoder.fit_transform(df['EducationLevel'])
# labels = encoder.fit_transform(df[['EducationLevel']]).toarray()

x = np.hstack([scaled_features, city_encoded])
y = labels
# display(x.head(5))

# %%
display(y)
# Out:
# array([0, 1, 2, 2, 1, 1, 0, 1, 0, 2, 2, 0, 1, 1, 1, 0, 1, 0, 2, 2, 0, 1,
#        1, 1, 0, 1, 0, 2, 2, 0, 1, 1, 1, 0, 1, 0])

# %%
# splitting dataset to training set and testing set 
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=200)

# %% [markdown]
# ##  data visualization

# %% [markdown]
# ## Build ANN model

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam

# model = Sequential([
    # Dense(1, input_shape=(1,), activation='linear')
#     Dense(5, input_shape=(x.shape[1],), activation='linear')
# ])

model = Sequential([
    Dense(8, input_shape=(x.shape[1],), activation='relu'),
    Dense(6, activation='relu'),
    Dense(3, activation='softmax')
])

# Sequential.help

model.compile(optimizer=Adam(learning_rate=0.005), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ## Training ANN model

# %%
from tensorflow.keras.callbacks import EarlyStopping

# early_stop = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)
history = model.fit(x_train, y_train, validation_split=0.2, epochs=20, batch_size=2)
# Out:
# Epoch 1/20
# 11/11 [==============================] - 2s 69ms/step - loss: 1.1202 - accuracy: 0.3182 - val_loss: 1.1334 - val_accuracy: 0.3333
# Epoch 2/20
# 11/11 [==============================] - 0s 10ms/step - loss: 1.0227 - accuracy: 0.5909 - val_loss: 1.0896 - val_accuracy: 0.3333
# Epoch 3/20
# 11/11 [==============================] - 0s 9ms/step - loss: 0.9837 - accuracy: 0.6364 - val_loss: 1.0695 - val_accuracy: 0.3333
# Epoch 4/20
# 11/11 [==============================] - 0s 10ms/step - loss: 0.9509 - accuracy: 0.6364 - val_loss: 1.0279 - val_accuracy: 0.3333
# Epoch 5/20
# 11/11 [==============================] - 0s 10ms/step - loss: 0.9012 - accuracy: 0.6364 - val_loss: 1.0124 - val_accuracy: 0.3333
# Epoch 6/20
# 11/11 [==============================] - 0s 10ms/step - loss: 0.8502 - accuracy: 0.6364 - val_loss: 0.9682 - val_accuracy: 0.5000
# Epoch 7/20
# 11/11 [==============================] - 0s 11ms/step - loss: 0.8021 - accuracy: 0.6364 - val_loss: 0.9456 - val_accuracy: 0.5000
# Epoch 8/20
# 11/11 [==============================] - 0s 12ms/step - loss: 0.7540 - accuracy: 0.6364 - val_loss: 0.8760 - val_accuracy: 0.8333
# Epoch 9/20
# 11/11 [==============================] - 0s 11ms/step - loss: 0.7030 - accuracy: 0.7727 - val_loss: 0.8225 - val_accuracy: 0.8333
# Epoch 10/20
# 11/11 [==============================] - 0s 14ms/step - loss: 0.6576 - accuracy: 0.7727 - val_loss: 0.7428 - val_accuracy: 0.8333
# Epoch 11/20
# 11/11 [==============================] - 0s 11ms/step - loss: 0.6012 - accuracy: 0.7727 - val_loss: 0.6650 - val_accuracy: 0.8333
# Epoch 12/20
# 11/11 [==============================] - 0s 10ms/step - loss: 0.5549 - accuracy: 0.7727 - val_loss: 0.5896 - val_accuracy: 0.8333
# Epoch 13/20
# 11/11 [==============================] - 0s 12ms/step - loss: 0.5152 - accuracy: 0.7727 - val_loss: 0.5188 - val_accuracy: 0.8333
# Epoch 14/20
# 11/11 [==============================] - 0s 12ms/step - loss: 0.4872 - accuracy: 0.7727 - val_loss: 0.4564 - val_accuracy: 0.8333
# Epoch 15/20
# 11/11 [==============================] - 0s 14ms/step - loss: 0.4560 - accuracy: 0.7727 - val_loss: 0.4148 - val_accuracy: 0.8333
# Epoch 16/20
# 11/11 [==============================] - 0s 12ms/step - loss: 0.4340 - accuracy: 0.7727 - val_loss: 0.3881 - val_accuracy: 0.8333
# Epoch 17/20
# 11/11 [==============================] - 0s 10ms/step - loss: 0.4242 - accuracy: 0.7727 - val_loss: 0.3438 - val_accuracy: 0.8333
# Epoch 18/20
# 11/11 [==============================] - 0s 10ms/step - loss: 0.4091 - accuracy: 0.7727 - val_loss: 0.3151 - val_accuracy: 0.8333
# Epoch 19/20
# 11/11 [==============================] - 0s 11ms/step - loss: 0.3972 - accuracy: 0.7727 - val_loss: 0.3147 - val_accuracy: 0.8333
# Epoch 20/20
# 11/11 [==============================] - 0s 12ms/step - loss: 0.3833 - accuracy: 0.7727 - val_loss: 0.2936 - val_accuracy: 0.8333

# %% [markdown]
# ## Model evaluation

# %%
history.history['loss'][:10]
# Out:
# [1.1202385425567627,
#  1.0227150917053223,
#  0.9837265014648438,
#  0.9508820176124573,
#  0.9012378454208374,
#  0.8502330183982849,
#  0.8021261096000671,
#  0.7540144324302673,
#  0.7029575705528259,
#  0.65756756067276]

# %%
# model.evaluate(x_test, y_test)
loss = model.evaluate(x_test, y_test)

# 繪製訓練歷史
plt.plot(history.history['loss'][10:], label='Training loss')
plt.plot(history.history['val_loss'][10:], label='Validation loss')
plt.legend()
plt.show()
# Out:
# 1/1 [==============================] - 0s 420ms/step - loss: 0.3477 - accuracy: 0.7500

# %%
loss, accuracy = model.evaluate(x_test, y_test)
print(f'Accuracy: {accuracy*100}%')
# Out:
# 1/1 [==============================] - 0s 61ms/step - loss: 0.3477 - accuracy: 0.7500
# Accuracy: 75.0%

# %%
y_pred = model.predict(x_test)
print((y_pred),(y_test))
# Out:
# 1/1 [==============================] - 0s 240ms/step
# [[0.04006026 0.93636554 0.02357419]
#  [0.42874733 0.01165029 0.5596024 ]
#  [0.13873498 0.76705    0.09421497]
#  [0.7682122  0.02628961 0.20549828]
#  [0.40598777 0.01678252 0.5772296 ]
#  [0.02725996 0.9538163  0.01892371]
#  [0.03189098 0.9485395  0.01956939]
#  [0.28569603 0.00176016 0.7125438 ]] [1 0 1 0 0 1 1 2]

# %%
def plot_scatter (x, y, title, x_label, y_label,n):
    # plt.subplot(2, 2, n);
    plt.figure(figsize=(5, 5));
    plt.scatter(x, y, marker="x", color="red")
    # plt.axis((0,210, 0,210))
    plt.title(title)
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.show()

y_pred = model.predict(x_test)
y_pred = np.argmax(y_pred, axis=1)


plot_scatter(y_test, y_pred, "Testing set", "True value", "Pred. value",1)

y_pred = model.predict(x_train)
y_pred = np.argmax(y_pred, axis=1)

plot_scatter(y_train, y_pred, "Training set", "True value", "Pred. value",2)
# Out:
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 61ms/step

# %%
from sklearn.metrics import confusion_matrix

y_pred = model.predict(x_train)
y_pred = np.argmax(y_pred, axis=1)
cm = confusion_matrix(y_train, y_pred)

# 打印混淆矩陣
print("Confusion Matrix:")
print(cm)
# Out:
# 1/1 [==============================] - 0s 59ms/step
# Confusion Matrix:
# [[ 3  0  6]
#  [ 0 12  0]
#  [ 0  0  7]]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# 繪製混淆矩陣的熱圖
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()
